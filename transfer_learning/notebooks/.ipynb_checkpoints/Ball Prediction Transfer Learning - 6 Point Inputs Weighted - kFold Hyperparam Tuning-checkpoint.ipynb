# %% [markdown]
# # Ping Pong Ball Prediction Using Transfer Learning:
#
# Inputs:
# - x y z (frame 1)
# - x y z (frame 2)
# - x y z (frame 3)
# - x y z (frame 4)
# - x y z (frame 5)
# - x y z (frame 6)
# - dt12
# - dt23
# - dt34
# - dt45
# - dt56
#
#
# Outputs:
# - x y z (interception)
# - vx vy vz
# - t_hit

# %% [markdown]
# ## Importing the Libraries

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ### Importing the Dataset

# %%
dataset = pd.read_csv('../learning_data/synthetic_data/synthetic_intercept_dataset.csv')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 41 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   x1                     20000 non-null  float64
#  1   y1                     20000 non-null  float64
#  2   z1                     20000 non-null  float64
#  3   x2                     20000 non-null  float64
#  4   y2                     20000 non-null  float64
#  5   z2                     20000 non-null  float64
#  6   x3                     20000 non-null  float64
#  7   y3                     20000 non-null  float64
#  8   z3                     20000 non-null  float64
#  9   x4                     20000 non-null  float64
#  10  y4                     20000 non-null  float64
#  11  z4                     20000 non-null  float64
#  12  x5                     20000 non-null  float64
#  13  y5                     20000 non-null  float64
#  14  z5                     20000 non-null  float64
#  15  x6                     20000 non-null  float64
#  16  y6                     20000 non-null  float64
#  17  z6                     20000 non-null  float64
#  18  dt12                   20000 non-null  float64
#  19  dt23                   20000 non-null  float64
#  20  dt34                   20000 non-null  float64
#  21  dt45                   20000 non-null  float64
#  22  dt56                   20000 non-null  float64
#  23  x_hit                  20000 non-null  float64
#  24  y_hit                  20000 non-null  float64
#  25  z_hit                  20000 non-null  float64
#  26  vx_hit                 20000 non-null  float64
#  27  vy_hit                 20000 non-null  float64
#  28  vz_hit                 20000 non-null  float64
#  29  t_hit                  20000 non-null  float64
#  30  is_reachable           20000 non-null  float64
#  31  bounces_before_hit     20000 non-null  float64
#  32  has_bounce_before_hit  20000 non-null  float64
#  33  intercept_valid        20000 non-null  float64
#  34  x0                     20000 non-null  float64
#  35  y0                     20000 non-null  float64
#  36  z0                     20000 non-null  float64
#  37  vx0                    20000 non-null  float64
#  38  vy0                    20000 non-null  float64
#  39  vz0                    20000 non-null  float64
#  40  gravity_z_mm_s2        20000 non-null  float64
# dtypes: float64(41)
# memory usage: 6.3 MB

# %%
dataset.describe()
# Out:
#                  x1            y1            z1            x2            y2  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       2.846180   2586.805399   -800.782866      2.587758   2516.164890
# std      611.462974    375.072852    203.189690    589.374269    397.389140
# min    -1062.362775   1940.034250  -1150.718078  -1063.103457   1765.688301
# 25%     -528.535366   2260.726977   -977.935437   -509.131333   2172.421868
# 50%        3.959062   2585.280814   -801.336626      1.937988   2515.546526
# 75%      529.412526   2912.452341   -622.844420    508.848227   2861.943378
# max     1062.362428   3239.991853   -450.793865   1062.991701   3220.357264
#
#                  z2            x3            y3            z3            x4  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean    -830.432964      2.335908   2445.474348   -857.060668      2.063134
# std      201.130733    568.209203    420.543096    195.828620    548.091609
# min    -1150.553726  -1064.714239   1589.401180  -1150.412514  -1069.299827
# 25%    -1011.389874   -487.865675   2084.232867  -1040.274206   -467.281644
# 50%     -832.605819      1.703397   2442.896152   -868.113493      1.632830
# 75%     -654.383173    490.945488   2810.925219   -688.377206    474.061369
# max     -424.677132   1065.423516   3204.612203   -395.711871   1067.941189
#
#        ...  bounces_before_hit  has_bounce_before_hit  intercept_valid  \
# count  ...         20000.00000           20000.000000          20000.0
# mean   ...             1.15260               0.957000              1.0
# std    ...             0.46403               0.202862              0.0
# min    ...             0.00000               0.000000              1.0
# 25%    ...             1.00000               1.000000              1.0
# 50%    ...             1.00000               1.000000              1.0
# 75%    ...             1.00000               1.000000              1.0
# max    ...             2.00000               1.000000              1.0
#
#                  x0            y0            z0           vx0           vy0  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       2.846180   2586.805399   -800.782866    -16.938254  -4560.467929
# std      611.462974    375.072852    203.189690   2055.477303   1858.306767
# min    -1062.362775   1940.034250  -1150.718078  -5389.215897 -10000.000000
# 25%     -528.535366   2260.726977   -977.935437  -1493.140882  -5785.656253
# 50%        3.959062   2585.280814   -801.336626    -20.485697  -4299.572021
# 75%      529.412526   2912.452341   -622.844420   1442.721220  -3122.030705
# max     1062.362428   3239.991853   -450.793865   5259.466574   -816.493459
#
#                 vz0  gravity_z_mm_s2
# count  20000.000000          20000.0
# mean   -2008.859992          -9810.0
# std     1790.670399              0.0
# min    -5579.934696          -9810.0
# 25%    -3529.333450          -9810.0
# 50%    -2039.711058          -9810.0
# 75%     -599.665230          -9810.0
# max     2414.174822          -9810.0
#
# [8 rows x 41 columns]

# %% [markdown]
# ### Pre-Processing

# %% [markdown]
# ### Separating the Input and Outputs

# %%
input_cols_6 = [
    "x1", "y1", "z1",
    "x2", "y2", "z2",
    "x3", "y3", "z3",
    "x4", "y4", "z4",
    "x5", "y5", "z5",
    "x6", "y6", "z6",
    "dt12", "dt23", "dt34", "dt45", "dt56",
]
target_cols = ["x_hit", "y_hit", "z_hit", "vx_hit", "vy_hit", "vz_hit", "t_hit"]

x = dataset[input_cols_6]
y = dataset[target_cols]

# %%
# View the inputs
print(x)
# Out:
#                x1           y1           z1          x2           y2  \
# 0     -129.883316  3056.177296  -662.582380  -82.613370  3020.750138
# 1     -637.695070  1949.570951  -599.892936 -598.290176  1818.696515
# 2      981.532537  3121.154898  -660.945006  979.224710  3084.695960
# 3     -129.813147  1968.095704  -572.335653 -156.440657  1812.347335
# 4     -403.062195  2950.626290  -470.461502 -415.733914  2903.238033
# ...           ...          ...          ...         ...          ...
# 19995 -569.758900  1956.017896  -541.428463 -548.070337  1834.083464
# 19996 -576.209725  1945.075686  -657.666635 -542.943741  1825.041555
# 19997   -0.633386  2788.299177  -802.618530   18.380385  2696.490869
# 19998  928.145514  3204.306094 -1082.108162  877.262426  3156.054259
# 19999  584.466916  2829.469475  -779.738803  538.987805  2785.366693
#
#                 z2          x3           y3           z3          x4  ...  \
# 0      -652.486762  -39.135189  2988.164773  -645.857170    6.740777  ...
# 1      -626.042303 -561.264075  1695.722700  -652.981292 -523.102993  ...
# 2      -665.155562  977.211292  3052.888079  -671.259336  975.364845  ...
# 3      -642.736582 -177.844024  1687.155774  -701.300065 -205.636378  ...
# 4      -535.784846 -429.172271  2852.982794  -607.651254 -442.149069  ...
# ...            ...         ...          ...          ...         ...  ...
# 19995  -589.468395 -531.494975  1740.895759  -628.225426 -511.076694  ...
# 19996  -694.995376 -508.235709  1699.804062  -736.760036 -479.229496  ...
# 19997  -860.898889   37.755048  2602.939992  -923.333310   55.393128  ...
# 19998 -1146.836336  826.755122  3108.158776 -1077.094869  770.921143  ...
# 19999  -768.327112  490.317110  2738.168913  -758.862237  444.621120  ...
#
#                 y5           z5          x6           y6           z6  \
# 0      2923.210564  -640.359486   85.426327  2894.810306  -641.162618
# 1      1434.236947  -717.930680 -443.534728  1304.711322  -753.980682
# 2      2993.469606  -688.790685  971.355387  2960.376792  -702.029303
# 3      1393.739997  -845.671054 -248.855290  1271.800047  -908.543422
# 4      2761.741985  -744.897833 -467.456775  2709.810758  -826.923616
# ...            ...          ...         ...          ...          ...
# 19995  1520.983889  -726.833104 -472.144009  1407.220989  -781.746239
# 19996  1467.468437  -821.934846 -416.033935  1367.111065  -861.822858
# 19997  2441.777690 -1038.281873   86.665441  2366.775362 -1094.927325
# 19998  3006.816766  -934.366468  658.834572  2948.921688  -857.125388
# 19999  2657.376946  -749.256468  363.911134  2615.588345  -747.564670
#
#            dt12      dt23      dt34      dt45      dt56
# 0      0.017634  0.016219  0.017114  0.015217  0.014136
# 1      0.016342  0.015355  0.015826  0.016825  0.016174
# 2      0.017513  0.015279  0.014012  0.014530  0.015896
# 3      0.016843  0.013539  0.017580  0.014151  0.013187
# 4      0.015532  0.016471  0.015906  0.013999  0.017021
# ...         ...       ...       ...       ...       ...
# 19995  0.017707  0.013533  0.016670  0.015265  0.016521
# 19996  0.016500  0.017215  0.014387  0.017550  0.013795
# 19997  0.017530  0.017862  0.016261  0.014511  0.014321
# 19998  0.014875  0.014765  0.016322  0.014919  0.017848
# 19999  0.015927  0.017044  0.016002  0.013173  0.015091
#
# [20000 rows x 23 columns]

# %%
# View the outputs
print(y)
# Out:
#              x_hit        y_hit        z_hit       vx_hit       vy_hit  \
# 0      1371.275360  1931.111771  -754.428699  2680.640491 -2009.045581
# 1       -22.823035   -92.587337 -1011.623073  2411.262880 -8008.463872
# 2       784.524643     8.834025  -954.400194  -131.777856 -2081.819982
# 3      -430.184554   211.177523  -817.838405 -1580.902144 -9246.937796
# 4     -1288.275025  -359.792069  -317.001280  -815.864359 -3051.076828
# ...            ...          ...          ...          ...          ...
# 19995  -251.299871   165.621686  -817.065476  1224.842421 -6886.139268
# 19996   -41.939604    17.261082  -819.872175  2016.113666 -7274.772092
# 19997   552.542952   117.278195  -268.933929  1084.659487 -5237.296043
# 19998 -1363.733066  1030.944538   -64.595064 -3420.714299 -3243.823218
# 19999 -1114.591436  1181.829511  -764.898660 -2855.560255 -2769.142797
#
#             vz_hit     t_hit
# 0      1496.186381  0.479680
# 1      3222.377021  0.174478
# 2     -2404.186073  1.417770
# 3      4646.398297  0.114700
# 4     -3746.520565  1.006072
# ...            ...       ...
# 19995  3506.516783  0.180304
# 19996  2816.769102  0.185552
# 19997    80.428533  0.429515
# 19998 -1559.836134  0.591271
# 19999   584.422732  0.517763
#
# [20000 rows x 7 columns]

# %%
x = x.values
y = y.values

# %% [markdown]
# ### Splitting the Dataset into the Training set and Test set

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error

# 1) Build reachability vector from your full dataset
# (change column name if needed)
r = dataset["is_reachable"].to_numpy().astype(int)

# 2) Split x, y, and r together (important)
x_train, x_test, y_train, y_test, r_train, r_test = train_test_split(
    x, y, r,
    test_size=0.05,
    random_state=6,
    stratify=r   # recommended
)

# 3) Keep full test copy
x_test_all = x_test.copy()
y_test_all = y_test.copy()

# 4) Reachable-only adjusted test set
mask_reach = (r_test == 1)
x_test_reach = x_test_all[mask_reach].copy()
y_test_reach = y_test_all[mask_reach].copy()

# %%
print(x_train.shape)
print(x_test_all.shape)
print(x_test_reach.shape)
print(y_train.shape)
print(y_test_all.shape)
print(y_test_reach.shape)
# Out:
# (19000, 23)
# (1000, 23)
# (236, 23)
# (19000, 7)
# (1000, 7)
# (236, 7)

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

scx = StandardScaler()
scy = StandardScaler()

x_train = scx.fit_transform(x_train)
x_test_all = scx.transform(x_test_all)
x_test_reach = scx.transform(x_test_reach)

y_train = scy.fit_transform((y_train))
y_test_all = scy.transform((y_test_all))
y_test_reach = scy.transform((y_test_reach))

# %%
# --- weighted loss + sample weighting helpers (xyz emphasis + center/reach emphasis) ---
import tensorflow as tf
import numpy as np

@tf.keras.utils.register_keras_serializable(package="Custom")
def weighted_mse(y_true, y_pred):
    # Output order: [x_hit, y_hit, z_hit, vx_hit, vy_hit, vz_hit, t_hit]
    raw_w = tf.constant([8.0, 8.0, 8.0, 0.5, 0.5, 0.5, 1.0], dtype=tf.float32)
    w = raw_w / tf.reduce_mean(raw_w)
    err2 = tf.square(y_true - y_pred)
    return tf.reduce_mean(err2 * w)

WORKSPACE_CENTER_MM = np.array([0.0, 0.0, -900.0], dtype=np.float32)
CENTER_SIGMA_MM = 250.0
REACH_BOOST = 1.0
CENTER_BOOST = 2.0

def build_sample_weights(y_train_scaled, y_scaler, reachable_vec=None,
                         center=WORKSPACE_CENTER_MM,
                         sigma_mm=CENTER_SIGMA_MM,
                         reach_boost=REACH_BOOST,
                         center_boost=CENTER_BOOST):
    y_u = y_scaler.inverse_transform(y_train_scaled)
    d_mm = np.linalg.norm(y_u[:, :3] - center[None, :], axis=1)

    w_center = 1.0 + center_boost * np.exp(-(d_mm ** 2) / (2.0 * sigma_mm ** 2))
    if reachable_vec is None:
        w_reach = np.ones_like(w_center)
    else:
        w_reach = 1.0 + reach_boost * np.asarray(reachable_vec, dtype=float)

    w = w_center * w_reach
    w = w / np.mean(w)
    return np.clip(w, 0.5, 5.0)

# Broad-stage sample weights (r_train comes from the broad train/test split cell)
sample_w_broad = build_sample_weights(y_train, scy, reachable_vec=r_train)
print("sample_w_broad stats:", sample_w_broad.min(), sample_w_broad.mean(), sample_w_broad.max())
# Out:
# sample_w_broad stats: 0.5998079855302864 1.0 3.596074989182777

# %% [markdown]
# ## The ANN Model Initialization

# %%
ball_predictor = tf.keras.models.Sequential()

# %% [markdown]
# ### Constructing the Model

# %%
ball_predictor.add(tf.keras.layers.Dense(units=23, activation='relu')) # 23 input features (6 points + 5 dt)
ball_predictor.add(tf.keras.layers.Dense(units=32, activation='relu')) # hiddel layer 1
ball_predictor.add(tf.keras.layers.Dense(units=64, activation='relu')) # hidden layer 2
ball_predictor.add(tf.keras.layers.Dense(units=32, activation='relu')) # hiddel layer 3
ball_predictor.add(tf.keras.layers.Dense(units=7, activation='linear')) # 7

# %%
ball_predictor.compile(
    loss=weighted_mse,
    optimizer='adam',
    metrics=['mean_squared_error']
)

# %% [markdown]
# ### Training

# %%
p1 = ball_predictor.fit(
    x_train,
    y_train,
    sample_weight=sample_w_broad,
    validation_split=0.2,
    batch_size=32,
    epochs=60,
    verbose=1,
)
# Out:
# Epoch 1/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.7509 - mean_squared_error: 0.7003 - val_loss: 0.5435 - val_mean_squared_error: 0.5369
# Epoch 2/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3843 - mean_squared_error: 0.4136 - val_loss: 0.2712 - val_mean_squared_error: 0.3278
# Epoch 3/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2279 - mean_squared_error: 0.2891 - val_loss: 0.1892 - val_mean_squared_error: 0.2528
# Epoch 4/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1751 - mean_squared_error: 0.2348 - val_loss: 0.1454 - val_mean_squared_error: 0.2035
# Epoch 5/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1388 - mean_squared_error: 0.1943 - val_loss: 0.1183 - val_mean_squared_error: 0.1758
# Epoch 6/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1156 - mean_squared_error: 0.1699 - val_loss: 0.1022 - val_mean_squared_error: 0.1567
# Epoch 7/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0986 - mean_squared_error: 0.1544 - val_loss: 0.0893 - val_mean_squared_error: 0.1457
# Epoch 8/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0889 - mean_squared_error: 0.1447 - val_loss: 0.0785 - val_mean_squared_error: 0.1356
# Epoch 9/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0808 - mean_squared_error: 0.1370 - val_loss: 0.0846 - val_mean_squared_error: 0.1388
# Epoch 10/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0751 - mean_squared_error: 0.1318 - val_loss: 0.0731 - val_mean_squared_error: 0.1290
# Epoch 11/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0716 - mean_squared_error: 0.1272 - val_loss: 0.0646 - val_mean_squared_error: 0.1209
# Epoch 12/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0674 - mean_squared_error: 0.1229 - val_loss: 0.0732 - val_mean_squared_error: 0.1255
# Epoch 13/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0653 - mean_squared_error: 0.1202 - val_loss: 0.0643 - val_mean_squared_error: 0.1187
# Epoch 14/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0622 - mean_squared_error: 0.1169 - val_loss: 0.0615 - val_mean_squared_error: 0.1164
# Epoch 15/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0602 - mean_squared_error: 0.1139 - val_loss: 0.0546 - val_mean_squared_error: 0.1090
# Epoch 16/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0579 - mean_squared_error: 0.1108 - val_loss: 0.0639 - val_mean_squared_error: 0.1147
# Epoch 17/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0567 - mean_squared_error: 0.1088 - val_loss: 0.0570 - val_mean_squared_error: 0.1088
# Epoch 18/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0542 - mean_squared_error: 0.1059 - val_loss: 0.0501 - val_mean_squared_error: 0.1022
# Epoch 19/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0531 - mean_squared_error: 0.1039 - val_loss: 0.0521 - val_mean_squared_error: 0.1022
# Epoch 20/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0508 - mean_squared_error: 0.1008 - val_loss: 0.0481 - val_mean_squared_error: 0.0990
# Epoch 21/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0494 - mean_squared_error: 0.0989 - val_loss: 0.0451 - val_mean_squared_error: 0.0960
# Epoch 22/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0486 - mean_squared_error: 0.0968 - val_loss: 0.0457 - val_mean_squared_error: 0.0949
# Epoch 23/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0469 - mean_squared_error: 0.0941 - val_loss: 0.0440 - val_mean_squared_error: 0.0920
# Epoch 24/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0454 - mean_squared_error: 0.0915 - val_loss: 0.0443 - val_mean_squared_error: 0.0904
# Epoch 25/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0443 - mean_squared_error: 0.0894 - val_loss: 0.0410 - val_mean_squared_error: 0.0870
# Epoch 26/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0433 - mean_squared_error: 0.0869 - val_loss: 0.0439 - val_mean_squared_error: 0.0872
# Epoch 27/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0412 - mean_squared_error: 0.0842 - val_loss: 0.0403 - val_mean_squared_error: 0.0842
# Epoch 28/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0399 - mean_squared_error: 0.0813 - val_loss: 0.0383 - val_mean_squared_error: 0.0812
# Epoch 29/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0394 - mean_squared_error: 0.0798 - val_loss: 0.0357 - val_mean_squared_error: 0.0784
# Epoch 30/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0388 - mean_squared_error: 0.0784 - val_loss: 0.0351 - val_mean_squared_error: 0.0743
# Epoch 31/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0375 - mean_squared_error: 0.0759 - val_loss: 0.0346 - val_mean_squared_error: 0.0739
# Epoch 32/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0374 - mean_squared_error: 0.0745 - val_loss: 0.0336 - val_mean_squared_error: 0.0717
# Epoch 33/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0362 - mean_squared_error: 0.0727 - val_loss: 0.0359 - val_mean_squared_error: 0.0719
# Epoch 34/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0341 - mean_squared_error: 0.0699 - val_loss: 0.0363 - val_mean_squared_error: 0.0714
# Epoch 35/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0346 - mean_squared_error: 0.0691 - val_loss: 0.0357 - val_mean_squared_error: 0.0702
# Epoch 36/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0346 - mean_squared_error: 0.0679 - val_loss: 0.0369 - val_mean_squared_error: 0.0718
# Epoch 37/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0330 - mean_squared_error: 0.0662 - val_loss: 0.0305 - val_mean_squared_error: 0.0653
# Epoch 38/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0327 - mean_squared_error: 0.0653 - val_loss: 0.0357 - val_mean_squared_error: 0.0676
# Epoch 39/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0323 - mean_squared_error: 0.0641 - val_loss: 0.0338 - val_mean_squared_error: 0.0650
# Epoch 40/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0315 - mean_squared_error: 0.0626 - val_loss: 0.0327 - val_mean_squared_error: 0.0622
# Epoch 41/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0310 - mean_squared_error: 0.0616 - val_loss: 0.0340 - val_mean_squared_error: 0.0629
# Epoch 42/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0310 - mean_squared_error: 0.0608 - val_loss: 0.0313 - val_mean_squared_error: 0.0633
# Epoch 43/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0303 - mean_squared_error: 0.0592 - val_loss: 0.0321 - val_mean_squared_error: 0.0611
# Epoch 44/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0300 - mean_squared_error: 0.0583 - val_loss: 0.0326 - val_mean_squared_error: 0.0617
# Epoch 45/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0300 - mean_squared_error: 0.0580 - val_loss: 0.0293 - val_mean_squared_error: 0.0575
# Epoch 46/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0292 - mean_squared_error: 0.0566 - val_loss: 0.0297 - val_mean_squared_error: 0.0565
# Epoch 47/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0291 - mean_squared_error: 0.0558 - val_loss: 0.0302 - val_mean_squared_error: 0.0578
# Epoch 48/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0290 - mean_squared_error: 0.0554 - val_loss: 0.0316 - val_mean_squared_error: 0.0584
# Epoch 49/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0281 - mean_squared_error: 0.0540 - val_loss: 0.0281 - val_mean_squared_error: 0.0543
# Epoch 50/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0277 - mean_squared_error: 0.0532 - val_loss: 0.0252 - val_mean_squared_error: 0.0507
# Epoch 51/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0281 - mean_squared_error: 0.0531 - val_loss: 0.0310 - val_mean_squared_error: 0.0568
# Epoch 52/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0281 - mean_squared_error: 0.0523 - val_loss: 0.0276 - val_mean_squared_error: 0.0513
# Epoch 53/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0274 - mean_squared_error: 0.0515 - val_loss: 0.0272 - val_mean_squared_error: 0.0533
# Epoch 54/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0271 - mean_squared_error: 0.0510 - val_loss: 0.0270 - val_mean_squared_error: 0.0530
# Epoch 55/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0259 - mean_squared_error: 0.0487 - val_loss: 0.0256 - val_mean_squared_error: 0.0492
# Epoch 56/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0260 - mean_squared_error: 0.0487 - val_loss: 0.0318 - val_mean_squared_error: 0.0532
# Epoch 57/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0262 - mean_squared_error: 0.0480 - val_loss: 0.0236 - val_mean_squared_error: 0.0459
# Epoch 58/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0261 - mean_squared_error: 0.0476 - val_loss: 0.0272 - val_mean_squared_error: 0.0498
# Epoch 59/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0251 - mean_squared_error: 0.0467 - val_loss: 0.0270 - val_mean_squared_error: 0.0479
# Epoch 60/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0242 - mean_squared_error: 0.0453 - val_loss: 0.0238 - val_mean_squared_error: 0.0450

# %% [markdown]
# ### Learning Curves

# %%
fig, axs = plt.subplots(figsize=(16,5))
fig.suptitle('Loss Function')

axs.plot(p1.history['loss'])
axs.plot(p1.history['val_loss'])
axs.set_title("Ball Prediction Learning Curves")
axs.set(xlabel='Epoch', ylabel='Loss')

fig.legend(labels=['Train', 'Validation'], loc="upper left")
plt.show()

# %%
# def eval_regression(name, y_true, y_pred):
#     mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')
#     rmse = np.sqrt(mean_squared_error(y_true, y_pred, multioutput='raw_values'))
#     print(f"\n{name}")
#     print("MAE per output:", mae)
#     print("RMSE per output:", rmse)

# # If y is scaled, inverse-transform both y_true and y_pred before metrics.
# y_pred_all = ball_predictor.predict(x_test_all)
# y_pred_reach = ball_predictor.predict(x_test_reach)

# # Example for scaled targets:
# # y_pred_all = scy.inverse_transform(y_pred_all); y_test_all_eval = scy.inverse_transform(y_test_all)
# # y_pred_reach = scy.inverse_transform(y_pred_reach); y_test_reach_eval = scy.inverse_transform(y_test_reach)

# eval_regression("All test shots", y_test_all, y_pred_all)
# eval_regression("Reachable-only test shots", y_test_reach, y_pred_reach)

import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error

target_names = ["x_hit", "y_hit", "z_hit", "vx_hit", "vy_hit", "vz_hit", "t_hit"]
target_units = ["mm", "mm", "mm", "mm/s", "mm/s", "mm/s", "ms"]

def eval_with_units(name, model, x_eval, y_eval, y_scaler, y_is_scaled=True, t_hit_in_seconds=True):
    y_pred = model.predict(x_eval, verbose=0)

    # Convert to physical units exactly once
    if y_is_scaled:
        assert y_eval.shape[1] == y_scaler.n_features_in_ == len(target_names)
        y_true_u = y_scaler.inverse_transform(y_eval)
        y_pred_u = y_scaler.inverse_transform(y_pred)
    else:
        y_true_u = y_eval
        y_pred_u = y_pred

    err = y_pred_u - y_true_u
    abs_err = np.abs(err)

    mae = mean_absolute_error(y_true_u, y_pred_u, multioutput="raw_values")
    rmse = np.sqrt(mean_squared_error(y_true_u, y_pred_u, multioutput="raw_values"))
    std_abs = abs_err.std(axis=0)

    # Convert t_hit to ms for reporting (only if stored in seconds)
    if t_hit_in_seconds:
        i = target_names.index("t_hit")
        mae[i] *= 1000.0
        rmse[i] *= 1000.0
        std_abs[i] *= 1000.0

    report = pd.DataFrame({
        "target": target_names,
        "unit": target_units,
        "MAE": mae,
        "RMSE": rmse,
        "STD_abs_error": std_abs,
    })

    print(f"\n{name}")
    print(report.to_string(index=False, float_format=lambda v: f"{v:,.3f}"))

# Run both:
eval_with_units("All test shots", ball_predictor, x_test_all, y_test_all, scy, y_is_scaled=True, t_hit_in_seconds=True)
eval_with_units("Reachable-only test shots", ball_predictor, x_test_reach, y_test_reach, scy, y_is_scaled=True, t_hit_in_seconds=True)
# Out:
# All test shots
# target unit     MAE    RMSE  STD_abs_error
#  x_hit   mm  49.806  67.074         44.926
#  y_hit   mm  59.796  91.202         68.863
#  z_hit   mm  41.621  57.721         39.993
# vx_hit mm/s 178.618 232.763        149.245
# vy_hit mm/s 190.183 247.439        158.293
# vz_hit mm/s 590.723 948.703        742.351
#  t_hit   ms  27.458  40.578         29.876
#
# Reachable-only test shots
# target unit     MAE      RMSE  STD_abs_error
#  x_hit   mm  47.847    62.374         40.016
#  y_hit   mm  76.336   113.439         83.911
#  z_hit   mm  36.633    49.244         32.909
# vx_hit mm/s 172.690   221.018        137.938
# vy_hit mm/s 198.632   251.836        154.811
# vz_hit mm/s 667.556 1,033.814        789.393
#  t_hit   ms  24.475    33.850         23.384

# %%
# Verification 
train_std = scy.scale_ 
rmse_sigma = np.sqrt(0.1084)   # val_mse from curve, e.g. 0.1151
rmse_units = rmse_sigma * train_std

print(rmse_units)
# Out:
# [2.46173362e+02 1.74235303e+02 1.17654887e+02 6.77165753e+02
#  6.11690846e+02 7.15093293e+02 9.30324965e-02]

# %% [markdown]
# ## Loading the Matched Synthetic Dataset (Transfer Learning)

# %%
matched_dataset = pd.read_csv('../learning_data/synthetic_matched_data/synthetic_intercept_dataset.csv')
matched_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 41 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   x1                     10000 non-null  float64
#  1   y1                     10000 non-null  float64
#  2   z1                     10000 non-null  float64
#  3   x2                     10000 non-null  float64
#  4   y2                     10000 non-null  float64
#  5   z2                     10000 non-null  float64
#  6   x3                     10000 non-null  float64
#  7   y3                     10000 non-null  float64
#  8   z3                     10000 non-null  float64
#  9   x4                     10000 non-null  float64
#  10  y4                     10000 non-null  float64
#  11  z4                     10000 non-null  float64
#  12  x5                     10000 non-null  float64
#  13  y5                     10000 non-null  float64
#  14  z5                     10000 non-null  float64
#  15  x6                     10000 non-null  float64
#  16  y6                     10000 non-null  float64
#  17  z6                     10000 non-null  float64
#  18  dt12                   10000 non-null  float64
#  19  dt23                   10000 non-null  float64
#  20  dt34                   10000 non-null  float64
#  21  dt45                   10000 non-null  float64
#  22  dt56                   10000 non-null  float64
#  23  x_hit                  10000 non-null  float64
#  24  y_hit                  10000 non-null  float64
#  25  z_hit                  10000 non-null  float64
#  26  vx_hit                 10000 non-null  float64
#  27  vy_hit                 10000 non-null  float64
#  28  vz_hit                 10000 non-null  float64
#  29  t_hit                  10000 non-null  float64
#  30  is_reachable           10000 non-null  float64
#  31  bounces_before_hit     10000 non-null  float64
#  32  has_bounce_before_hit  10000 non-null  float64
#  33  intercept_valid        10000 non-null  float64
#  34  x0                     10000 non-null  float64
#  35  y0                     10000 non-null  float64
#  36  z0                     10000 non-null  float64
#  37  vx0                    10000 non-null  float64
#  38  vy0                    10000 non-null  float64
#  39  vz0                    10000 non-null  float64
#  40  gravity_z_mm_s2        10000 non-null  float64
# dtypes: float64(41)
# memory usage: 3.1 MB

# %%
input_cols_6 = [
    "x1", "y1", "z1",
    "x2", "y2", "z2",
    "x3", "y3", "z3",
    "x4", "y4", "z4",
    "x5", "y5", "z5",
    "x6", "y6", "z6",
    "dt12", "dt23", "dt34", "dt45", "dt56",
]
target_cols = ["x_hit", "y_hit", "z_hit", "vx_hit", "vy_hit", "vz_hit", "t_hit"]

x_matched = matched_dataset[input_cols_6]
y_matched = matched_dataset[target_cols]
r_matched = matched_dataset["is_reachable"].to_numpy().astype(int)

# View the inputs
print(x_matched)
print(y_matched)

x_matched = x_matched.values
y_matched = y_matched.values
# Out:
#               x1           y1           z1          x2           y2  \
# 0      89.384098  2497.130664  -507.592687   88.530663  2470.751062
# 1     -25.181972  2465.962700  -591.888417  -23.676343  2437.120467
# 2      26.115563  2425.404595  -794.090581   16.715099  2399.819544
# 3    -278.851328  2408.352866  -379.653193 -270.862368  2362.167014
# 4    -282.926270  2417.636907  -404.155517 -278.312044  2395.463430
# ...          ...          ...          ...         ...          ...
# 9995   35.808687  2441.757114  -793.605519   25.008045  2391.264699
# 9996 -436.476024  2431.436673  -562.554997 -431.358869  2391.018892
# 9997 -209.032818  2493.414134  -483.535914 -197.653580  2454.246241
# 9998  244.304104  2395.044847  -764.802932  254.788196  2367.043198
# 9999 -286.839773  2444.128254 -1044.094322 -266.168965  2390.783190
#
#                z2          x3           y3           z3          x4  ...  \
# 0     -551.027299   89.996010  2446.577520  -594.742439   96.775159  ...
# 1     -638.291218  -19.396442  2402.919275  -687.980946  -17.371511  ...
# 2     -818.823058   17.328725  2368.312015  -851.236084    5.468941  ...
# 3     -410.082430 -257.554933  2327.122630  -427.273462 -243.477747  ...
# 4     -441.443220 -273.627080  2356.258959  -486.854067 -270.254834  ...
# ...           ...         ...          ...          ...         ...  ...
# 9995  -826.768283    9.963445  2336.211144  -859.639461   -4.952566  ...
# 9996  -604.533822 -435.403618  2362.847386  -638.952357 -428.301614  ...
# 9997  -515.314987 -185.409958  2415.175178  -552.940962 -177.191446  ...
# 9998  -825.548982  261.633321  2327.987574  -907.816658  253.678342  ...
# 9999 -1096.995140 -248.755224  2357.776442 -1146.632933 -236.585415  ...
#
#                y5           z5          x6           y6           z6  \
# 0     2384.831565  -698.657941  103.815894  2348.815982  -759.498497
# 1     2327.506709  -800.421206   -8.454309  2297.115015  -854.530016
# 2     2303.334731  -911.896766   -8.443324  2270.045133  -948.544929
# 3     2245.490051  -482.283735 -219.099622  2201.005773  -518.736550
# 4     2300.205779  -573.851006 -251.491470  2272.839402  -619.718635
# ...           ...          ...         ...          ...          ...
# 9995  2233.395261  -942.552564  -30.513492  2169.931311  -987.806157
# 9996  2293.180107  -727.659240 -422.581499  2260.027720  -761.621879
# 9997  2345.377332  -630.258666 -153.894402  2306.465030  -664.293924
# 9998  2269.015842 -1041.628828  269.747407  2236.278008 -1105.169022
# 9999  2267.140071 -1064.087670 -202.740866  2228.583131 -1016.376902
#
#           dt12      dt23      dt34      dt45      dt56
# 0     0.013960  0.012557  0.014382  0.016048  0.016223
# 1     0.013602  0.017818  0.018428  0.012885  0.015542
# 2     0.017580  0.016595  0.019460  0.014183  0.017974
# 3     0.018541  0.016670  0.017204  0.017166  0.018096
# 4     0.014767  0.015059  0.016952  0.015091  0.014413
# ...        ...       ...       ...       ...       ...
# 9995  0.014753  0.015395  0.015499  0.018464  0.018907
# 9996  0.018606  0.015177  0.015437  0.014949  0.014976
# 9997  0.015572  0.018956  0.014428  0.017552  0.014241
# 9998  0.012600  0.018158  0.017036  0.014960  0.012863
# 9999  0.017108  0.015370  0.012961  0.016576  0.015214
#
# [10000 rows x 23 columns]
#            x_hit       y_hit       z_hit       vx_hit       vy_hit  \
# 0     356.762790  143.645618 -837.941293   226.185097 -1970.756455
# 1     116.129080  -43.408255 -928.791837   127.422054 -2253.671295
# 2    -399.702382   71.464229 -903.556652  -330.698477 -1841.699577
# 3     376.744333    0.508919 -828.547129   634.868758 -2340.316106
# 4     198.526255  121.305664 -864.608767   404.808038 -1921.915425
# ...          ...         ...         ...          ...          ...
# 9995 -542.699108   98.356311 -828.509093  -817.686725 -3299.003160
# 9996 -346.738684   35.618515 -874.054726    81.020172 -2199.704209
# 9997  526.126318  224.192073 -932.420421   733.415967 -2262.901557
# 9998  505.442251   78.208079 -897.301765   218.117482 -2004.380403
# 9999  575.820518  231.222909 -892.237615  1106.478539 -2842.974472
#
#            vz_hit     t_hit
# 0     3930.273408  1.121830
# 1     3926.714735  1.036725
# 2    -1945.023027  1.194208
# 3    -3148.869856  0.942323
# 4     3878.502311  1.118718
# ...           ...       ...
# 9995 -2191.348089  0.626982
# 9996  3249.301369  1.010855
# 9997 -3539.881504  0.919251
# 9998  4413.233788  1.079383
# 9999  2283.306338  0.702770
#
# [10000 rows x 7 columns]

# %%
#Split input and output x, y
x_matched_train, x_matched_test, y_matched_train, y_matched_test, r_matched_train, r_matched_test = train_test_split(
    x_matched, y_matched, r_matched,
    test_size=0.1,
    random_state=6,
    stratify=r_matched
)

# %%
print(x_matched_train.shape)
print(x_matched_test.shape)
print(y_matched_train.shape)
print(y_matched_test.shape)

x_matched_train_s = scx.transform(x_matched_train)
x_matched_test_s = scx.transform(x_matched_test)
y_matched_train_s = scy.transform(y_matched_train)
y_matched_test_s = scy.transform(y_matched_test)

sample_w_matched = build_sample_weights(y_matched_train_s, scy, reachable_vec=r_matched_train)
print("sample_w_matched stats:", sample_w_matched.min(), sample_w_matched.mean(), sample_w_matched.max())
# Out:
# (9000, 23)
# (1000, 23)
# (9000, 7)
# (1000, 7)
# sample_w_matched stats: 0.5556570908399867 1.0000000000000002 1.6172154227707274

# %%
import tensorflow as tf
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam

# Try 1e-5 first; then tune [1e-6, 1e-5, 5e-5]
L2_LAMBDA = 5e-5

dense_total = sum(isinstance(l, tf.keras.layers.Dense) for l in ball_predictor.layers)
dense_seen = {"n": 0}

def clone_with_l2(layer):
    cfg = layer.get_config()
    if isinstance(layer, tf.keras.layers.Dense):
        dense_seen["n"] += 1
        is_output_layer = (dense_seen["n"] == dense_total)
        if not is_output_layer:  # regularize hidden layers only
            cfg["kernel_regularizer"] = regularizers.serialize(regularizers.l2(L2_LAMBDA))
    return layer.__class__.from_config(cfg)

# Start from broad pretrained model, but with L2 regularization added
transfer_model_matched = tf.keras.models.clone_model(
    ball_predictor,
    clone_function=clone_with_l2
)
transfer_model_matched.set_weights(ball_predictor.get_weights())

# Matched stage: unfreeze all layers, train with low LR
for layer in transfer_model_matched.layers:
    layer.trainable = True

transfer_model_matched.compile(
    loss=weighted_mse,
    optimizer=Adam(learning_rate=1e-4),
    metrics=["mean_squared_error"]
)

history_matched = transfer_model_matched.fit(
    x_matched_train_s, y_matched_train_s,
    sample_weight=sample_w_matched,
    validation_split=0.2,
    epochs=40,
    verbose=1
)
# Out:
# Epoch 1/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0505 - mean_squared_error: 0.1447 - val_loss: 0.0469 - val_mean_squared_error: 0.1347
# Epoch 2/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0459 - mean_squared_error: 0.1331 - val_loss: 0.0447 - val_mean_squared_error: 0.1298
# Epoch 3/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0439 - mean_squared_error: 0.1274 - val_loss: 0.0436 - val_mean_squared_error: 0.1262
# Epoch 4/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0427 - mean_squared_error: 0.1242 - val_loss: 0.0423 - val_mean_squared_error: 0.1243
# Epoch 5/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0417 - mean_squared_error: 0.1216 - val_loss: 0.0417 - val_mean_squared_error: 0.1234
# Epoch 6/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0409 - mean_squared_error: 0.1198 - val_loss: 0.0407 - val_mean_squared_error: 0.1202
# Epoch 7/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0401 - mean_squared_error: 0.1179 - val_loss: 0.0400 - val_mean_squared_error: 0.1186
# Epoch 8/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0393 - mean_squared_error: 0.1160 - val_loss: 0.0398 - val_mean_squared_error: 0.1189
# Epoch 9/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0387 - mean_squared_error: 0.1147 - val_loss: 0.0387 - val_mean_squared_error: 0.1166
# Epoch 10/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0383 - mean_squared_error: 0.1143 - val_loss: 0.0384 - val_mean_squared_error: 0.1161
# Epoch 11/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0377 - mean_squared_error: 0.1130 - val_loss: 0.0380 - val_mean_squared_error: 0.1158
# Epoch 12/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0373 - mean_squared_error: 0.1127 - val_loss: 0.0376 - val_mean_squared_error: 0.1145
# Epoch 13/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0369 - mean_squared_error: 0.1123 - val_loss: 0.0374 - val_mean_squared_error: 0.1149
# Epoch 14/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0365 - mean_squared_error: 0.1112 - val_loss: 0.0369 - val_mean_squared_error: 0.1136
# Epoch 15/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0362 - mean_squared_error: 0.1109 - val_loss: 0.0367 - val_mean_squared_error: 0.1151
# Epoch 16/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0360 - mean_squared_error: 0.1110 - val_loss: 0.0367 - val_mean_squared_error: 0.1158
# Epoch 17/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0357 - mean_squared_error: 0.1101 - val_loss: 0.0363 - val_mean_squared_error: 0.1135
# Epoch 18/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0354 - mean_squared_error: 0.1099 - val_loss: 0.0361 - val_mean_squared_error: 0.1148
# Epoch 19/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0354 - mean_squared_error: 0.1099 - val_loss: 0.0360 - val_mean_squared_error: 0.1151
# Epoch 20/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0350 - mean_squared_error: 0.1092 - val_loss: 0.0356 - val_mean_squared_error: 0.1129
# Epoch 21/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0348 - mean_squared_error: 0.1095 - val_loss: 0.0357 - val_mean_squared_error: 0.1147
# Epoch 22/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0346 - mean_squared_error: 0.1093 - val_loss: 0.0353 - val_mean_squared_error: 0.1133
# Epoch 23/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0344 - mean_squared_error: 0.1089 - val_loss: 0.0353 - val_mean_squared_error: 0.1148
# Epoch 24/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0343 - mean_squared_error: 0.1084 - val_loss: 0.0348 - val_mean_squared_error: 0.1128
# Epoch 25/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0340 - mean_squared_error: 0.1082 - val_loss: 0.0348 - val_mean_squared_error: 0.1128
# Epoch 26/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0339 - mean_squared_error: 0.1079 - val_loss: 0.0348 - val_mean_squared_error: 0.1133
# Epoch 27/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0337 - mean_squared_error: 0.1076 - val_loss: 0.0347 - val_mean_squared_error: 0.1144
# Epoch 28/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0336 - mean_squared_error: 0.1076 - val_loss: 0.0346 - val_mean_squared_error: 0.1143
# Epoch 29/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0334 - mean_squared_error: 0.1069 - val_loss: 0.0342 - val_mean_squared_error: 0.1127
# Epoch 30/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0334 - mean_squared_error: 0.1076 - val_loss: 0.0341 - val_mean_squared_error: 0.1115
# Epoch 31/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0331 - mean_squared_error: 0.1064 - val_loss: 0.0342 - val_mean_squared_error: 0.1128
# Epoch 32/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0329 - mean_squared_error: 0.1062 - val_loss: 0.0342 - val_mean_squared_error: 0.1134
# Epoch 33/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0329 - mean_squared_error: 0.1061 - val_loss: 0.0336 - val_mean_squared_error: 0.1112
# Epoch 34/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0329 - mean_squared_error: 0.1071 - val_loss: 0.0341 - val_mean_squared_error: 0.1140
# Epoch 35/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0327 - mean_squared_error: 0.1063 - val_loss: 0.0333 - val_mean_squared_error: 0.1104
# Epoch 36/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0324 - mean_squared_error: 0.1054 - val_loss: 0.0335 - val_mean_squared_error: 0.1121
# Epoch 37/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0324 - mean_squared_error: 0.1054 - val_loss: 0.0337 - val_mean_squared_error: 0.1133
# Epoch 38/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0324 - mean_squared_error: 0.1059 - val_loss: 0.0335 - val_mean_squared_error: 0.1121
# Epoch 39/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0323 - mean_squared_error: 0.1055 - val_loss: 0.0332 - val_mean_squared_error: 0.1111
# Epoch 40/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0321 - mean_squared_error: 0.1050 - val_loss: 0.0338 - val_mean_squared_error: 0.1161

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12,4))
ax.plot(history_matched.history["loss"], label="Train")
ax.plot(history_matched.history["val_loss"], label="Validation")
ax.set_title("Matched Synthetic Data Learning Curves")
ax.set_xlabel("Epoch")
ax.set_ylabel("Loss")
ax.legend()
plt.show()

# %%
eval_with_units(
    "Matched Data Transfer Model",
    transfer_model_matched,
    x_matched_test_s,
    y_matched_test_s,
    scy,
    y_is_scaled=True,
    t_hit_in_seconds=True
)
# Out:
# Matched Data Transfer Model
# target unit       MAE      RMSE  STD_abs_error
#  x_hit   mm    40.576    50.884         30.704
#  y_hit   mm    44.797    58.118         37.025
#  z_hit   mm    27.773    35.920         22.779
# vx_hit mm/s    76.784    97.508         60.100
# vy_hit mm/s    71.355    89.397         53.854
# vz_hit mm/s 1,106.243 1,861.532      1,497.173
#  t_hit   ms    24.609    32.021         20.487

# %% [markdown]
# ## Loading the Real Dataset (Transfer Learning)

# %%
real_dataset = pd.read_csv('../learning_data/real_data/real_transfer_predictor_verified_clean.csv')
real_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 35 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   sample_id           102 non-null    int64
#  1   captured_at         102 non-null    object
#  2   x1                  102 non-null    float64
#  3   y1                  102 non-null    float64
#  4   z1                  102 non-null    float64
#  5   x2                  102 non-null    float64
#  6   y2                  102 non-null    float64
#  7   z2                  102 non-null    float64
#  8   x3                  102 non-null    float64
#  9   y3                  102 non-null    float64
#  10  z3                  102 non-null    float64
#  11  x4                  102 non-null    float64
#  12  y4                  102 non-null    float64
#  13  z4                  102 non-null    float64
#  14  x5                  102 non-null    float64
#  15  y5                  102 non-null    float64
#  16  z5                  102 non-null    float64
#  17  x6                  102 non-null    float64
#  18  y6                  102 non-null    float64
#  19  z6                  102 non-null    float64
#  20  dt12                102 non-null    float64
#  21  dt23                102 non-null    float64
#  22  dt34                102 non-null    float64
#  23  dt45                102 non-null    float64
#  24  dt56                102 non-null    float64
#  25  x_hit               102 non-null    float64
#  26  y_hit               102 non-null    float64
#  27  z_hit               102 non-null    float64
#  28  vx_hit              102 non-null    float64
#  29  vy_hit              102 non-null    float64
#  30  vz_hit              102 non-null    float64
#  31  t_hit               102 non-null    float64
#  32  is_reachable        102 non-null    int64
#  33  intercept_valid     102 non-null    int64
#  34  bounces_before_hit  102 non-null    int64
# dtypes: float64(30), int64(4), object(1)
# memory usage: 28.0+ KB

# %%
real_dataset.describe()
# Out:
#         sample_id          x1           y1           z1          x2  \
# count  102.000000  102.000000   102.000000   102.000000  102.000000
# mean    55.186275  113.445545  2481.107347  -735.691062  116.269819
# std     30.674184  319.085833   121.208627   224.743203  312.382678
# min      1.000000 -424.139309  1376.753747 -1088.880989 -400.960797
# 25%     30.250000 -185.539421  2465.033403  -917.677502 -159.252234
# 50%     55.500000  121.963376  2492.248825  -806.129483  133.435652
# 75%     80.750000  355.598998  2521.889374  -558.255463  359.352332
# max    107.000000  778.574600  2578.329790  -202.463462  767.789459
#
#                 y2           z2          x3           y3           z3  ...  \
# count   102.000000   102.000000  102.000000   102.000000   102.000000  ...
# mean   2413.973788  -756.405619  115.244868  2347.193116  -777.832314  ...
# std     116.942937   242.468372  305.158921   112.075331   259.165467  ...
# min    1349.684935 -1108.415713 -396.451038  1330.610550 -1114.560918  ...
# 25%    2398.240459  -953.255903 -152.810850  2332.178875 -1000.198216  ...
# 50%    2425.629614  -845.678118  128.282817  2361.734204  -872.024670  ...
# 75%    2454.973839  -548.212031  355.157908  2384.958005  -543.971916  ...
# max    2521.317811  -224.895161  756.187685  2464.327618  -236.286537  ...
#
#             x_hit       y_hit        z_hit      vx_hit       vy_hit  \
# count  102.000000  102.000000   102.000000  102.000000   102.000000
# mean    45.803787    8.496171  -856.813536  -55.186871 -1939.008776
# std    297.137013  131.877543    57.766482  314.890082   342.237235
# min   -612.197110 -385.745273 -1017.808779 -875.828997 -3125.673335
# 25%   -210.574879  -61.188492  -884.951474 -152.021290 -2137.911071
# 50%    117.355166    5.861416  -844.951417  -17.123231 -1906.432176
# 75%    272.615927   74.683613  -804.628420   91.245513 -1698.928112
# max    619.598548  280.947165  -800.079216  661.044003 -1142.194414
#
#             vz_hit       t_hit  is_reachable  intercept_valid  \
# count   102.000000  102.000000         102.0            102.0
# mean   -561.778747    0.832062           1.0              1.0
# std    1316.196233    0.142155           0.0              0.0
# min   -2403.803700    0.481092           1.0              1.0
# 25%   -1522.401428    0.735493           1.0              1.0
# 50%   -1023.955444    0.810567           1.0              1.0
# 75%     779.190902    0.920944           1.0              1.0
# max    2314.541399    1.264158           1.0              1.0
#
#        bounces_before_hit
# count          102.000000
# mean             0.441176
# std              0.498980
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              1.000000
# max              1.000000
#
# [8 rows x 34 columns]

# %% [markdown]
# ### Pre-Processing the Real Dataset

# %%
input_cols_6 = [
    "x1", "y1", "z1",
    "x2", "y2", "z2",
    "x3", "y3", "z3",
    "x4", "y4", "z4",
    "x5", "y5", "z5",
    "x6", "y6", "z6",
    "dt12", "dt23", "dt34", "dt45", "dt56",
]
target_cols = ["x_hit", "y_hit", "z_hit", "vx_hit", "vy_hit", "vz_hit", "t_hit"]

x_real = real_dataset[input_cols_6]
y_real = real_dataset[target_cols]

# %%
# View the inputs
print(x_real)
# Out:
#              x1           y1           z1          x2           y2  \
# 0     17.057403  2488.654688 -1059.231099   13.965808  2401.042538
# 1   -371.660861  2562.756415  -902.337499 -363.831118  2492.365082
# 2    348.988339  2530.440019 -1019.428264  346.543998  2455.846440
# 3   -339.351594  2578.329790 -1088.880989 -338.167709  2521.317811
# 4    606.993396  2514.340931  -959.900229  617.580909  2462.769555
# ..          ...          ...          ...         ...          ...
# 97   347.393442  2513.380763  -837.735261  359.388014  2444.685893
# 98   147.748628  2540.914774  -948.471107  166.410486  2473.010504
# 99   778.574600  2413.757989  -475.275458  767.789459  2361.251185
# 100  503.323972  2356.436827  -229.299041  500.385245  2302.072589
# 101 -113.447210  2470.912318  -314.627031 -111.778994  2407.764608
#
#               z2          x3           y3           z3          x4  ...  \
# 0   -1108.415713   16.430451  2332.622645 -1080.383280   11.984324  ...
# 1    -953.382562 -314.496283  2417.829851  -997.806090 -295.714865  ...
# 2   -1071.237333  348.878118  2385.145970 -1092.443740  344.902333  ...
# 3   -1034.171136 -329.726779  2464.327618  -976.717411 -341.085918  ...
# 4    -911.330375  611.770870  2402.576022  -875.028672  606.222648  ...
# ..           ...         ...          ...          ...         ...  ...
# 97   -864.059240  356.800646  2371.684263  -898.180402  351.442953  ...
# 98   -984.765348  167.695295  2400.717425 -1028.805692  170.928512  ...
# 99   -460.375834  756.187685  2307.324449  -447.744294  746.231729  ...
# 100  -231.328503  498.867205  2249.746557  -236.286537  500.240598  ...
# 101  -307.174227 -112.635163  2346.454455  -302.719888 -112.868900  ...
#
#               y5           z5          x6           y6           z6      dt12  \
# 0    2201.788645  -999.708288   10.580371  2135.468471  -966.185374  0.018373
# 1    2274.321481 -1100.197176 -246.669636  2216.134508 -1093.540337  0.015758
# 2    2269.886091 -1005.033675  336.257722  2209.893987  -965.661926  0.015611
# 3    2356.015483  -879.103321 -319.651216  2301.813034  -831.678655  0.015701
# 4    2284.457106  -809.707353  592.207653  2225.360142  -784.310406  0.015752
# ..           ...          ...         ...          ...          ...       ...
# 97   2227.714525  -971.668071  346.516878  2156.037229 -1013.993556  0.018112
# 98   2262.469332 -1098.596537  169.906700  2207.887698 -1054.196239  0.010631
# 99   2203.206861  -429.895166  727.534187  2152.090080  -424.047217  0.017971
# 100  2145.801144  -260.055230  497.858201  2094.486581  -274.903497  0.017439
# 101  2225.148943  -300.934809 -109.770185  2166.431412  -303.421456  0.015897
#
#          dt23      dt34      dt45      dt56
# 0    0.012525  0.016053  0.017001  0.015989
# 1    0.012682  0.011663  0.014242  0.014976
# 2    0.013622  0.015760  0.017316  0.015082
# 3    0.016075  0.016934  0.013524  0.013979
# 4    0.016920  0.016279  0.018537  0.013502
# ..        ...       ...       ...       ...
# 97   0.015156  0.012023  0.010592  0.015268
# 98   0.014056  0.016513  0.016888  0.015076
# 99   0.017390  0.013912  0.016260  0.015325
# 100  0.018514  0.011893  0.011918  0.017370
# 101  0.015651  0.014198  0.017274  0.014645
#
# [102 rows x 23 columns]

# %%
# View the inputs
print(y_real)
# Out:
#           x_hit       y_hit       z_hit      vx_hit       vy_hit       vz_hit  \
# 0     -4.641024    4.358949 -871.436038  -24.221133 -2421.730067   704.516383
# 1    406.220234  113.632881 -806.213728  559.027545 -1784.209457  -239.937665
# 2    195.766794   30.848722 -801.231740 -136.388611 -2090.589103   414.346604
# 3   -233.764694  239.451476 -801.823987   79.766397 -1867.498690  1705.369142
# 4    323.498877  -64.604830 -828.768999 -248.830649 -2121.369813  -753.121741
# ..          ...         ...         ...         ...          ...          ...
# 97   193.839881  -19.301921 -885.549040 -137.302534 -1910.219734  -583.161809
# 98   127.766898  -11.573475 -890.456844  -33.863654 -1902.644618  -956.554854
# 99   296.566195  -85.472919 -877.207377 -345.538103 -1796.118893 -1963.216922
# 100  475.026525  -33.738712 -884.099688  -18.932829 -1723.216687 -2403.803700
# 101  -99.758850 -269.164879 -804.681175    9.105959 -1944.024326 -1897.377825
#
#         t_hit
# 0    0.646031
# 1    0.858384
# 2    0.760020
# 3    0.773699
# 4    0.796867
# ..        ...
# 97   0.832104
# 98   0.863174
# 99   0.919852
# 100  0.921355
# 101  0.916005
#
# [102 rows x 7 columns]

# %%
x_real = x_real.values
y_real = y_real.values

# %% [markdown]
# ### Splitting the Dataset into the Training set and Test set

# %%
#Split input and output x, y
x_real_train, x_real_test, y_real_train, y_real_test= train_test_split(
    x_real, y_real,
    test_size=0.2,
    random_state=12
    

)

# %%
print(x_real_train.shape)
print(x_real_test.shape)
print(y_real_train.shape)
print(y_real_test.shape)
# Out:
# (81, 23)
# (21, 23)
# (81, 7)
# (21, 7)

# %% [markdown]
# ### Scaling the real dataset

# %%
x_real_train_s = scx.transform(x_real_train)
x_real_test_s = scx.transform(x_real_test)
y_real_train_s = scy.transform(y_real_train)
y_real_test_s = scy.transform(y_real_test)

# Real dataset is mostly/all reachable in this collection; use center emphasis.
sample_w_real = build_sample_weights(
    y_real_train_s,
    scy,
    reachable_vec=np.ones(y_real_train_s.shape[0], dtype=int),
)
print("sample_w_real stats:", sample_w_real.min(), sample_w_real.mean(), sample_w_real.max())
# Out:
# sample_w_real stats: 0.5216041321351877 1.0000000000000002 1.4575224714080164

# %%
# ### WEighting the xyz more than velocities

# # Output order must match your y columns:
# # [x_hit, y_hit, z_hit, vx_hit, vy_hit, vz_hit, t_hit]
# raw_w = tf.constant([10.0, 10.0, 10.0, 1.0, 1.0, 1.0, 5.0], dtype=tf.float32)

# # normalize so average weight is ~1 (keeps loss scale stable)
# output_weights = raw_w / tf.reduce_mean(raw_w)

# def weighted_mse(y_true, y_pred):
#     err2 = tf.square(y_true - y_pred)              # (batch, 7)
#     weighted_err2 = err2 * output_weights          # broadcast on 7 outputs
#     return tf.reduce_mean(weighted_err2)

# %% [markdown]
# ## Training the New Layers (Classification Layers)

# %%
# Start from synthetic-pretrained weights
transfer_model = tf.keras.models.clone_model(transfer_model_matched)
transfer_model.set_weights(transfer_model_matched.get_weights())

# Stage 1: freeze first 2 layers
for layer in transfer_model.layers[:3]:
    layer.trainable = False

transfer_model.compile(
    loss=weighted_mse,
    optimizer=Adam(learning_rate=5e-4),
    metrics=["mean_squared_error"]
)

history_stage1 = transfer_model.fit(
    x_real_train_s, y_real_train_s,
    sample_weight=sample_w_real,
    validation_split=0.2,
    epochs=150,
    verbose=1
)
# Out:
# Epoch 1/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - loss: 0.2504 - mean_squared_error: 0.4799 - val_loss: 0.2381 - val_mean_squared_error: 0.4868
# Epoch 2/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.2212 - mean_squared_error: 0.4563 - val_loss: 0.2145 - val_mean_squared_error: 0.4681
# Epoch 3/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1974 - mean_squared_error: 0.4354 - val_loss: 0.1947 - val_mean_squared_error: 0.4509
# Epoch 4/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1761 - mean_squared_error: 0.4159 - val_loss: 0.1784 - val_mean_squared_error: 0.4350
# Epoch 5/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1589 - mean_squared_error: 0.3960 - val_loss: 0.1652 - val_mean_squared_error: 0.4195
# Epoch 6/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1454 - mean_squared_error: 0.3775 - val_loss: 0.1549 - val_mean_squared_error: 0.4047
# Epoch 7/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.1329 - mean_squared_error: 0.3592 - val_loss: 0.1468 - val_mean_squared_error: 0.3904
# Epoch 8/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1236 - mean_squared_error: 0.3421 - val_loss: 0.1405 - val_mean_squared_error: 0.3764
# Epoch 9/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1168 - mean_squared_error: 0.3259 - val_loss: 0.1356 - val_mean_squared_error: 0.3629
# Epoch 10/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.1112 - mean_squared_error: 0.3108 - val_loss: 0.1316 - val_mean_squared_error: 0.3499
# Epoch 11/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1062 - mean_squared_error: 0.2954 - val_loss: 0.1282 - val_mean_squared_error: 0.3368
# Epoch 12/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1014 - mean_squared_error: 0.2809 - val_loss: 0.1249 - val_mean_squared_error: 0.3236
# Epoch 13/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0975 - mean_squared_error: 0.2666 - val_loss: 0.1216 - val_mean_squared_error: 0.3107
# Epoch 14/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0931 - mean_squared_error: 0.2528 - val_loss: 0.1182 - val_mean_squared_error: 0.2979
# Epoch 15/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0895 - mean_squared_error: 0.2391 - val_loss: 0.1147 - val_mean_squared_error: 0.2854
# Epoch 16/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0859 - mean_squared_error: 0.2267 - val_loss: 0.1111 - val_mean_squared_error: 0.2734
# Epoch 17/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0820 - mean_squared_error: 0.2139 - val_loss: 0.1074 - val_mean_squared_error: 0.2616
# Epoch 18/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0784 - mean_squared_error: 0.2025 - val_loss: 0.1037 - val_mean_squared_error: 0.2506
# Epoch 19/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0754 - mean_squared_error: 0.1918 - val_loss: 0.1003 - val_mean_squared_error: 0.2402
# Epoch 20/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0725 - mean_squared_error: 0.1821 - val_loss: 0.0972 - val_mean_squared_error: 0.2306
# Epoch 21/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0699 - mean_squared_error: 0.1738 - val_loss: 0.0944 - val_mean_squared_error: 0.2216
# Epoch 22/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0677 - mean_squared_error: 0.1654 - val_loss: 0.0918 - val_mean_squared_error: 0.2134
# Epoch 23/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0654 - mean_squared_error: 0.1587 - val_loss: 0.0894 - val_mean_squared_error: 0.2058
# Epoch 24/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0630 - mean_squared_error: 0.1520 - val_loss: 0.0873 - val_mean_squared_error: 0.1992
# Epoch 25/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0620 - mean_squared_error: 0.1467 - val_loss: 0.0854 - val_mean_squared_error: 0.1931
# Epoch 26/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0604 - mean_squared_error: 0.1415 - val_loss: 0.0836 - val_mean_squared_error: 0.1878
# Epoch 27/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0587 - mean_squared_error: 0.1371 - val_loss: 0.0820 - val_mean_squared_error: 0.1831
# Epoch 28/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0577 - mean_squared_error: 0.1332 - val_loss: 0.0805 - val_mean_squared_error: 0.1790
# Epoch 29/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0563 - mean_squared_error: 0.1295 - val_loss: 0.0791 - val_mean_squared_error: 0.1754
# Epoch 30/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0553 - mean_squared_error: 0.1263 - val_loss: 0.0778 - val_mean_squared_error: 0.1721
# Epoch 31/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0541 - mean_squared_error: 0.1232 - val_loss: 0.0766 - val_mean_squared_error: 0.1691
# Epoch 32/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0531 - mean_squared_error: 0.1204 - val_loss: 0.0755 - val_mean_squared_error: 0.1665
# Epoch 33/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0521 - mean_squared_error: 0.1180 - val_loss: 0.0744 - val_mean_squared_error: 0.1640
# Epoch 34/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0514 - mean_squared_error: 0.1155 - val_loss: 0.0735 - val_mean_squared_error: 0.1618
# Epoch 35/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0506 - mean_squared_error: 0.1135 - val_loss: 0.0726 - val_mean_squared_error: 0.1597
# Epoch 36/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0498 - mean_squared_error: 0.1112 - val_loss: 0.0716 - val_mean_squared_error: 0.1576
# Epoch 37/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0491 - mean_squared_error: 0.1094 - val_loss: 0.0707 - val_mean_squared_error: 0.1558
# Epoch 38/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0485 - mean_squared_error: 0.1074 - val_loss: 0.0698 - val_mean_squared_error: 0.1542
# Epoch 39/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0480 - mean_squared_error: 0.1057 - val_loss: 0.0690 - val_mean_squared_error: 0.1524
# Epoch 40/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0473 - mean_squared_error: 0.1040 - val_loss: 0.0681 - val_mean_squared_error: 0.1510
# Epoch 41/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0468 - mean_squared_error: 0.1024 - val_loss: 0.0673 - val_mean_squared_error: 0.1493
# Epoch 42/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0463 - mean_squared_error: 0.1009 - val_loss: 0.0665 - val_mean_squared_error: 0.1479
# Epoch 43/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0457 - mean_squared_error: 0.0994 - val_loss: 0.0657 - val_mean_squared_error: 0.1465
# Epoch 44/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0452 - mean_squared_error: 0.0980 - val_loss: 0.0650 - val_mean_squared_error: 0.1452
# Epoch 45/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0448 - mean_squared_error: 0.0967 - val_loss: 0.0643 - val_mean_squared_error: 0.1438
# Epoch 46/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0440 - mean_squared_error: 0.0953 - val_loss: 0.0637 - val_mean_squared_error: 0.1426
# Epoch 47/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0433 - mean_squared_error: 0.0942 - val_loss: 0.0632 - val_mean_squared_error: 0.1414
# Epoch 48/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0434 - mean_squared_error: 0.0929 - val_loss: 0.0626 - val_mean_squared_error: 0.1403
# Epoch 49/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0430 - mean_squared_error: 0.0918 - val_loss: 0.0620 - val_mean_squared_error: 0.1392
# Epoch 50/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0423 - mean_squared_error: 0.0907 - val_loss: 0.0615 - val_mean_squared_error: 0.1380
# Epoch 51/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0423 - mean_squared_error: 0.0896 - val_loss: 0.0610 - val_mean_squared_error: 0.1371
# Epoch 52/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0418 - mean_squared_error: 0.0887 - val_loss: 0.0606 - val_mean_squared_error: 0.1364
# Epoch 53/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0414 - mean_squared_error: 0.0876 - val_loss: 0.0602 - val_mean_squared_error: 0.1356
# Epoch 54/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0415 - mean_squared_error: 0.0868 - val_loss: 0.0599 - val_mean_squared_error: 0.1347
# Epoch 55/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0407 - mean_squared_error: 0.0860 - val_loss: 0.0595 - val_mean_squared_error: 0.1338
# Epoch 56/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0407 - mean_squared_error: 0.0851 - val_loss: 0.0592 - val_mean_squared_error: 0.1331
# Epoch 57/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0405 - mean_squared_error: 0.0844 - val_loss: 0.0589 - val_mean_squared_error: 0.1324
# Epoch 58/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0402 - mean_squared_error: 0.0837 - val_loss: 0.0585 - val_mean_squared_error: 0.1315
# Epoch 59/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0400 - mean_squared_error: 0.0830 - val_loss: 0.0582 - val_mean_squared_error: 0.1306
# Epoch 60/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0396 - mean_squared_error: 0.0824 - val_loss: 0.0578 - val_mean_squared_error: 0.1298
# Epoch 61/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0393 - mean_squared_error: 0.0817 - val_loss: 0.0575 - val_mean_squared_error: 0.1293
# Epoch 62/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0389 - mean_squared_error: 0.0812 - val_loss: 0.0571 - val_mean_squared_error: 0.1286
# Epoch 63/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0389 - mean_squared_error: 0.0806 - val_loss: 0.0568 - val_mean_squared_error: 0.1280
# Epoch 64/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0388 - mean_squared_error: 0.0800 - val_loss: 0.0565 - val_mean_squared_error: 0.1274
# Epoch 65/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0382 - mean_squared_error: 0.0794 - val_loss: 0.0563 - val_mean_squared_error: 0.1270
# Epoch 66/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0383 - mean_squared_error: 0.0789 - val_loss: 0.0561 - val_mean_squared_error: 0.1267
# Epoch 67/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0382 - mean_squared_error: 0.0783 - val_loss: 0.0559 - val_mean_squared_error: 0.1262
# Epoch 68/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0381 - mean_squared_error: 0.0778 - val_loss: 0.0556 - val_mean_squared_error: 0.1255
# Epoch 69/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0377 - mean_squared_error: 0.0772 - val_loss: 0.0553 - val_mean_squared_error: 0.1251
# Epoch 70/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0375 - mean_squared_error: 0.0767 - val_loss: 0.0550 - val_mean_squared_error: 0.1247
# Epoch 71/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0375 - mean_squared_error: 0.0762 - val_loss: 0.0548 - val_mean_squared_error: 0.1245
# Epoch 72/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0377 - mean_squared_error: 0.0757 - val_loss: 0.0546 - val_mean_squared_error: 0.1244
# Epoch 73/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0371 - mean_squared_error: 0.0752 - val_loss: 0.0544 - val_mean_squared_error: 0.1242
# Epoch 74/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0368 - mean_squared_error: 0.0747 - val_loss: 0.0541 - val_mean_squared_error: 0.1237
# Epoch 75/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0363 - mean_squared_error: 0.0742 - val_loss: 0.0539 - val_mean_squared_error: 0.1233
# Epoch 76/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0365 - mean_squared_error: 0.0737 - val_loss: 0.0536 - val_mean_squared_error: 0.1227
# Epoch 77/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0358 - mean_squared_error: 0.0732 - val_loss: 0.0534 - val_mean_squared_error: 0.1222
# Epoch 78/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0363 - mean_squared_error: 0.0728 - val_loss: 0.0532 - val_mean_squared_error: 0.1216
# Epoch 79/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0359 - mean_squared_error: 0.0724 - val_loss: 0.0529 - val_mean_squared_error: 0.1212
# Epoch 80/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0358 - mean_squared_error: 0.0720 - val_loss: 0.0527 - val_mean_squared_error: 0.1206
# Epoch 81/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0355 - mean_squared_error: 0.0715 - val_loss: 0.0524 - val_mean_squared_error: 0.1200
# Epoch 82/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0353 - mean_squared_error: 0.0711 - val_loss: 0.0522 - val_mean_squared_error: 0.1194
# Epoch 83/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0353 - mean_squared_error: 0.0707 - val_loss: 0.0520 - val_mean_squared_error: 0.1192
# Epoch 84/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0352 - mean_squared_error: 0.0703 - val_loss: 0.0518 - val_mean_squared_error: 0.1188
# Epoch 85/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0350 - mean_squared_error: 0.0699 - val_loss: 0.0516 - val_mean_squared_error: 0.1185
# Epoch 86/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0348 - mean_squared_error: 0.0695 - val_loss: 0.0514 - val_mean_squared_error: 0.1181
# Epoch 87/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0347 - mean_squared_error: 0.0691 - val_loss: 0.0513 - val_mean_squared_error: 0.1179
# Epoch 88/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0346 - mean_squared_error: 0.0687 - val_loss: 0.0511 - val_mean_squared_error: 0.1176
# Epoch 89/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0345 - mean_squared_error: 0.0684 - val_loss: 0.0510 - val_mean_squared_error: 0.1173
# Epoch 90/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0342 - mean_squared_error: 0.0680 - val_loss: 0.0508 - val_mean_squared_error: 0.1170
# Epoch 91/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0342 - mean_squared_error: 0.0676 - val_loss: 0.0507 - val_mean_squared_error: 0.1169
# Epoch 92/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0340 - mean_squared_error: 0.0673 - val_loss: 0.0505 - val_mean_squared_error: 0.1165
# Epoch 93/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0338 - mean_squared_error: 0.0669 - val_loss: 0.0504 - val_mean_squared_error: 0.1162
# Epoch 94/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0336 - mean_squared_error: 0.0666 - val_loss: 0.0503 - val_mean_squared_error: 0.1158
# Epoch 95/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0335 - mean_squared_error: 0.0663 - val_loss: 0.0502 - val_mean_squared_error: 0.1155
# Epoch 96/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0333 - mean_squared_error: 0.0659 - val_loss: 0.0501 - val_mean_squared_error: 0.1154
# Epoch 97/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0332 - mean_squared_error: 0.0656 - val_loss: 0.0500 - val_mean_squared_error: 0.1152
# Epoch 98/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0330 - mean_squared_error: 0.0652 - val_loss: 0.0498 - val_mean_squared_error: 0.1150
# Epoch 99/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0331 - mean_squared_error: 0.0649 - val_loss: 0.0497 - val_mean_squared_error: 0.1148
# Epoch 100/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0326 - mean_squared_error: 0.0646 - val_loss: 0.0496 - val_mean_squared_error: 0.1145
# Epoch 101/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0326 - mean_squared_error: 0.0642 - val_loss: 0.0495 - val_mean_squared_error: 0.1143
# Epoch 102/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0325 - mean_squared_error: 0.0640 - val_loss: 0.0494 - val_mean_squared_error: 0.1143
# Epoch 103/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0323 - mean_squared_error: 0.0636 - val_loss: 0.0493 - val_mean_squared_error: 0.1139
# Epoch 104/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0323 - mean_squared_error: 0.0633 - val_loss: 0.0491 - val_mean_squared_error: 0.1137
# Epoch 105/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0321 - mean_squared_error: 0.0630 - val_loss: 0.0490 - val_mean_squared_error: 0.1133
# Epoch 106/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0321 - mean_squared_error: 0.0629 - val_loss: 0.0489 - val_mean_squared_error: 0.1126
# Epoch 107/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0319 - mean_squared_error: 0.0625 - val_loss: 0.0489 - val_mean_squared_error: 0.1124
# Epoch 108/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0319 - mean_squared_error: 0.0622 - val_loss: 0.0487 - val_mean_squared_error: 0.1120
# Epoch 109/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0317 - mean_squared_error: 0.0619 - val_loss: 0.0486 - val_mean_squared_error: 0.1119
# Epoch 110/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0316 - mean_squared_error: 0.0617 - val_loss: 0.0485 - val_mean_squared_error: 0.1117
# Epoch 111/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0315 - mean_squared_error: 0.0614 - val_loss: 0.0484 - val_mean_squared_error: 0.1115
# Epoch 112/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0312 - mean_squared_error: 0.0611 - val_loss: 0.0483 - val_mean_squared_error: 0.1115
# Epoch 113/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0313 - mean_squared_error: 0.0608 - val_loss: 0.0482 - val_mean_squared_error: 0.1114
# Epoch 114/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0311 - mean_squared_error: 0.0605 - val_loss: 0.0481 - val_mean_squared_error: 0.1112
# Epoch 115/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0309 - mean_squared_error: 0.0603 - val_loss: 0.0480 - val_mean_squared_error: 0.1111
# Epoch 116/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0308 - mean_squared_error: 0.0601 - val_loss: 0.0479 - val_mean_squared_error: 0.1108
# Epoch 117/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0309 - mean_squared_error: 0.0598 - val_loss: 0.0478 - val_mean_squared_error: 0.1106
# Epoch 118/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0302 - mean_squared_error: 0.0596 - val_loss: 0.0477 - val_mean_squared_error: 0.1104
# Epoch 119/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0305 - mean_squared_error: 0.0594 - val_loss: 0.0476 - val_mean_squared_error: 0.1103
# Epoch 120/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0296 - mean_squared_error: 0.0591 - val_loss: 0.0476 - val_mean_squared_error: 0.1101
# Epoch 121/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0305 - mean_squared_error: 0.0589 - val_loss: 0.0474 - val_mean_squared_error: 0.1099
# Epoch 122/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0303 - mean_squared_error: 0.0587 - val_loss: 0.0473 - val_mean_squared_error: 0.1097
# Epoch 123/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0302 - mean_squared_error: 0.0585 - val_loss: 0.0472 - val_mean_squared_error: 0.1094
# Epoch 124/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0302 - mean_squared_error: 0.0583 - val_loss: 0.0471 - val_mean_squared_error: 0.1092
# Epoch 125/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0300 - mean_squared_error: 0.0581 - val_loss: 0.0471 - val_mean_squared_error: 0.1091
# Epoch 126/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0298 - mean_squared_error: 0.0579 - val_loss: 0.0470 - val_mean_squared_error: 0.1088
# Epoch 127/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0298 - mean_squared_error: 0.0577 - val_loss: 0.0469 - val_mean_squared_error: 0.1087
# Epoch 128/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0298 - mean_squared_error: 0.0576 - val_loss: 0.0468 - val_mean_squared_error: 0.1085
# Epoch 129/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0295 - mean_squared_error: 0.0573 - val_loss: 0.0467 - val_mean_squared_error: 0.1082
# Epoch 130/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0296 - mean_squared_error: 0.0571 - val_loss: 0.0466 - val_mean_squared_error: 0.1077
# Epoch 131/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0295 - mean_squared_error: 0.0569 - val_loss: 0.0465 - val_mean_squared_error: 0.1074
# Epoch 132/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0294 - mean_squared_error: 0.0567 - val_loss: 0.0464 - val_mean_squared_error: 0.1071
# Epoch 133/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0293 - mean_squared_error: 0.0566 - val_loss: 0.0463 - val_mean_squared_error: 0.1071
# Epoch 134/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0292 - mean_squared_error: 0.0564 - val_loss: 0.0462 - val_mean_squared_error: 0.1068
# Epoch 135/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0289 - mean_squared_error: 0.0562 - val_loss: 0.0462 - val_mean_squared_error: 0.1067
# Epoch 136/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0290 - mean_squared_error: 0.0560 - val_loss: 0.0461 - val_mean_squared_error: 0.1066
# Epoch 137/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0290 - mean_squared_error: 0.0558 - val_loss: 0.0461 - val_mean_squared_error: 0.1065
# Epoch 138/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0289 - mean_squared_error: 0.0557 - val_loss: 0.0460 - val_mean_squared_error: 0.1064
# Epoch 139/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0290 - mean_squared_error: 0.0555 - val_loss: 0.0460 - val_mean_squared_error: 0.1063
# Epoch 140/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0286 - mean_squared_error: 0.0553 - val_loss: 0.0459 - val_mean_squared_error: 0.1062
# Epoch 141/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0286 - mean_squared_error: 0.0551 - val_loss: 0.0459 - val_mean_squared_error: 0.1060
# Epoch 142/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0285 - mean_squared_error: 0.0550 - val_loss: 0.0458 - val_mean_squared_error: 0.1059
# Epoch 143/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0287 - mean_squared_error: 0.0548 - val_loss: 0.0457 - val_mean_squared_error: 0.1059
# Epoch 144/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0284 - mean_squared_error: 0.0546 - val_loss: 0.0456 - val_mean_squared_error: 0.1056
# Epoch 145/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0283 - mean_squared_error: 0.0545 - val_loss: 0.0455 - val_mean_squared_error: 0.1053
# Epoch 146/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0278 - mean_squared_error: 0.0543 - val_loss: 0.0454 - val_mean_squared_error: 0.1051
# Epoch 147/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0283 - mean_squared_error: 0.0542 - val_loss: 0.0453 - val_mean_squared_error: 0.1047
# Epoch 148/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0281 - mean_squared_error: 0.0541 - val_loss: 0.0453 - val_mean_squared_error: 0.1046
# Epoch 149/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0280 - mean_squared_error: 0.0539 - val_loss: 0.0453 - val_mean_squared_error: 0.1045
# Epoch 150/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0279 - mean_squared_error: 0.0538 - val_loss: 0.0452 - val_mean_squared_error: 0.1045

# %% [markdown]
# ## Stage 1 Validation Curve

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12,4))
ax.plot(history_stage1.history["loss"], label="Train")
ax.plot(history_stage1.history["val_loss"], label="Validation")
ax.set_title("Stage 1 Learning Curves")
ax.set_xlabel("Epoch")
ax.set_ylabel("Loss")
ax.legend()
plt.show()

# %%
eval_with_units(
    "Stage 1 Transfer Model - Real Test",
    transfer_model,
    x_real_test_s,
    y_real_test_s,
    scy,
    y_is_scaled=True,
    t_hit_in_seconds=True
)
# Out:
# Stage 1 Transfer Model - Real Test
# target unit       MAE      RMSE  STD_abs_error
#  x_hit   mm    68.798    84.826         49.621
#  y_hit   mm    95.126   122.408         77.038
#  z_hit   mm    46.101    63.873         44.208
# vx_hit mm/s    98.116   126.734         80.218
# vy_hit mm/s   229.675   295.882        186.536
# vz_hit mm/s 1,032.008 1,340.172        854.997
#  t_hit   ms    89.918   106.145         56.405

# %%
def snapshot_model(model):
    with tf.keras.utils.custom_object_scope({'weighted_mse': weighted_mse}):
        m = tf.keras.models.clone_model(model)
    m.set_weights(model.get_weights())
    return m

# --- run this RIGHT AFTER stage 1 training/eval ---
stage1_model = snapshot_model(transfer_model)
print("Saved stage1_model snapshot.")
# Out:
# Saved stage1_model snapshot.

# %%
# Stage 2: unfreeze all layers
for layer in transfer_model.layers:
    layer.trainable = True

transfer_model.compile(
    loss=weighted_mse,
    optimizer=Adam(learning_rate=1e-6),
    metrics=["mean_squared_error"]
)

history_stage2 = transfer_model.fit(
    x_real_train_s, y_real_train_s,
    sample_weight=sample_w_real,
    validation_split=0.2,
    epochs=50,
    verbose=1
)
# Out:
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 287ms/step - loss: 0.0351 - mean_squared_error: 0.0536 - val_loss: 0.0526 - val_mean_squared_error: 0.1045
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0353 - mean_squared_error: 0.0536 - val_loss: 0.0526 - val_mean_squared_error: 0.1045
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0350 - mean_squared_error: 0.0536 - val_loss: 0.0526 - val_mean_squared_error: 0.1045
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0351 - mean_squared_error: 0.0536 - val_loss: 0.0526 - val_mean_squared_error: 0.1045
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0351 - mean_squared_error: 0.0536 - val_loss: 0.0526 - val_mean_squared_error: 0.1045
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0350 - mean_squared_error: 0.0536 - val_loss: 0.0526 - val_mean_squared_error: 0.1045
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0352 - mean_squared_error: 0.0536 - val_loss: 0.0526 - val_mean_squared_error: 0.1045
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0352 - mean_squared_error: 0.0536 - val_loss: 0.0526 - val_mean_squared_error: 0.1045
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0349 - mean_squared_error: 0.0536 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0350 - mean_squared_error: 0.0536 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0348 - mean_squared_error: 0.0536 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0353 - mean_squared_error: 0.0536 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0347 - mean_squared_error: 0.0536 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0352 - mean_squared_error: 0.0536 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0352 - mean_squared_error: 0.0536 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 16/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0352 - mean_squared_error: 0.0535 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 17/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0352 - mean_squared_error: 0.0535 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 18/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0354 - mean_squared_error: 0.0535 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 19/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0351 - mean_squared_error: 0.0535 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 20/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0350 - mean_squared_error: 0.0535 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 21/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0353 - mean_squared_error: 0.0535 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 22/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0348 - mean_squared_error: 0.0535 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 23/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0351 - mean_squared_error: 0.0535 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 24/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0351 - mean_squared_error: 0.0535 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 25/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0351 - mean_squared_error: 0.0535 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 26/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0351 - mean_squared_error: 0.0535 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 27/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0351 - mean_squared_error: 0.0535 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 28/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0350 - mean_squared_error: 0.0535 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 29/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0351 - mean_squared_error: 0.0535 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 30/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0351 - mean_squared_error: 0.0535 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 31/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0351 - mean_squared_error: 0.0535 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 32/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0350 - mean_squared_error: 0.0535 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0351 - mean_squared_error: 0.0535 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0353 - mean_squared_error: 0.0535 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0352 - mean_squared_error: 0.0535 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0350 - mean_squared_error: 0.0535 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0351 - mean_squared_error: 0.0535 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0351 - mean_squared_error: 0.0534 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0350 - mean_squared_error: 0.0534 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0351 - mean_squared_error: 0.0534 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0351 - mean_squared_error: 0.0534 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0350 - mean_squared_error: 0.0534 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0350 - mean_squared_error: 0.0534 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0351 - mean_squared_error: 0.0534 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0350 - mean_squared_error: 0.0534 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0351 - mean_squared_error: 0.0534 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0350 - mean_squared_error: 0.0534 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 48/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0350 - mean_squared_error: 0.0534 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 49/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0351 - mean_squared_error: 0.0534 - val_loss: 0.0525 - val_mean_squared_error: 0.1045
# Epoch 50/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0350 - mean_squared_error: 0.0534 - val_loss: 0.0525 - val_mean_squared_error: 0.1045

# %%
fig, ax = plt.subplots(figsize=(12,4))
ax.plot(history_stage2.history["loss"], label="Train")
ax.plot(history_stage2.history["val_loss"], label="Validation")
ax.set_title("Stage 2 Learning Curves")
ax.set_xlabel("Epoch")
ax.set_ylabel("Loss")
ax.legend()
plt.show()

# %%
eval_with_units(
    "Stage 2 Final Transfer Model - Real Test",
    transfer_model,
    x_real_test_s,
    y_real_test_s,
    scy,
    y_is_scaled=True,
    t_hit_in_seconds=True
)
# Out:
# Stage 2 Final Transfer Model - Real Test
# target unit       MAE      RMSE  STD_abs_error
#  x_hit   mm    68.882    84.463         48.880
#  y_hit   mm    95.040   122.587         77.428
#  z_hit   mm    46.007    63.841         44.261
# vx_hit mm/s    97.838   126.524         80.224
# vy_hit mm/s   229.604   295.562        186.116
# vz_hit mm/s 1,030.561 1,338.592        854.267
#  t_hit   ms    89.828   105.935         56.153

# %%
stage2_model = snapshot_model(transfer_model)
print("Saved stage2_model snapshot.")

# --- run once (any time after broad + matched are trained) ---
broad_model = snapshot_model(ball_predictor)
matched_model = snapshot_model(transfer_model_matched)
print("Saved broad_model and matched_model snapshots.")
# Out:
# Saved stage2_model snapshot.
# Saved broad_model and matched_model snapshots.

# %%
# --- final comparison on real test set ---
eval_with_units("Broad model - Real Test",   broad_model,   x_real_test_s, y_real_test_s, scy, y_is_scaled=True, t_hit_in_seconds=True)
eval_with_units("Matched model - Real Test", matched_model, x_real_test_s, y_real_test_s, scy, y_is_scaled=True, t_hit_in_seconds=True)
eval_with_units("Stage 1 model - Real Test", stage1_model,  x_real_test_s, y_real_test_s, scy, y_is_scaled=True, t_hit_in_seconds=True)
eval_with_units("Stage 2 model - Real Test", stage2_model,  x_real_test_s, y_real_test_s, scy, y_is_scaled=True, t_hit_in_seconds=True)
# Out:
# WARNING:tensorflow:5 out of the last 35 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000233BA535080> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
# Broad model - Real Test
# target unit       MAE      RMSE  STD_abs_error
#  x_hit   mm    90.890   109.102         60.352
#  y_hit   mm   172.574   205.748        112.029
#  z_hit   mm   275.155   348.979        214.653
# vx_hit mm/s   322.997   448.110        310.606
# vy_hit mm/s 2,226.650 2,296.569        562.368
# vz_hit mm/s 2,114.293 2,612.439      1,534.470
#  t_hit   ms   344.502   368.190        129.931
# WARNING:tensorflow:6 out of the last 36 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000233BA534AE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
# Matched model - Real Test
# target unit       MAE      RMSE  STD_abs_error
#  x_hit   mm    75.963    92.843         53.380
#  y_hit   mm   148.939   175.919         93.621
#  z_hit   mm   192.327   217.947        102.525
# vx_hit mm/s   303.185   336.401        145.754
# vy_hit mm/s 1,988.546 2,029.748        406.891
# vz_hit mm/s 1,735.723 2,095.884      1,174.733
#  t_hit   ms   295.473   324.304        133.674
#
# Stage 1 model - Real Test
# target unit       MAE      RMSE  STD_abs_error
#  x_hit   mm    68.798    84.826         49.621
#  y_hit   mm    95.126   122.408         77.038
#  z_hit   mm    46.101    63.873         44.208
# vx_hit mm/s    98.116   126.734         80.218
# vy_hit mm/s   229.675   295.882        186.536
# vz_hit mm/s 1,032.008 1,340.172        854.997
#  t_hit   ms    89.918   106.145         56.405
#
# Stage 2 model - Real Test
# target unit       MAE      RMSE  STD_abs_error
#  x_hit   mm    68.882    84.463         48.880
#  y_hit   mm    95.040   122.587         77.428
#  z_hit   mm    46.007    63.841         44.261
# vx_hit mm/s    97.838   126.524         80.224
# vy_hit mm/s   229.604   295.562        186.116
# vz_hit mm/s 1,030.561 1,338.592        854.267
#  t_hit   ms    89.828   105.935         56.153

# %%
from pathlib import Path
import joblib

export_dir = Path("../models/ann_stage2_6pt_verified")
export_dir.mkdir(parents=True, exist_ok=True)

deploy_model = stage2_model   # or transfer_model / matched_model / broad_model
deploy_model.save(export_dir / "ball_predictor.keras")
joblib.dump(scx, export_dir / "scx.joblib")
joblib.dump(scy, export_dir / "scy.joblib")

print("Saved model + scalers to:", export_dir.resolve())
# Out:
# Saved model + scalers to: C:\Users\rocky\Personal\UBC\Year 4\IGEN 430\TableTennis_Software_Firmware\transfer_learning\models\ann_stage2_6pt_verified

# %% [markdown]
# ## K-Fold Hyperparameter Tuning (Real Data)
#
# Run this section after `transfer_model_matched`, `x_real`, `y_real`, `scx`, `scy`, `weighted_mse`, and `build_sample_weights` are defined.

# %%
from sklearn.model_selection import KFold, ParameterGrid
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
import numpy as np
import pandas as pd


def clone_with_weights(model):
    with tf.keras.utils.custom_object_scope({"weighted_mse": weighted_mse}):
        m = tf.keras.models.clone_model(model)
    m.set_weights(model.get_weights())
    return m


def evaluate_physical_mae(model, x_val_s, y_val_s, y_scaler):
    y_pred_s = model.predict(x_val_s, verbose=0)
    y_true_u = y_scaler.inverse_transform(y_val_s)
    y_pred_u = y_scaler.inverse_transform(y_pred_s)
    mae = np.mean(np.abs(y_pred_u - y_true_u), axis=0)
    mae_ms = mae.copy()
    mae_ms[6] = mae_ms[6] * 1000.0
    return mae_ms


def run_transfer_kfold_once(x_real_raw, y_real_raw, base_model, hp, n_splits=5, seed=6):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=seed)
    fold_rows = []

    for fold_id, (tr_idx, va_idx) in enumerate(kf.split(x_real_raw), start=1):
        x_tr, x_va = x_real_raw[tr_idx], x_real_raw[va_idx]
        y_tr, y_va = y_real_raw[tr_idx], y_real_raw[va_idx]

        x_tr_s = scx.transform(x_tr)
        x_va_s = scx.transform(x_va)
        y_tr_s = scy.transform(y_tr)
        y_va_s = scy.transform(y_va)

        sample_w = build_sample_weights(
            y_tr_s, scy, reachable_vec=np.ones(y_tr_s.shape[0], dtype=int)
        )

        model = clone_with_weights(base_model)

        freeze_first_n = int(hp.get("freeze_first_n", 2))
        for layer in model.layers[:freeze_first_n]:
            layer.trainable = False

        callbacks = [
            EarlyStopping(
                monitor="val_loss",
                patience=int(hp.get("patience", 12)),
                restore_best_weights=True,
                verbose=0,
            )
        ]

        model.compile(
            loss=weighted_mse,
            optimizer=Adam(learning_rate=float(hp["stage1_lr"])),
            metrics=["mean_squared_error"],
        )
        hist1 = model.fit(
            x_tr_s,
            y_tr_s,
            sample_weight=sample_w,
            validation_data=(x_va_s, y_va_s),
            epochs=int(hp.get("stage1_epochs", 120)),
            batch_size=int(hp.get("batch_size", 16)),
            callbacks=callbacks,
            verbose=0,
        )
        best_stage1 = float(np.min(hist1.history["val_loss"]))

        stage2_epochs = int(hp.get("stage2_epochs", 80))
        if stage2_epochs > 0:
            for layer in model.layers:
                layer.trainable = True

            model.compile(
                loss=weighted_mse,
                optimizer=Adam(learning_rate=float(hp["stage2_lr"])),
                metrics=["mean_squared_error"],
            )
            hist2 = model.fit(
                x_tr_s,
                y_tr_s,
                sample_weight=sample_w,
                validation_data=(x_va_s, y_va_s),
                epochs=stage2_epochs,
                batch_size=int(hp.get("batch_size", 16)),
                callbacks=callbacks,
                verbose=0,
            )
            best_stage2 = float(np.min(hist2.history["val_loss"]))
            best_val_loss = min(best_stage1, best_stage2)
        else:
            best_val_loss = best_stage1

        mae = evaluate_physical_mae(model, x_va_s, y_va_s, scy)

        fold_rows.append(
            {
                "fold": fold_id,
                "best_val_loss": best_val_loss,
                "mae_x_mm": mae[0],
                "mae_y_mm": mae[1],
                "mae_z_mm": mae[2],
                "mae_vx_mm_s": mae[3],
                "mae_vy_mm_s": mae[4],
                "mae_vz_mm_s": mae[5],
                "mae_t_ms": mae[6],
            }
        )

        tf.keras.backend.clear_session()

    return pd.DataFrame(fold_rows)


def run_grid_kfold(x_real_raw, y_real_raw, base_model, param_grid, n_splits=5, seed=6):
    all_runs = []

    for run_id, hp in enumerate(ParameterGrid(param_grid), start=1):
        fold_df = run_transfer_kfold_once(
            x_real_raw=x_real_raw,
            y_real_raw=y_real_raw,
            base_model=base_model,
            hp=hp,
            n_splits=n_splits,
            seed=seed,
        )

        summary = {
            "run_id": run_id,
            **hp,
            "mean_val_loss": fold_df["best_val_loss"].mean(),
            "std_val_loss": fold_df["best_val_loss"].std(ddof=0),
            "mae_xyz_mm": fold_df[["mae_x_mm", "mae_y_mm", "mae_z_mm"]].mean().mean(),
            "mae_v_mm_s": fold_df[["mae_vx_mm_s", "mae_vy_mm_s", "mae_vz_mm_s"]].mean().mean(),
            "mae_t_ms": fold_df["mae_t_ms"].mean(),
        }
        all_runs.append(summary)
        print(f"[run {run_id}] mean_val_loss={summary['mean_val_loss']:.4f} hp={hp}")

    out_df = pd.DataFrame(all_runs).sort_values("mean_val_loss").reset_index(drop=True)
    return out_df

# %%
param_grid = {
    "freeze_first_n": [1, 2],
    "stage1_lr": [1e-4, 5e-5],
    "stage2_lr": [5e-5, 1e-5],
    "batch_size": [16],
    "stage1_epochs": [120],
    "stage2_epochs": [80],
    "patience": [12],
}

kfold_results = run_grid_kfold(
    x_real_raw=x_real,
    y_real_raw=y_real,
    base_model=transfer_model_matched,
    param_grid=param_grid,
    n_splits=5,
    seed=6,
)

kfold_results.head(10)
# Out:
# WARNING:tensorflow:From C:\Users\rocky\anaconda3\envs\manu465\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# [run 1] mean_val_loss=0.0491 hp={'batch_size': 16, 'freeze_first_n': 1, 'patience': 12, 'stage1_epochs': 120, 'stage1_lr': 0.0001, 'stage2_epochs': 80, 'stage2_lr': 5e-05}
# [run 2] mean_val_loss=0.0480 hp={'batch_size': 16, 'freeze_first_n': 1, 'patience': 12, 'stage1_epochs': 120, 'stage1_lr': 0.0001, 'stage2_epochs': 80, 'stage2_lr': 1e-05}
# [run 3] mean_val_loss=0.0528 hp={'batch_size': 16, 'freeze_first_n': 1, 'patience': 12, 'stage1_epochs': 120, 'stage1_lr': 5e-05, 'stage2_epochs': 80, 'stage2_lr': 5e-05}
# [run 4] mean_val_loss=0.0546 hp={'batch_size': 16, 'freeze_first_n': 1, 'patience': 12, 'stage1_epochs': 120, 'stage1_lr': 5e-05, 'stage2_epochs': 80, 'stage2_lr': 1e-05}
# [run 5] mean_val_loss=0.0473 hp={'batch_size': 16, 'freeze_first_n': 2, 'patience': 12, 'stage1_epochs': 120, 'stage1_lr': 0.0001, 'stage2_epochs': 80, 'stage2_lr': 5e-05}
# [run 6] mean_val_loss=0.0485 hp={'batch_size': 16, 'freeze_first_n': 2, 'patience': 12, 'stage1_epochs': 120, 'stage1_lr': 0.0001, 'stage2_epochs': 80, 'stage2_lr': 1e-05}
# [run 7] mean_val_loss=0.0529 hp={'batch_size': 16, 'freeze_first_n': 2, 'patience': 12, 'stage1_epochs': 120, 'stage1_lr': 5e-05, 'stage2_epochs': 80, 'stage2_lr': 5e-05}
# [run 8] mean_val_loss=0.0540 hp={'batch_size': 16, 'freeze_first_n': 2, 'patience': 12, 'stage1_epochs': 120, 'stage1_lr': 5e-05, 'stage2_epochs': 80, 'stage2_lr': 1e-05}
#    run_id  batch_size  freeze_first_n  patience  stage1_epochs  stage1_lr  \
# 0       5          16               2        12            120    0.00010
# 1       2          16               1        12            120    0.00010
# 2       6          16               2        12            120    0.00010
# 3       1          16               1        12            120    0.00010
# 4       3          16               1        12            120    0.00005
# 5       7          16               2        12            120    0.00005
# 6       8          16               2        12            120    0.00005
# 7       4          16               1        12            120    0.00005
#
#    stage2_epochs  stage2_lr  mean_val_loss  std_val_loss  mae_xyz_mm  \
# 0             80    0.00005       0.047344      0.007868   67.545851
# 1             80    0.00001       0.048000      0.008880   65.900306
# 2             80    0.00001       0.048453      0.009333   68.229456
# 3             80    0.00005       0.049140      0.008945   66.717152
# 4             80    0.00005       0.052806      0.009858   67.247200
# 5             80    0.00005       0.052869      0.008714   68.790125
# 6             80    0.00001       0.053972      0.007244   70.295537
# 7             80    0.00001       0.054631      0.009754   68.072220
#
#    mae_v_mm_s   mae_t_ms
# 0  533.708075  82.532113
# 1  517.295529  77.374954
# 2  532.057291  83.898401
# 3  526.083468  79.460772
# 4  562.083816  81.941139
# 5  586.685811  88.280070
# 6  598.946461  92.731483
# 7  604.164533  90.920887

# %%
from pathlib import Path

best_hp = kfold_results.iloc[0].to_dict()
print("Best hyperparameters:")
print(best_hp)

out_dir = Path("../models/kfold_tuning_logs")
out_dir.mkdir(parents=True, exist_ok=True)
out_path = out_dir / "kfold_results_6pt_weighted.csv"
kfold_results.to_csv(out_path, index=False)
print(f"Saved k-fold summary to: {out_path.resolve()}")
# Out:
# Best hyperparameters:
# {'run_id': 5.0, 'batch_size': 16.0, 'freeze_first_n': 2.0, 'patience': 12.0, 'stage1_epochs': 120.0, 'stage1_lr': 0.0001, 'stage2_epochs': 80.0, 'stage2_lr': 5e-05, 'mean_val_loss': 0.0473440483212471, 'std_val_loss': 0.00786756728747595, 'mae_xyz_mm': 67.54585146806672, 'mae_v_mm_s': 533.7080749585343, 'mae_t_ms': 82.53211272682371}
# Saved k-fold summary to: C:\Users\rocky\Personal\UBC\Year 4\IGEN 430\TableTennis_Software_Firmware\transfer_learning\models\kfold_tuning_logs\kfold_results_6pt_weighted.csv
