# %% [markdown]
# # Ping Pong Ball Prediction Using Transfer Learning:
#
# Inputs:
# - x y z (frame 1)
# - x y z (frame 2)
# - x y z (frame 3)
# - x y z (frame 4)
# - x y z (frame 5)
# - x y z (frame 6)
# - dt12
# - dt23
# - dt34
# - dt45
# - dt56
#
#
# Outputs:
# - x y z (interception)
# - vx vy vz
# - t_hit

# %% [markdown]
# ## Importing the Libraries

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ### Importing the Dataset

# %%
dataset = pd.read_csv('../learning_data/synthetic_data/broad_noloss_clean.csv')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 41 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   x1                     20000 non-null  float64
#  1   y1                     20000 non-null  float64
#  2   z1                     20000 non-null  float64
#  3   x2                     20000 non-null  float64
#  4   y2                     20000 non-null  float64
#  5   z2                     20000 non-null  float64
#  6   x3                     20000 non-null  float64
#  7   y3                     20000 non-null  float64
#  8   z3                     20000 non-null  float64
#  9   x4                     20000 non-null  float64
#  10  y4                     20000 non-null  float64
#  11  z4                     20000 non-null  float64
#  12  x5                     20000 non-null  float64
#  13  y5                     20000 non-null  float64
#  14  z5                     20000 non-null  float64
#  15  x6                     20000 non-null  float64
#  16  y6                     20000 non-null  float64
#  17  z6                     20000 non-null  float64
#  18  dt12                   20000 non-null  float64
#  19  dt23                   20000 non-null  float64
#  20  dt34                   20000 non-null  float64
#  21  dt45                   20000 non-null  float64
#  22  dt56                   20000 non-null  float64
#  23  x_hit                  20000 non-null  float64
#  24  y_hit                  20000 non-null  float64
#  25  z_hit                  20000 non-null  float64
#  26  vx_hit                 20000 non-null  float64
#  27  vy_hit                 20000 non-null  float64
#  28  vz_hit                 20000 non-null  float64
#  29  t_hit                  20000 non-null  float64
#  30  is_reachable           20000 non-null  float64
#  31  bounces_before_hit     20000 non-null  float64
#  32  has_bounce_before_hit  20000 non-null  float64
#  33  intercept_valid        20000 non-null  float64
#  34  x0                     20000 non-null  float64
#  35  y0                     20000 non-null  float64
#  36  z0                     20000 non-null  float64
#  37  vx0                    20000 non-null  float64
#  38  vy0                    20000 non-null  float64
#  39  vz0                    20000 non-null  float64
#  40  gravity_z_mm_s2        20000 non-null  float64
# dtypes: float64(41)
# memory usage: 6.3 MB

# %%
dataset.describe()
# Out:
#                  x1            y1            z1            x2            y2  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean      -0.447304   1800.152467   -909.271733     -0.984933   1716.539020
# std      408.446415    212.061961    172.772196    394.527807    222.207137
# min     -719.959843   1175.727354  -1225.283312   -735.624378   1093.323790
# 25%     -341.246675   1651.668248  -1052.431568   -327.611367   1559.761084
# 50%       -1.640492   1851.681127   -940.164344     -1.868385   1769.652962
# 75%      344.472316   1984.353766   -792.955536    328.323117   1907.611710
# max      719.998335   2059.998708   -277.403912    739.598449   2024.076446
#
#                  z2            x3            y3            z3            x4  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean    -904.426395     -1.546829   1632.950727   -895.395035     -2.079480
# std      174.734358    382.963293    233.778980    179.973870    374.016457
# min    -1243.661838   -757.036026   1013.066529  -1265.466398   -776.962829
# 25%    -1049.315326   -313.405949   1466.821653  -1044.105242   -301.457143
# 50%     -935.386454     -4.828110   1684.608430   -927.449878     -4.152023
# 75%     -786.166485    313.456250   1831.943459   -774.236045    301.576454
# max     -271.992997    761.498199   1984.648324   -259.396559    781.099831
#
#        ...  bounces_before_hit  has_bounce_before_hit  intercept_valid  \
# count  ...        20000.000000            20000.00000          20000.0
# mean   ...            1.014750                0.94725              1.0
# std    ...            0.346466                0.22354              0.0
# min    ...            0.000000                0.00000              1.0
# 25%    ...            1.000000                1.00000              1.0
# 50%    ...            1.000000                1.00000              1.0
# 75%    ...            1.000000                1.00000              1.0
# max    ...            2.000000                1.00000              1.0
#
#                  x0            y0            z0           vx0           vy0  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       4.738115   2407.351437   -799.004243    -36.721753  -5396.585951
# std      571.037507    206.503886    202.250071   2147.727564   1378.678917
# min    -1062.136528   2060.045799  -1150.736745  -5217.870244  -9668.937333
# 25%     -475.611063   2232.521133   -974.364751  -1673.944288  -6348.996366
# 50%        6.569219   2398.963050   -798.179357    -77.072068  -5228.751069
# 75%      486.326497   2568.511844   -624.265295   1592.468310  -4342.256995
# max     1062.381926   2931.924114   -450.743508   5158.299680  -2492.464319
#
#                 vz0  gravity_z_mm_s2
# count  20000.000000          20000.0
# mean   -2033.064445          -9810.0
# std     1783.722104              0.0
# min    -5424.469006          -9810.0
# 25%    -3564.806602          -9810.0
# 50%    -2091.400441          -9810.0
# 75%     -602.129080          -9810.0
# max     2409.881602          -9810.0
#
# [8 rows x 41 columns]

# %% [markdown]
# ### Pre-Processing

# %% [markdown]
# ### Separating the Input and Outputs

# %%
input_cols_6 = [
    "x1", "y1", "z1",
    "x2", "y2", "z2",
    "x3", "y3", "z3",
    "x4", "y4", "z4",
    "x5", "y5", "z5",
    "x6", "y6", "z6",
    "dt12", "dt23", "dt34", "dt45", "dt56",
]
target_cols = ["x_hit", "y_hit", "z_hit", "vx_hit", "vy_hit", "vz_hit", "t_hit"]

x = dataset[input_cols_6]
y = dataset[target_cols]

# %%
# View the inputs
print(x)
# Out:
#                x1           y1           z1          x2           y2  \
# 0     -168.553485  2050.907145  -991.864021 -157.318349  1998.319604
# 1      414.793276  1482.988510  -914.631824  413.599803  1383.041357
# 2      705.080133  1411.436528 -1121.121983  690.989926  1338.195532
# 3      -59.578364  1961.375719 -1020.371065  -85.524259  1891.077037
# 4     -466.357216  1852.318796  -656.512761 -490.875091  1757.047446
# ...           ...          ...          ...         ...          ...
# 19995  -92.569900  1807.536897 -1005.353844  -80.456652  1729.830988
# 19996 -574.976702  1621.007120 -1022.760416 -532.624769  1509.751459
# 19997 -183.000015  1745.920601 -1039.944551 -146.208293  1655.439772
# 19998  408.806428  1680.714981 -1121.626042  420.612169  1584.202376
# 19999 -709.398314  2013.422247  -764.300366 -642.801164  1936.574003
#
#                 z2          x3           y3           z3          x4  ...  \
# 0      -970.809814 -147.460185  1952.177162  -954.682242 -137.929200  ...
# 1      -978.398284  412.362212  1279.399519 -1046.555272  411.008244  ...
# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error

# 1) Build reachability vector from your full dataset
# (change column name if needed)
r = dataset["is_reachable"].to_numpy().astype(int)

# 2) Split x, y, and r together (important)
x_train, x_test, y_train, y_test, r_train, r_test = train_test_split(
    x, y, r,
    test_size=0.1,
    random_state=1,
    stratify=r   # recommended
)

# 3) Keep full test copy
x_test_all = x_test.copy()
y_test_all = y_test.copy()

# 4) Reachable-only adjusted test set
mask_reach = (r_test == 1)
x_test_reach = x_test_all[mask_reach].copy()
y_test_reach = y_test_all[mask_reach].copy()

# %%
print(x_train.shape)
print(x_test_all.shape)
print(x_test_reach.shape)
print(y_train.shape)
print(y_test_all.shape)
print(y_test_reach.shape)
# Out:
# (18000, 23)
# (2000, 23)
# (542, 23)
# (18000, 7)
# (2000, 7)
# (542, 7)

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

scx = StandardScaler()
scy = StandardScaler()

x_train = scx.fit_transform(x_train)
x_test_all = scx.transform(x_test_all)
x_test_reach = scx.transform(x_test_reach)

y_train = scy.fit_transform((y_train))
y_test_all = scy.transform((y_test_all))
y_test_reach = scy.transform((y_test_reach))

# %% [markdown]
# ## The ANN Model Initialization

# %%
ball_predictor = tf.keras.models.Sequential()

# %% [markdown]
# ### Constructing the Model

# %%
ball_predictor.add(tf.keras.layers.Dense(units=23, activation='relu')) # 23 input features (6 points + 5 dt)
ball_predictor.add(tf.keras.layers.Dense(units=32, activation='relu')) # hiddel layer 1
ball_predictor.add(tf.keras.layers.Dense(units=64, activation='relu')) # hidden layer 2
ball_predictor.add(tf.keras.layers.Dense(units=32, activation='relu')) # hiddel layer 3
ball_predictor.add(tf.keras.layers.Dense(units=16, activation='relu')) # hiddel layer 4
ball_predictor.add(tf.keras.layers.Dense(units=16, activation='relu')) # hiddel layer 4
ball_predictor.add(tf.keras.layers.Dense(units=7, activation='linear')) # 7

# %%
ball_predictor.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])

# %% [markdown]
# ### Training

# %%
p1 = ball_predictor.fit(x_train, y_train, validation_split=0.2, batch_size = 32, epochs = 80,verbose=1)
# Out:
# Epoch 1/80
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.6212 - mean_squared_error: 0.6212 - val_loss: 0.3605 - val_mean_squared_error: 0.3605
# Epoch 2/80
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2743 - mean_squared_error: 0.2743 - val_loss: 0.2137 - val_mean_squared_error: 0.2137
# Epoch 3/80
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1760 - mean_squared_error: 0.1760 - val_loss: 0.1564 - val_mean_squared_error: 0.1564
# Epoch 4/80
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1297 - mean_squared_error: 0.1297 - val_loss: 0.1166 - val_mean_squared_error: 0.1166
# Epoch 5/80
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1049 - mean_squared_error: 0.1049 - val_loss: 0.0922 - val_mean_squared_error: 0.0922
# Epoch 6/80
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0893 - mean_squared_error: 0.0893 - val_loss: 0.0851 - val_mean_squared_error: 0.0851
# Epoch 7/80
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.
80
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0295 - mean_squared_error: 0.0295 - val_loss: 0.0348 - val_mean_squared_error: 0.0348
# Epoch 64/80
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0306 - mean_squared_error: 0.0306 - val_loss: 0.0342 - val_mean_squared_error: 0.0342
# Epoch 65/80
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0333 - val_mean_squared_error: 0.0333
# Epoch 66/80
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0282 - mean_squared_error: 0.0282 - val_loss: 0.0352 - val_mean_squared_error: 0.0352
# Epoch 67/80
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0325 - val_mean_squared_error: 0.0325
# Epoch 68/80
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0289 - mean_squared_error: 0.0289 - val_loss: 0.0314 - val_mean_squared_error: 0.0314
# Epoch 69/80
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0270 - mean_squared_error: 0.0270 - val_loss: 0.0315 - val_mean_squared_error: 0.0315
# Epoch 70/80
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0275 - mean_squared_error: 0.0275 - val_loss: 0.0305 - val_mean_squared_error: 0.0305
# Epoch 71/80
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0277 - mean_squared_error: 0.0277 - val_loss: 0.0279 - val_mean_squared_error: 0.0279
# Epoch 72/80
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0278 - mean_squared_error: 0.0278 - val_loss: 0.0285 - val_mean_squared_error: 0.0285
# Epoch 73/80
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0275 - mean_squared_error: 0.0275 - val_loss: 0.0287 - val_mean_squared_error: 0.0287
# Epoch 74/80
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0267 - mean_squared_error: 0.0267 - val_loss: 0.0333 - val_mean_squared_error: 0.0333
# Epoch 75/80
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0282 - mean_squared_error: 0.0282 - val_loss: 0.0364 - val_mean_squared_error: 0.0364
# Epoch 76/80
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0265 - mean_squared_error: 0.0265 - val_loss: 0.0330 - val_mean_squared_error: 0.0330
# Epoch 77/80
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0283 - mean_squared_error: 0.0283 - val_loss: 0.0327 - val_mean_squared_error: 0.0327
# Epoch 78/80
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0250 - mean_squared_error: 0.0250 - val_loss: 0.0319 - val_mean_squared_error: 0.0319
# Epoch 79/80
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0276 - mean_squared_error: 0.0276 - val_loss: 0.0310 - val_mean_squared_error: 0.0310
# Epoch 80/80
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0268 - mean_squared_error: 0.0268 - val_loss: 0.0351 - val_mean_squared_error: 0.0351

# %% [markdown]
# ### Learning Curves

# %%
fig, axs = plt.subplots(figsize=(16,5))
fig.suptitle('Loss Function')

axs.plot(p1.history['loss'])
axs.plot(p1.history['val_loss'])
axs.set_title("Ball Prediction Learning Curves")
axs.set(xlabel='Epoch', ylabel='Loss')

fig.legend(labels=['Train', 'Validation'], loc="upper left")
plt.show()

# %%
# def eval_regression(name, y_true, y_pred):
#     mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')
#     rmse = np.sqrt(mean_squared_error(y_true, y_pred, multioutput='raw_values'))
#     print(f"\n{name}")
#     print("MAE per output:", mae)
#     print("RMSE per output:", rmse)

# # If y is scaled, inverse-transform both y_true and y_pred before metrics.
# y_pred_all = ball_predictor.predict(x_test_all)
# y_pred_reach = ball_predictor.predict(x_test_reach)

# # Example for scaled targets:
# # y_pred_all = scy.inverse_transform(y_pred_all); y_test_all_eval = scy.inverse_transform(y_test_all)
# # y_pred_reach = scy.inverse_transform(y_pred_reach); y_test_reach_eval = scy.inverse_transform(y_test_reach)

# eval_regression("All test shots", y_test_all, y_pred_all)
# eval_regression("Reachable-only test shots", y_test_reach, y_pred_reach)

import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error

target_names = ["x_hit", "y_hit", "z_hit", "vx_hit", "vy_hit", "vz_hit", "t_hit"]
target_units = ["mm", "mm", "mm", "mm/s", "mm/s", "mm/s", "ms"]

def eval_with_units(name, model, x_eval, y_eval, y_scaler, y_is_scaled=True, t_hit_in_seconds=True):
    y_pred = model.predict(x_eval, verbose=0)

    # Convert to physical units exactly once
    if y_is_scaled:
        assert y_eval.shape[1] == y_scaler.n_features_in_ == len(target_names)
        y_true_u = y_scaler.inverse_transform(y_eval)
        y_pred_u = y_scaler.inverse_transform(y_pred)
    else:
        y_true_u = y_eval
        y_pred_u = y_pred

    err = y_pred_u - y_true_u
    abs_err = np.abs(err)

    mae = mean_absolute_error(y_true_u, y_pred_u, multioutput="raw_values")
    rmse = np.sqrt(mean_squared_error(y_true_u, y_pred_u, multioutput="raw_values"))
    std_abs = abs_err.std(axis=0)

    # Convert t_hit to ms for reporting (only if stored in seconds)
    if t_hit_in_seconds:
        i = target_names.index("t_hit")
        mae[i] *= 1000.0
        rmse[i] *= 1000.0
        std_abs[i] *= 1000.0

    report = pd.DataFrame({
        "target": target_names,
        "unit": target_units,
        "MAE": mae,
        "RMSE": rmse,
        "STD_abs_error": std_abs,
    })

    print(f"\n{name}")
    print(report.to_string(index=False, float_format=lambda v: f"{v:,.3f}"))

# Run both:
eval_with_units("All test shots", ball_predictor, x_test_all, y_test_all, scy, y_is_scaled=True, t_hit_in_seconds=True)
eval_with_units("Reachable-only test shots", ball_predictor, x_test_reach, y_test_reach, scy, y_is_scaled=True, t_hit_in_seconds=True)
# Out:
# All test shots
# target unit     MAE    RMSE  STD_abs_error
#  x_hit   mm  37.651  51.635         35.335
#  y_hit   mm  49.649  77.738         59.818
#  z_hit   mm  32.857  43.587         28.639
# vx_hit mm/s 129.200 162.164         98.002
# vy_hit mm/s  75.896  99.464         64.288
# vz_hit mm/s 257.166 549.374        485.467
#  t_hit   ms  12.183  18.330         13.696
#
# Reachable-only test shots
# target unit     MAE    RMSE  STD_abs_error
#  x_hit   mm  42.523  59.031         40.945
#  y_hit   mm  78.083 118.559         89.215
#  z_hit   mm  32.616  42.413         27.113
# vx_hit mm/s 133.032 163.387         94.857
# vy_hit mm/s  82.270 106.913         68.278
# vz_hit mm/s 303.596 654.587        579.926
#  t_hit   ms  15.823  23.681         17.620

# %%
# Verification 
train_std = scy.scale_ 
rmse_sigma = np.sqrt(0.1084)   # val_mse from curve, e.g. 0.1151
rmse_units = rmse_sigma * train_std

print(rmse_units)
# Out:
# [1.77799725e+02 9.70927615e+01 1.14991837e+02 7.06416397e+02
#  4.53896914e+02 5.90667127e+02 3.65534503e-02]

# %% [markdown]
# ## Loading the Matched Synthetic Dataset (Transfer Learning)

# %%
import pandas as pd
from pathlib import Path

matched_dataset_path = Path("../learning_data/synthetic_matched_data/synthetic_intercept_dataset_new.csv")
if not matched_dataset_path.exists():
    raise FileNotFoundError(f"Matched synthetic dataset not found: {matched_dataset_path}")

print(f"Using matched synthetic dataset: {matched_dataset_path}")
matched_dataset = pd.read_csv(matched_dataset_path)
print(f"matched rows: {len(matched_dataset)}")
matched_dataset.info()
# Out:
# Using matched synthetic dataset: ..\learning_data\synthetic_matched_data\synthetic_intercept_dataset_new.csv
# matched rows: 15000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 41 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   x1                     15000 non-null  float64
#  1   y1                     15000 non-null  float64
#  2   z1                     15000 non-null  float64
#  3   x2                     15000 non-null  float64
#  4   y2                     15000 non-null  float64
#  5   z2                     15000 non-null  float64
#  6   x3                     15000 non-null  float64
#  7   y3                     15000 non-null  float64
#  8   z3                     15000 non-null  float64
#  9   x4                     15000 non-null  float64
#  10  y4                     15000 non-null  float64
#  11  z4                     15000 non-null  float64
#  12  x5                     15000 non-null  float64
#  13  y5                     15000 non-null  float64
#  14  z5                     15000 non-null  float64
#  15  x6                     15000 non-null  float64
#  16  y6                     15000 non-null  float64
#  17  z6                     15000 non-null  float64
#  18  dt12                   15000 non-null  float64
#  19  dt23                   15000 non-null  float64
#  20  dt34                   15000 non-null  float64
#  21  dt45                   15000 non-null  float64
#  22  dt56                   15000 non-null  float64
#  23  x_hit                  15000 non-null  float64
#  24  y_hit                  15000 non-null  float64
#  25  z_hit                  15000 non-null  float64
#  26  vx_hit                 15000 non-null  float64
#  27  vy_hit                 15000 non-null  float64
#  28  vz_hit                 15000 non-null  float64
#  29  t_hit                  15000 non-null  float64
#  30  is_reachable           15000 non-null  float64
#  31  bounces_before_hit     15000 non-null  float64
#  32  has_bounce_before_hit  15000 non-null  float64
#  33  intercept_valid        15000 non-null  float64
#  34  x0                     15000 non-null  float64
#  35  y0                     15000 non-null  float64
#  36  z0                     15000 non-null  float64
#  37  vx0                    15000 non-null  float64
#  38  vy0                    15000 non-null  float64
#  39  vz0                    15000 non-null  float64
#  40  gravity_z_mm_s2        15000 non-null  float64
# dtypes: float64(41)
# memory usage: 4.7 MB

# %%
input_cols_6 = [
    "x1", "y1", "z1",
    "x2", "y2", "z2",
    "x3", "y3", "z3",
    "x4", "y4", "z4",
    "x5", "y5", "z5",
    "x6", "y6", "z6",
    "dt12", "dt23", "dt34", "dt45", "dt56",
]
target_cols = ["x_hit", "y_hit", "z_hit", "vx_hit", "vy_hit", "vz_hit", "t_hit"]

x_matched = matched_dataset[input_cols_6]
y_matched = matched_dataset[target_cols]


# View the inputs
print(x_matched)
print(y_matched)

x_matched = x_matched.values
y_matched = y_matched.values
# Out:
#                x1           y1           z1          x2           y2  \
# 0       62.782314  2057.281123  -612.060880   95.317932  2010.625484
# 1     -255.217922  2024.200406 -1108.952615 -289.547850  1980.630025
# 2     -311.497537  2045.749020 -1084.063377 -365.901547  2000.867483
# 3      197.924197  2047.131928 -1109.882367  241.874037  1965.225265
# 4       27.763058  2045.846336 -1072.465856   43.930100  2002.996411
# ...           ...          ...          ...         ...          ...
# 14995 -354.846713  1941.309089  -934.184073 -373.493899  1877.141631
# 14996  494.425326  2030.116053 -1017.921022  503.246693  1974.629658
# 14998  -566.932845   165.629983  -880.050822 -2081.208662 -6256.269352
# 14999  1170.074994  1005.713471 -1049.890461  3328.325577 -4237.271538
#
#             vz_hit     t_hit
# 0      1618.174348  0.334256
# 1      -334.005539  0.257014
# 2      3353.643101  0.090640
# 3      1024.851204  0.263435
# 4     -2706.597183  0.531904
# ...            ...       ...
# 14995  -139.605313  0.416354
# 14996 -1894.495828  0.412407
# 14997    96.878957  0.272492
# 14998 -2733.260171  0.183551
# 14999 -3089.661426  0.151191
#
# [15000 rows x 7 columns]

# %%
#Split input and output x, y
x_matched_train, x_matched_test, y_matched_train, y_matched_test= train_test_split(
    x_matched, y_matched,
    test_size=0.1,
    random_state=1
    
)

# %%
print(x_matched_train.shape)
print(x_matched_test.shape)
print(y_matched_train.shape)
print(y_matched_test.shape)

x_matched_train_s = scx.transform(x_matched_train)
x_matched_test_s = scx.transform(x_matched_test)
y_matched_train_s = scy.transform(y_matched_train)
y_matched_test_s = scy.transform(y_matched_test)
# Out:
# (13500, 23)
# (1500, 23)
# (13500, 7)
# (1500, 7)

# %%
# from tensorflow.keras.optimizers import Adam
# import tensorflow as tf

# # Start from synthetic-pretrained weights
# transfer_model_matched = tf.keras.models.clone_model(ball_predictor)
# transfer_model_matched.set_weights(ball_predictor.get_weights())

# # Freezing layers
# for layer in transfer_model_matched.layers[:1]:
#     layer.trainable = False

# transfer_model_matched.compile(
#     loss="mean_squared_error",
#     optimizer=Adam(learning_rate=1e-3),
#     metrics=["mean_squared_error"]
# )

# history_matched = transfer_model_matched.fit(
#     x_matched_train_s, y_matched_train_s,
#     validation_split=0.2,
#     epochs=100,
#     verbose=1
# )

## Regularization
import tensorflow as tf
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam

# Try 1e-5 first; then tune [1e-6, 1e-5, 5e-5]
L2_LAMBDA = 1e-5

dense_total = sum(isinstance(l, tf.keras.layers.Dense) for l in ball_predictor.layers)
dense_seen = {"n": 0}

def clone_with_l2(layer):
    cfg = layer.get_config()
    if isinstance(layer, tf.keras.layers.Dense):
        dense_seen["n"] += 1
        is_output_layer = (dense_seen["n"] == dense_total)
        if not is_output_layer:  # regularize hidden layers only
            cfg["kernel_regularizer"] = regularizers.serialize(regularizers.l2(L2_LAMBDA))
    return layer.__class__.from_config(cfg)

# Start from broad pretrained model, but with L2 regularization added
transfer_model_matched = tf.keras.models.clone_model(
    ball_predictor,
    clone_function=clone_with_l2
)
transfer_model_matched.set_weights(ball_predictor.get_weights())

# for layer in transfer_model_matched.layers[:3]:
#     layer.trainable = False

transfer_model_matched.compile(
    loss="mean_squared_error",
    optimizer=Adam(learning_rate=1e-4),
    metrics=["mean_squared_error"]
)

history_matched = transfer_model_matched.fit(
    x_matched_train_s, y_matched_train_s,
    validation_split=0.2,
    epochs=100,
    verbose=1
)
# Out:
# Epoch 1/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0600 - mean_squared_error: 0.0563 - val_loss: 0.0489 - val_mean_squared_error: 0.0453
# Epoch 2/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0507 - mean_squared_error: 0.0471 - val_loss: 0.0458 - val_mean_squared_error: 0.0422
# Epoch 3/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.
100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0286 - mean_squared_error: 0.0254 - val_loss: 0.0375 - val_mean_squared_error: 0.0343
# Epoch 87/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0286 - mean_squared_error: 0.0254 - val_loss: 0.0380 - val_mean_squared_error: 0.0348
# Epoch 88/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0282 - mean_squared_error: 0.0250 - val_loss: 0.0360 - val_mean_squared_error: 0.0328
# Epoch 89/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0285 - mean_squared_error: 0.0253 - val_loss: 0.0368 - val_mean_squared_error: 0.0336
# Epoch 90/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0283 - mean_squared_error: 0.0251 - val_loss: 0.0375 - val_mean_squared_error: 0.0343
# Epoch 91/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0280 - mean_squared_error: 0.0248 - val_loss: 0.0370 - val_mean_squared_error: 0.0338
# Epoch 92/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0279 - mean_squared_error: 0.0247 - val_loss: 0.0371 - val_mean_squared_error: 0.0339
# Epoch 93/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0282 - mean_squared_error: 0.0250 - val_loss: 0.0382 - val_mean_squared_error: 0.0350
# Epoch 94/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0278 - mean_squared_error: 0.0246 - val_loss: 0.0358 - val_mean_squared_error: 0.0326
# Epoch 95/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0278 - mean_squared_error: 0.0246 - val_loss: 0.0393 - val_mean_squared_error: 0.0361
# Epoch 96/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0278 - mean_squared_error: 0.0246 - val_loss: 0.0367 - val_mean_squared_error: 0.0335
# Epoch 97/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0279 - mean_squared_error: 0.0247 - val_loss: 0.0362 - val_mean_squared_error: 0.0330
# Epoch 98/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0279 - mean_squared_error: 0.0247 - val_loss: 0.0355 - val_mean_squared_error: 0.0323
# Epoch 99/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0281 - mean_squared_error: 0.0249 - val_loss: 0.0369 - val_mean_squared_error: 0.0337
# Epoch 100/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0276 - mean_squared_error: 0.0244 - val_loss: 0.0377 - val_mean_squared_error: 0.0345

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12,4))
ax.plot(history_matched.history["loss"], label="Train")
ax.plot(history_matched.history["val_loss"], label="Validation")
ax.set_title("Matched Synthetic Data Learning Curves")
ax.set_xlabel("Epoch")
ax.set_ylabel("Loss")
ax.legend()
plt.show()

# %%
eval_with_units(
    "Matched Data Transfer Model",
    transfer_model_matched,
    x_matched_test_s,
    y_matched_test_s,
    scy,
    y_is_scaled=True,
    t_hit_in_seconds=True
)
# Out:
# Matched Data Transfer Model
# target unit     MAE    RMSE  STD_abs_error
#  x_hit   mm  34.097  45.598         30.275
#  y_hit   mm  46.609  70.386         52.743
#  z_hit   mm  38.512  50.917         33.307
# vx_hit mm/s 105.175 133.921         82.903
# vy_hit mm/s  83.898 106.782         66.056
# vz_hit mm/s 262.522 591.433        529.976
#  t_hit   ms  13.456  19.917         14.684

# %% [markdown]
# ## Loading the Real Dataset (Transfer Learning)

# %%
import pandas as pd
from pathlib import Path

real_dataset_path = Path("../learning_data/real_data/real_transfer_true_xyz_6pt_clean.csv")
if not real_dataset_path.exists():
    raise FileNotFoundError(f"Real cleaned dataset not found: {real_dataset_path}")

print(f"Using real cleaned dataset: {real_dataset_path}")
real_dataset = pd.read_csv(real_dataset_path)
print(f"real rows: {len(real_dataset)}")
real_dataset.info()
# Out:
# Using real cleaned dataset: ..\learning_data\real_data\real_transfer_true_xyz_6pt_clean.csv
# real rows: 293
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293 entries, 0 to 292
# Data columns (total 40 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   sample_id                             293 non-null    int64
#  1   captured_at                           293 non-null    object
#  2   x1                                    293 non-null    float64
#  3   y1                                    293 non-null    float64
#  4   z1                                    293 non-null    float64
#  5   x2                                    293 non-null    float64
#  6   y2                                    293 non-null    float64
#  7   z2                                    293 non-null    float64
#  8   x3                                    293 non-null    float64
#  9   y3                                    293 non-null    float64
#  10  z3                                    293 non-null    float64
#  11  x4                                    293 non-null    float64
#  12  y4                                    293 non-null    float64
#  13  z4                                    293 non-null    float64
#  14  x5                                    293 non-null    float64
#  15  y5                                    293 non-null    float64
#  16  z5                                    293 non-null    float64
#  17  x6                                    293 non-null    float64
#  18  y6                                    293 non-null    float64
#  19  z6                                    293 non-null    float64
#  20  dt12                                  293 non-null    float64
#  21  dt23                                  293 non-null    float64
#  22  dt34                                  293 non-null    float64
#  23  dt45                                  293 non-null    float64
#  24  dt56                                  293 non-null    float64
#  25  x_hit                                 293 non-null    float64
#  26  y_hit                                 293 non-null    float64
#  27  z_hit                                 293 non-null    float64
#  28  vx_hit                                293 non-null    float64
#  29  vy_hit                                293 non-null    float64
#  30  vz_hit                                293 non-null    float64
#  31  t_hit                                 293 non-null    float64
#  32  is_reachable                          293 non-null    float64
#  33  intercept_valid                       293 non-null    float64
#  34  bounces_before_hit                    293 non-null    float64
#  35  has_bounce_before_hit                 293 non-null    float64
#  36  hit_obs_index                         293 non-null    float64
#  37  hit_obs_in_workspace                  293 non-null    float64
#  38  hit_obs_selected_from_workspace_pool  293 non-null    float64
#  39  hit_center_dist_mm                    293 non-null    float64
# dtypes: float64(38), int64(1), object(1)
# memory usage: 91.7+ KB

# %%
real_dataset.describe()
# Out:
#         sample_id          x1           y1           z1          x2  \
# count  293.000000  293.000000   293.000000   293.000000  293.000000
# mean   158.569966   67.937748  2201.097693  -731.906596   72.013885
# std     91.397742  303.757984   287.344863   189.804736  297.252100
# min      1.000000 -598.301113  -454.643273 -1180.956522 -579.514017
# 25%     82.000000 -183.331617  2145.070293  -907.206703 -184.243794
# 50%    157.000000   29.589611  2256.274062  -689.644557   35.342004
# 75%    235.000000  339.054214  2348.810515  -596.429584  318.524115
# max    323.000000  902.243018  2451.031897  -290.554317  781.956709
#
#                 y2           z2          x3           y3           z3  ...  \
# count   293.000000   293.000000  293.000000   293.000000   293.000000  ...
# mean   2115.967534  -741.948908   73.081668  2034.319263  -751.844233  ...
# std     280.571266   194.654799  292.150005   275.166338   196.510719  ...
# min    -446.537919 -1178.255555 -551.976584  -451.100210 -1184.921871  ...
# 25%    2065.854702  -909.077250 -166.455223  1988.744936  -906.993997  ...
# 50%    2168.244560  -687.288567   44.012786  2082.911829  -698.411145  ...
# 75%    2255.066160  -597.913748  303.667682  2167.218708  -610.133633  ...
# max    2388.775703  -330.595381  790.827727  2316.139011  -369.448247  ...
#
#             vz_hit       t_hit  is_reachable  intercept_valid  \
# count   293.000000  293.000000    293.000000            293.0
# mean     27.084364    0.524883      0.894198              1.0
# std    1316.970065    0.196044      0.308110              0.0
# min   -4931.714676    0.080021      0.000000              1.0
# 25%   -1063.995813    0.415339      1.000000              1.0
# 50%     117.749985    0.495668      1.000000              1.0
# 75%    1208.496554    0.604520      1.000000              1.0
# max    2801.682729    1.892035      1.000000              1.0
#
#        bounces_before_hit  has_bounce_before_hit  hit_obs_index  \
# count          293.000000             293.000000     293.000000
# mean             0.088737               0.088737      37.843003
# std              0.284851               0.284851      10.927654
# min              0.000000               0.000000      10.000000
# 25%              0.000000               0.000000      31.000000
# 50%              0.000000               0.000000      37.000000
# 75%              0.000000               0.000000      43.000000
# max              1.000000               1.000000      92.000000
#
#        hit_obs_in_workspace  hit_obs_selected_from_workspace_pool  \
# count            293.000000                            293.000000
# mean               0.894198                              0.894198
# std                0.308110                              0.308110
# min                0.000000                              0.000000
# 25%                1.000000                              1.000000
# 50%                1.000000                              1.000000
# 75%                1.000000                              1.000000
# max                1.000000                              1.000000
#
#        hit_center_dist_mm
# count          293.000000
# mean           338.293158
# std            223.387618
# min              6.334217
# 25%            173.650438
# 50%            301.895497
# 75%            456.604422
# max           1513.950066
#
# [8 rows x 39 columns]

# %% [markdown]
# ### Pre-Processing the Real Dataset

# %%
input_cols_6 = [
    "x1", "y1", "z1",
    "x2", "y2", "z2",
    "x3", "y3", "z3",
    "x4", "y4", "z4",
    "x5", "y5", "z5",
    "x6", "y6", "z6",
    "dt12", "dt23", "dt34", "dt45", "dt56",
]
target_cols = ["x_hit", "y_hit", "z_hit", "vx_hit", "vy_hit", "vz_hit", "t_hit"]

x_real = real_dataset[input_cols_6]
y_real = real_dataset[target_cols]

# %%
# View the inputs
print(x_real)
# Out:
#              x1           y1           z1          x2           y2  \
# 0    -90.491715  2367.800266  -916.990844  -55.894581  2273.066741
# 1    461.634882  2140.277963 -1073.795995  454.063902  2086.468000
# 2    421.515221  2176.435601 -1041.177375  412.187513  2116.107869
# 3    171.279780  2243.360489  -688.233271  190.050059  2173.424327
# 4    228.686963  2181.511376  -518.696314  236.114838  2104.908337
# ..          ...          ...          ...         ...          ...
# 288  177.969000  1756.206724  -792.645737  157.111312  1669.138101
# 289 -261.385294  1147.100126  -789.493898 -292.460925  1060.850327
# 290  134.268440  2214.744820  -745.822122  138.167993  2090.633710
# 291 -158.796664  2273.096013  -663.306831 -134.711965  2141.913383
# 292  -46.359877  2316.732766  -644.515080    7.563078  2186.901628
#
#               z2          x3           y3           z3          x4  ...  \
# 0    -948.543017  -62.987701  2188.507166  -994.981357  -60.350077  ...
# 1   -1071.620664  449.725030  2040.002438 -1028.579191  456.277085  ...
# 2    -998.944444  391.577015  2062.332935  -969.214716  387.556829  ...
# 3    -694.700858  184.344766  2106.068753  -703.221103  179.143708  ...
# 4    -513.970504  242.731202  2030.735794  -511.632270  260.155155  ...
# ..           ...         ...          ...          ...         ...  ...
# 288  -801.949227  438.827522  1551.651536  -755.912639  450.065495  ...
# 289  -805.913396 -314.447074   978.124510  -822.249655   -8.615257  ...
# 290  -751.922053  155.947883  1960.108427  -763.491681  195.374704  ...
# 291  -670.622045 -130.244202  2019.109150  -680.199522 -135.713379  ...
ataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
import numpy as np

# Stratify real split by reachability so train/test have similar reachable mix.
r_real = real_dataset["is_reachable"].to_numpy().astype(int)
stratify_real = r_real if len(np.unique(r_real)) > 1 else None

x_real_train, x_real_test, y_real_train, y_real_test, r_real_train, r_real_test = train_test_split(
    x_real, y_real, r_real,
    test_size=0.1,
    random_state=1,
    stratify=stratify_real,
)

# %%
print(x_real_train.shape)
print(x_real_test.shape)
print(y_real_train.shape)
print(y_real_test.shape)

print("real reachability split:")
print("  train reachable frac:", (r_real_train == 1).mean())
print("  test reachable frac:", (r_real_test == 1).mean())
# Out:
# (263, 23)
# (30, 23)
# (263, 7)
# (30, 7)
# real reachability split:
#   train reachable frac: 0.8935361216730038
#   test reachable frac: 0.9

# %% [markdown]
# ### Scaling the real dataset

# %%
x_real_train_s = scx.transform(x_real_train)
x_real_test_s = scx.transform(x_real_test)
y_real_train_s = scy.transform(y_real_train)
y_real_test_s = scy.transform(y_real_test)

# %%
# ### WEighting the xyz more than velocities

# # Output order must match your y columns:
# # [x_hit, y_hit, z_hit, vx_hit, vy_hit, vz_hit, t_hit]
# raw_w = tf.constant([10.0, 10.0, 10.0, 1.0, 1.0, 1.0, 5.0], dtype=tf.float32)

# # normalize so average weight is ~1 (keeps loss scale stable)
# output_weights = raw_w / tf.reduce_mean(raw_w)

# def weighted_mse(y_true, y_pred):
#     err2 = tf.square(y_true - y_pred)              # (batch, 7)
#     weighted_err2 = err2 * output_weights          # broadcast on 7 outputs
#     return tf.reduce_mean(weighted_err2)

# %% [markdown]
# ## Training the New Layers (Classification Layers)

# %%
# Start from synthetic-pretrained weights
transfer_model = tf.keras.models.clone_model(transfer_model_matched)
transfer_model.set_weights(transfer_model_matched.get_weights())

# Stage 1: freeze first 2 layers
for layer in transfer_model.layers[:4]:
    layer.trainable = False

transfer_model.compile(
    loss="mean_squared_error",
    optimizer=Adam(learning_rate=5e-4),
    metrics=["mean_squared_error"]
)

# ###Weighted 
# transfer_model.compile(
#     loss=weighted_mse,
#     optimizer=Adam(learning_rate=5e-4),
#     metrics=["mean_squared_error"]  # still logs normal MSE too
# )


history_stage1 = transfer_model.fit(
    x_real_train_s, y_real_train_s,
    validation_split=0.2,
    epochs=150,
    verbose=1
)
# Out:
# Epoch 1/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.6100 - mean_squared_error: 1.6097 - val_loss: 1.3186 - val_mean_squared_error: 1.3183
# Epoch 2/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.2790 - mean_squared_error: 1.2787 - val_loss: 1.0666 - val_mean_squared_error: 1.0663
# Epoch 3/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0514 - mean_squared_error: 1.0511 - val_loss: 0.9033 - val_mean_squared_error: 0.9029
# Epoch 4/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9156 - mean_squared_error: 0.9153 - val_loss: 0.8097 - val_mean_squared_error: 0.8094
# Epoch 5/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8387 - mean_squared_error: 0.8384 - val_loss: 0.7609 - val_mean_squared_error: 0.7606
# Epoch 6/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8080 - mean_squared_error: 0.8077 - val_loss: 0.7338 - val_mean_squared_error: 0.7335
# Epoch 7/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7847 - mean_squared_error: 0.7843 - val_loss: 0.7149 - val_mean_squared_error: 0.7146
# Epoch 8/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7691 - mean_squared_error: 0.7688 - val_loss: 0.7004 - val_mean_squared_error: 0.7001
# Epoch 9/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7548 - mean_squared_error: 0.7545 - val_loss: 0.6896 - val_mean_squared_error: 0.6893
# Epoch 10/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0
150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5797 - mean_squared_error: 0.5794 - val_loss: 0.5579 - val_mean_squared_error: 0.5576
# Epoch 67/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5795 - mean_squared_error: 0.5792 - val_loss: 0.5583 - val_mean_squared_error: 0.5580
# Epoch 68/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5773 - mean_squared_error: 0.5770 - val_loss: 0.5574 - val_mean_squared_error: 0.5571
# Epoch 69/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5760 - mean_squared_error: 0.5757 - val_loss: 0.5580 - val_mean_squared_error: 0.5577
# Epoch 70/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5748 - mean_squared_error: 0.5745 - val_loss: 0.5575 - val_mean_squared_error: 0.5572
# Epoch 71/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5739 - mean_squared_error: 0.5736 - val_loss: 0.5564 - val_mean_squared_error: 0.5561
# Epoch 72/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5732 - mean_squared_error: 0.5729 - val_loss: 0.5542 - val_mean_squared_error: 0.5539
# Epoch 73/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5717 - mean_squared_error: 0.5714 - val_loss: 0.5544 - val_mean_squared_error: 0.5541
# Epoch 74/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5712 - mean_squared_error: 0.5709 - val_loss: 0.5545 - val_mean_squared_error: 0.5542
# Epoch 75/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5701 - mean_squared_error: 0.5698 - val_loss: 0.5538 - val_mean_squared_error: 0.5535
# Epoch 76/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5687 - mean_squared_error: 0.5684 - val_loss: 0.5529 - val_mean_squared_error: 0.5526
# Epoch 77/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5683 - mean_squared_error: 0.5680 - val_loss: 0.5533 - val_mean_squared_error: 0.5530
# Epoch 78/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5672 - mean_squared_error: 0.5669 - val_loss: 0.5544 - val_mean_squared_error: 0.5541
# Epoch 79/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5663 - mean_squared_error: 0.5660 - val_loss: 0.5549 - val_mean_squared_error: 0.5546
# Epoch 80/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5653 - mean_squared_error: 0.5650 - val_loss: 0.5530 - val_mean_squared_error: 0.5527
# Epoch 81/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5644 - mean_squared_error: 0.5641 - val_loss: 0.5526 - val_mean_squared_error: 0.5523
# Epoch 82/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5635 - mean_squared_error: 0.5632 - val_loss: 0.5531 - val_mean_squared_error: 0.5528
# Epoch 83/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5631 - mean_squared_error: 0.5628 - val_loss: 0.5518 - val_mean_squared_error: 0.5515
# Epoch 84/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5619 - mean_squared_error: 0.5616 - val_loss: 0.5507 - val_mean_squared_error: 0.5504
# Epoch 85/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5612 - mean_squared_error: 0.5610 - val_loss: 0.5506 - val_mean_squared_error: 0.5503
# Epoch 86/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5608 - mean_squared_error: 0.5605 - val_loss: 0.5503 - val_mean_squared_error: 0.5500
# Epoch 87/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5593 - mean_squared_error: 0.5590 - val_loss: 0.5491 - val_mean_squared_error: 0.5488
# Epoch 88/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5589 - mean_squared_error: 0.5586 - val_loss: 0.5493 - val_mean_squared_error: 0.5490
# Epoch 89/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5581 - mean_squared_error: 0.5578 - val_loss: 0.5516 - val_mean_squared_error: 0.5513
# Epoch 90/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5575 - mean_squared_error: 0.5572 - val_loss: 0.5495 - val_mean_squared_error: 0.5492
# Epoch 91/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5567 - mean_squared_error: 0.5564 - val_loss: 0.5495 - val_mean_squared_error: 0.5492
# Epoch 92/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5557 - mean_squared_error: 0.5554 - val_loss: 0.5493 - val_mean_squared_error: 0.5490
# Epoch 93/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.
150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5220 - mean_squared_error: 0.5217 - val_loss: 0.5491 - val_mean_squared_error: 0.5488
# Epoch 150/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5220 - mean_squared_error: 0.5217 - val_loss: 0.5479 - val_mean_squared_error: 0.5476

# %% [markdown]
# ## Stage 1 Validation Curve

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12,4))
ax.plot(history_stage1.history["loss"], label="Train")
ax.plot(history_stage1.history["val_loss"], label="Validation")
ax.set_title("Stage 1 Learning Curves")
ax.set_xlabel("Epoch")
ax.set_ylabel("Loss")
ax.legend()
plt.show()

# %%
eval_with_units(
    "Stage 1 Transfer Model - Real Test",
    transfer_model,
    x_real_test_s,
    y_real_test_s,
    scy,
    y_is_scaled=True,
    t_hit_in_seconds=True
)
# Out:
# Stage 1 Transfer Model - Real Test
# target unit     MAE    RMSE  STD_abs_error
#  x_hit   mm 111.441 228.169        199.103
#  y_hit   mm  92.753 117.466         72.077
#  z_hit   mm  82.596 104.750         64.424
# vx_hit mm/s 390.633 564.673        407.751
# vy_hit mm/s 418.680 557.809        368.589
# vz_hit mm/s 814.678 924.268        436.545
#  t_hit   ms  63.397  96.524         72.785

# %%
def snapshot_model(model):
    m = tf.keras.models.clone_model(model)
    m.set_weights(model.get_weights())
    return m

# # Weighted Version
# def snapshot_model(model):
#     with tf.keras.utils.custom_object_scope({'weighted_mse': weighted_mse}):
#         m = tf.keras.models.clone_model(model)
#     m.set_weights(model.get_weights())
#     return m
    
# --- run this RIGHT AFTER stage 1 training/eval ---
stage1_model = snapshot_model(transfer_model)
print("Saved stage1_model snapshot.")
# Out:
# Saved stage1_model snapshot.

# %%
# Stage 2: unfreeze all layers
for layer in transfer_model.layers:
    layer.trainable = True

transfer_model.compile(
    loss="mean_squared_error",
    optimizer=Adam(learning_rate=1e-5),
    metrics=["mean_squared_error"]
)

# ###Weighted 
# transfer_model.compile(
#     loss=weighted_mse,
#     optimizer=Adam(learning_rate=1e-5),
#     metrics=["mean_squared_error"]
# )


history_stage2 = transfer_model.fit(
    x_real_train_s, y_real_train_s,
    validation_split=0.2,
    epochs=150,
    verbose=1
)
# Out:
# Epoch 1/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.5237 - mean_squared_error: 0.5205 - val_loss: 0.5507 - val_mean_squared_error: 0.5475
# Epoch 2/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5230 - mean_squared_error: 0.5198 - val_loss: 0.5502 - val_mean_squared_error: 0.5470
# Epoch 3/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5225 - mean_squared_error: 0.5193 - val_loss: 0.5499 - val_mean_squared_error: 0.5467
# Epoch 4/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5219 - mean_squared_error: 0.5187 - val_loss: 0.5497 - val_mean_squared_error: 0.5465
# Epoch 5/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5214 - mean_squared_error: 0.5182 - val_loss: 0.5494 - val_mean_squared_error: 0.5462
# Epoch 6/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5209 - mean_squared_error: 0.5177 - val_loss: 0.5493 - val_mean_squared_error: 0.5462
# Epoch 7/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5204 - mean_squared_error: 0.5172 - val_loss: 0.5492 - val_mean_squared_error: 0.5460
# Epoch 8/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5199 - mean_squared_error: 0.5167 - val_loss: 0.5492 - val_mean_squared_error: 0.5460
# Epoch 9/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5195 - mean_squared_error: 0.5163 - val_loss: 0.5489 - val_mean_squared_error: 0.5457
# Epoch 10/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5190 - mean_squared_error: 0.5158 - val_loss: 0.5488 - val_mean_squared_error: 0.5456
# Epoch 11/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5186 - mean_squared_error: 0.5154 - val_loss: 0.5486 - val_mean_squared_error: 0.5454
# Epoch 12/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5181 - mean_squared_error: 0.5150 - val_loss: 0.5485 - val_mean_squared_error: 0.5454
# Epoch 13/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5178 - mean_squared_error: 0.5146 - val_loss: 0.5484 - val_mean_squared_error: 0.5453
# Epoch 14/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5173 - mean_squared_error: 0.5141 - val_loss: 0.5484 - val_mean_squared_error: 0.5452
# Epoch 15/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5169 - mean_squared_error: 0.5137 - val_loss: 0.5483 - val_mean_squared_error: 0.5452
# Epoch 16/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5164 - mean_squared_error: 0.5132 - val_loss: 0.5482 - val_mean_squared_error: 0.5451
# Epoch 17/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5160 - mean_squared_error: 0.5128 - val_loss: 0.5481 - val_mean_squared_error: 0.5449
# Epoch 18/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5156 - mean_squared_error: 0.5124 - val_loss: 0.5480 - val_mean_squared_error: 0.5448
# Epoch 19/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5152 - mean_squared_error: 0.5120 - val_loss: 0.5477 - val_mean_squared_error: 0.5446
# Epoch 20/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5147 - mean_squared_error: 0.5116 - val_loss: 0.5477 - val_mean_squared_error: 0.5445
# Epoch 21/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5144 - mean_squared_error: 0.5112 - val_loss: 0.5476 - val_mean_squared_error: 0.5445
# Epoch 22/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5140 - mean_squared_error: 0.5109 - val_loss: 0.5475 - val_mean_squared_error: 0.5444
# Epoch 23/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5136 - mean_squared_error: 0.5104 - val_loss: 0.5476 - val_mean_squared_error: 0.5445
# Epoch 24/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5132 - mean_squared_error: 0.5100 - val_loss: 0.5474 - val_mean_squared_error: 0.5443
# Epoch 25/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5128 - mean_squared_error: 0.5096 - val_loss: 0.5477 - val_mean_squared_error: 0.5445
# Epoch 26/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5125 - mean_squared_error: 0.5093 - val_loss: 0.5478 - val_mean_squared_error: 0.5446
# Epoch 27/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5120 - mean_squared_error: 0.5088 - val_loss: 0.5472 - val_mean_squared_error: 0.5441
# Epoch 28/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5117 - mean_squared_error: 0.5086 - val_loss: 0.5469 - val_mean_squared_error: 0.5438
# Epoch 29/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5113 - mean_squared_error: 0.5081 - val_loss: 0.5471 - val_mean_squared_error: 0.5440
# Epoch 30/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5108 - mean_squared_error: 0.5076 - val_loss: 0.5470 - val_mean_squared_error: 0.5438
# Epoch 31/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5105 - mean_squared_error: 0.5073 - val_loss: 0.5471 - val_mean_squared_error: 0.5439
# Epoch 32/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5101 - mean_squared_error: 0.5069 - val_loss: 0.5469 - val_mean_squared_error: 0.5437
# Epoch 33/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5098 - mean_squared_error: 0.5066 - val_loss: 0.5464 - val_mean_squared_error: 0.5432
# Epoch 34/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5092 - mean_squared_error: 0.5061 - val_loss: 0.5463 - val_mean_squared_error: 0.5431
# Epoch 35/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5089 - mean_squared_error: 0.5057 - val_loss: 0.5464 - val_mean_squared_error: 0.5432
# Epoch 36/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5085 - mean_squared_error: 0.5053 - val_loss: 0.5464 - val_mean_squared_error: 0.5432
# Epoch 37/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.
150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4755 - mean_squared_error: 0.4723 - val_loss: 0.5443 - val_mean_squared_error: 0.5411
# Epoch 149/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4753 - mean_squared_error: 0.4722 - val_loss: 0.5444 - val_mean_squared_error: 0.5412
# Epoch 150/150
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4750 - mean_squared_error: 0.4718 - val_loss: 0.5446 - val_mean_squared_error: 0.5414

# %%
fig, ax = plt.subplots(figsize=(12,4))
ax.plot(history_stage2.history["loss"], label="Train")
ax.plot(history_stage2.history["val_loss"], label="Validation")
ax.set_title("Stage 2 Learning Curves")
ax.set_xlabel("Epoch")
ax.set_ylabel("Loss")
ax.legend()
plt.show()

# %%
eval_with_units(
    "Stage 2 Final Transfer Model - Real Test",
    transfer_model,
    x_real_test_s,
    y_real_test_s,
    scy,
    y_is_scaled=True,
    t_hit_in_seconds=True
)
# Out:
# Stage 2 Final Transfer Model - Real Test
# target unit     MAE    RMSE  STD_abs_error
#  x_hit   mm 112.547 216.248        184.651
#  y_hit   mm  94.544 119.242         72.664
#  z_hit   mm  80.032 101.765         62.856
# vx_hit mm/s 342.377 520.444        391.969
# vy_hit mm/s 427.878 551.765        348.374
# vz_hit mm/s 815.304 933.598        454.844
#  t_hit   ms  63.711 101.010         78.383

# %%
stage2_model = snapshot_model(transfer_model)
print("Saved stage2_model snapshot.")

# --- run once (any time after broad + matched are trained) ---
broad_model = snapshot_model(ball_predictor)
matched_model = snapshot_model(transfer_model_matched)
print("Saved broad_model and matched_model snapshots.")
# Out:
# Saved stage2_model snapshot.
# Saved broad_model and matched_model snapshots.

# %%
# --- final comparison on real test set ---
eval_with_units("Broad model - Real Test",   broad_model,   x_real_test_s, y_real_test_s, scy, y_is_scaled=True, t_hit_in_seconds=True)
eval_with_units("Matched model - Real Test", matched_model, x_real_test_s, y_real_test_s, scy, y_is_scaled=True, t_hit_in_seconds=True)
eval_with_units("Stage 1 model - Real Test", stage1_model,  x_real_test_s, y_real_test_s, scy, y_is_scaled=True, t_hit_in_seconds=True)
eval_with_units("Stage 2 model - Real Test", stage2_model,  x_real_test_s, y_real_test_s, scy, y_is_scaled=True, t_hit_in_seconds=True)
# Out:
# WARNING:tensorflow:5 out of the last 50 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002A348F5A700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
# Broad model - Real Test
# target unit       MAE      RMSE  STD_abs_error
#  x_hit   mm   161.042   310.746        265.761
#  y_hit   mm   134.519   176.199        113.801
#  z_hit   mm   123.005   156.471         96.711
# vx_hit mm/s   648.193 1,010.659        775.421
# vy_hit mm/s 2,484.386 2,570.736        660.689
# vz_hit mm/s 2,047.226 2,266.014        971.435
#  t_hit   ms   181.280   211.434        108.821
# WARNING:tensorflow:6 out of the last 51 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002A348F59DA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
# Matched model - Real Test
# target unit       MAE      RMSE  STD_abs_error
#  x_hit   mm   148.528   306.648        268.276
#  y_hit   mm   156.005   203.883        131.266
#  z_hit   mm   135.901   167.126         97.274
# vx_hit mm/s   648.902 1,020.563        787.702
# vy_hit mm/s 2,507.919 2,593.417        660.421
# vz_hit mm/s 2,086.858 2,289.057        940.641
#  t_hit   ms   182.764   216.828        116.669
#
# Stage 1 model - Real Test
# target unit     MAE    RMSE  STD_abs_error
#  x_hit   mm 111.441 228.169        199.103
#  y_hit   mm  92.753 117.466         72.077
#  z_hit   mm  82.596 104.750         64.424
# vx_hit mm/s 390.633 564.673        407.751
# vy_hit mm/s 418.680 557.809        368.589
# vz_hit mm/s 814.678 924.268        436.545
#  t_hit   ms  63.397  96.524         72.785
#
# Stage 2 model - Real Test
# target unit     MAE    RMSE  STD_abs_error
#  x_hit   mm 112.547 216.248        184.651
#  y_hit   mm  94.544 119.242         72.664
#  z_hit   mm  80.032 101.765         62.856
# vx_hit mm/s 342.377 520.444        391.969
# vy_hit mm/s 427.878 551.765        348.374
# vz_hit mm/s 815.304 933.598        454.844
#  t_hit   ms  63.711 101.010         78.383

# %%
from pathlib import Path
import joblib

export_dir = Path("../models/ann_stage2_large_dataset")
export_dir.mkdir(parents=True, exist_ok=True)

deploy_model = stage2_model   # or transfer_model / matched_model / broad_model
deploy_model.save(export_dir / "ball_predictor.keras")
joblib.dump(scx, export_dir / "scx.joblib")
joblib.dump(scy, export_dir / "scy.joblib")

print("Saved model + scalers to:", export_dir.resolve())
# Out:
# Saved model + scalers to: C:\Users\rocky\Personal\UBC\Year 4\IGEN 430\TableTennis_Software_Firmware\transfer_learning\models\ann_stage2_large_dataset

# %% [markdown]
# ###1.7. K-Fold Hyperparameter Tuning (Real Data)
#
# Run this section after transfer_model_matched, x_real, y_real, scx, scy, weighted_mse, and build_sample_weights are defined.

# %%
from sklearn.model_selection import KFold, ParameterGrid
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
import numpy as np
import pandas as pd


def clone_with_weights(model):
    with tf.keras.utils.custom_object_scope({"weighted_mse": weighted_mse}):
        m = tf.keras.models.clone_model(model)
    m.set_weights(model.get_weights())
    return m


def evaluate_physical_mae(model, x_val_s, y_val_s, y_scaler):
    y_pred_s = model.predict(x_val_s, verbose=0)
    y_true_u = y_scaler.inverse_transform(y_val_s)
    y_pred_u = y_scaler.inverse_transform(y_pred_s)
    mae = np.mean(np.abs(y_pred_u - y_true_u), axis=0)
    mae_ms = mae.copy()
    mae_ms[6] = mae_ms[6] * 1000.0
    return mae_ms


def run_transfer_kfold_once(x_real_raw, y_real_raw, base_model, hp, n_splits=5, seed=6):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=seed)
    fold_rows = []

    for fold_id, (tr_idx, va_idx) in enumerate(kf.split(x_real_raw), start=1):
        x_tr, x_va = x_real_raw[tr_idx], x_real_raw[va_idx]
        y_tr, y_va = y_real_raw[tr_idx], y_real_raw[va_idx]

        x_tr_s = scx.transform(x_tr)
        x_va_s = scx.transform(x_va)
        y_tr_s = scy.transform(y_tr)
        y_va_s = scy.transform(y_va)

        sample_w = build_sample_weights(
            y_tr_s, scy, reachable_vec=np.ones(y_tr_s.shape[0], dtype=int)
        )

        model = clone_with_weights(base_model)

        freeze_first_n = int(hp.get("freeze_first_n", 2))
        for layer in model.layers[:freeze_first_n]:
            layer.trainable = False

        callbacks = [
            EarlyStopping(
                monitor="val_loss",
                patience=int(hp.get("patience", 12)),
                restore_best_weights=True,
                verbose=0,
            )
        ]

        model.compile(
            loss=weighted_mse,
            optimizer=Adam(learning_rate=float(hp["stage1_lr"])),
            metrics=["mean_squared_error"],
        )
        hist1 = model.fit(
            x_tr_s,
            y_tr_s,
            sample_weight=sample_w,
            validation_data=(x_va_s, y_va_s),
            epochs=int(hp.get("stage1_epochs", 120)),
            batch_size=int(hp.get("batch_size", 16)),
            callbacks=callbacks,
            verbose=0,
        )
        best_stage1 = float(np.min(hist1.history["val_loss"]))

        stage2_epochs = int(hp.get("stage2_epochs", 80))
        if stage2_epochs > 0:
            for layer in model.layers:
                layer.trainable = True

            model.compile(
                loss=weighted_mse,
                optimizer=Adam(learning_rate=float(hp["stage2_lr"])),
                metrics=["mean_squared_error"],
            )
            hist2 = model.fit(
                x_tr_s,
                y_tr_s,
                sample_weight=sample_w,
                validation_data=(x_va_s, y_va_s),
                epochs=stage2_epochs,
                batch_size=int(hp.get("batch_size", 16)),
                callbacks=callbacks,
                verbose=0,
            )
            best_stage2 = float(np.min(hist2.history["val_loss"]))
            best_val_loss = min(best_stage1, best_stage2)
        else:
            best_val_loss = best_stage1

        mae = evaluate_physical_mae(model, x_va_s, y_va_s, scy)

        fold_rows.append(
            {
                "fold": fold_id,
                "best_val_loss": best_val_loss,
                "mae_x_mm": mae[0],
                "mae_y_mm": mae[1],
                "mae_z_mm": mae[2],
                "mae_vx_mm_s": mae[3],
                "mae_vy_mm_s": mae[4],
                "mae_vz_mm_s": mae[5],
                "mae_t_ms": mae[6],
            }
        )

        tf.keras.backend.clear_session()

    return pd.DataFrame(fold_rows)


def run_grid_kfold(x_real_raw, y_real_raw, base_model, param_grid, n_splits=5, seed=6):
    all_runs = []

    for run_id, hp in enumerate(ParameterGrid(param_grid), start=1):
        fold_df = run_transfer_kfold_once(
            x_real_raw=x_real_raw,
            y_real_raw=y_real_raw,
            base_model=base_model,
            hp=hp,
            n_splits=n_splits,
            seed=seed,
        )

        summary = {
            "run_id": run_id,
            **hp,
            "mean_val_loss": fold_df["best_val_loss"].mean(),
            "std_val_loss": fold_df["best_val_loss"].std(ddof=0),
            "mae_xyz_mm": fold_df[["mae_x_mm", "mae_y_mm", "mae_z_mm"]].mean().mean(),
            "mae_v_mm_s": fold_df[["mae_vx_mm_s", "mae_vy_mm_s", "mae_vz_mm_s"]].mean().mean(),
            "mae_t_ms": fold_df["mae_t_ms"].mean(),
        }
        all_runs.append(summary)
        print(f"[run {run_id}] mean_val_loss={summary['mean_val_loss']:.4f} hp={hp}")

    out_df = pd.DataFrame(all_runs).sort_values("mean_val_loss").reset_index(drop=True)
    return out_df

# %%
param_grid = {
    "freeze_first_n": [1, 2],
    "stage1_lr": [1e-4, 5e-5],
    "stage2_lr": [5e-5, 1e-5],
    "batch_size": [16],
    "stage1_epochs": [120],
    "stage2_epochs": [80],
    "patience": [12],
}

# kfold_results = run_grid_kfold(
#     x_real_raw=x_real,
#     y_real_raw=y_real,
#     base_model=transfer_model_matched,
#     param_grid=param_grid,
#     n_splits=5,
#     seed=6,
# )

kfold_results.head(10)
