# %% [markdown]
# # Ping Pong Ball Prediction Using Transfer Learning:
#
# Inputs:
# - x y z (frame 1)
# - x y z (frame 2)
# - x y z (frame 3)
# - x y z (frame 4)
# - x y z (frame 5)
# - x y z (frame 6)
# - dt12
# - dt23
# - dt34
# - dt45
# - dt56
#
#
# Outputs:
# - x y z (interception)
# - vx vy vz
# - t_hit

# %% [markdown]
# ## Importing the Libraries

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ### Importing the Dataset

# %%
synthetic_dataset_path = '../learning_data/synthetic_data/synthetic_intercept_dataset_70.csv'
dataset = pd.read_csv(synthetic_dataset_path)
print('Using synthetic dataset:', synthetic_dataset_path)
# Out:
# Using synthetic dataset: ../learning_data/synthetic_data/synthetic_intercept_dataset_70.csv

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 41 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   x1                     20000 non-null  float64
#  1   y1                     20000 non-null  float64
#  2   z1                     20000 non-null  float64
#  3   x2                     20000 non-null  float64
#  4   y2                     20000 non-null  float64
#  5   z2                     20000 non-null  float64
#  6   x3                     20000 non-null  float64
#  7   y3                     20000 non-null  float64
#  8   z3                     20000 non-null  float64
#  9   x4                     20000 non-null  float64
#  10  y4                     20000 non-null  float64
#  11  z4                     20000 non-null  float64
#  12  x5                     20000 non-null  float64
#  13  y5                     20000 non-null  float64
#  14  z5                     20000 non-null  float64
#  15  x6                     20000 non-null  float64
#  16  y6                     20000 non-null  float64
#  17  z6                     20000 non-null  float64
#  18  dt12                   20000 non-null  float64
#  19  dt23                   20000 non-null  float64
#  20  dt34                   20000 non-null  float64
#  21  dt45                   20000 non-null  float64
#  22  dt56                   20000 non-null  float64
#  23  x_hit                  20000 non-null  float64
#  24  y_hit                  20000 non-null  float64
#  25  z_hit                  20000 non-null  float64
#  26  vx_hit                 20000 non-null  float64
#  27  vy_hit                 20000 non-null  float64
#  28  vz_hit                 20000 non-null  float64
#  29  t_hit                  20000 non-null  float64
#  30  is_reachable           20000 non-null  float64
#  31  bounces_before_hit     20000 non-null  float64
#  32  has_bounce_before_hit  20000 non-null  float64
#  33  intercept_valid        20000 non-null  float64
#  34  x0                     20000 non-null  float64
#  35  y0                     20000 non-null  float64
#  36  z0                     20000 non-null  float64
#  37  vx0                    20000 non-null  float64
#  38  vy0                    20000 non-null  float64
#  39  vz0                    20000 non-null  float64
#  40  gravity_z_mm_s2        20000 non-null  float64
# dtypes: float64(41)
# memory usage: 6.3 MB

# %%
dataset.describe()
# Out:
#                  x1            y1            z1            x2            y2  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean      -1.339049   2203.586630   -877.583886     -1.054894   2134.673705
# std      456.306760    201.604991    165.661723    442.644894    212.744226
# min     -799.961743   1600.135373  -1121.043880   -823.774743   1484.292742
# 25%     -389.896077   2086.236518  -1011.940458   -377.125630   2012.306610
# 50%       -3.645759   2263.468909   -911.090996     -2.051878   2196.722559
# 75%      384.068485   2368.481873   -770.451513    370.179060   2307.096127
# max      799.899556   2429.995101   -410.487007    822.021552   2403.067286
#
#                  z2            x3            y3            z3            x4  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean    -873.419250     -0.858897   2065.751624   -866.701637     -0.473129
# std      167.493339    430.120098    224.710545    171.552756    418.847040
# min    -1123.516723   -836.497214   1356.343191  -1124.643861   -844.183416
# 25%    -1010.260756   -362.601183   1935.355116  -1006.857728   -348.988469
# 50%     -906.713056     -2.610234   2128.801441   -901.430906     -0.240149
# 75%     -762.575734    359.439162   2245.839892   -751.908432    348.732400
# max     -350.552969    830.928838   2372.606247   -309.335154    856.195219
#
#        ...  bounces_before_hit  has_bounce_before_hit  intercept_valid  \
# count  ...        20000.000000           20000.000000          20000.0
# mean   ...            1.251800               0.980700              1.0
# std    ...            0.476454               0.137581              0.0
# min    ...            0.000000               0.000000              1.0
# 25%    ...            1.000000               1.000000              1.0
# 50%    ...            1.000000               1.000000              1.0
# 75%    ...            2.000000               1.000000              1.0
# max    ...            2.000000               1.000000              1.0
#
#                  x0            y0            z0           vx0           vy0  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean      -3.555290   2701.507604   -802.872811     17.049800  -4271.521275
# std      584.717647    157.737503    188.447141   1630.148954   1126.616220
# min    -1062.142610   2450.018192  -1109.978151  -4978.077499  -7664.693198
# 25%     -508.474772   2565.753767   -959.391824   -998.360806  -5070.735911
# 50%        0.054000   2690.314689   -826.793136     12.176528  -4103.468482
# 75%      495.314177   2824.599037   -656.666080   1040.324403  -3390.508082
# max     1062.379353   3127.474310   -410.048376   5119.895506  -1782.255395
#
#                 vz0  gravity_z_mm_s2
# count  20000.000000     20000.000000
# mean   -1485.893304     -9810.242357
# std     1660.179677        49.010996
# min    -5461.122042     -9995.623185
# 25%    -2704.938759     -9843.343842
# 50%    -1380.761818     -9809.740122
# 75%     -232.511549     -9776.927599
# max     2474.356579     -9603.020698
#
# [8 rows x 41 columns]

# %% [markdown]
# ### Pre-Processing

# %% [markdown]
# ### Separating the Input and Outputs

# %%
input_cols_6 = [
    "x1", "y1", "z1",
    "x2", "y2", "z2",
    "x3", "y3", "z3",
    "x4", "y4", "z4",
    "x5", "y5", "z5",
    "x6", "y6", "z6",
    "dt12", "dt23", "dt34", "dt45", "dt56",
]
target_cols = ["x_hit", "y_hit", "z_hit", "vx_hit", "vy_hit", "vz_hit", "t_hit"]

x = dataset[input_cols_6]
y = dataset[target_cols]

# %%
# View the inputs
print(x)
# Out:
#                x1           y1           z1          x2           y2  \
# 0     -705.111897  2417.130082  -581.363406 -681.724603  2375.230548
# 1      420.691725  1971.800258 -1003.892873  433.849105  1914.777219
# 2     -609.028122  2426.370452  -982.912409 -623.072074  2368.350726
# 3      155.670559  2194.897294  -576.246119  114.404209  2141.931907
# 4      -19.299076  1990.005137 -1054.893700  -30.880989  1920.513947
# ...           ...          ...          ...         ...          ...
# 19995 -245.923648  2092.872927 -1070.358096 -250.190236  2053.267274
# 19996  126.929926  2204.734092  -712.619456   94.688112  2127.518402
# 19997 -193.188651  2268.340292  -835.759736 -154.941724  2226.870327
# 19998 -712.940639  2128.839267 -1050.459609 -672.108148  2065.408784
# 19999 -120.861255  2395.524215 -1111.791583 -121.249559  2333.795104
#
#                 z2          x3           y3           z3          x4  ...  \
# 0      -578.541098 -672.852777  2323.498216  -586.696949 -642.143723  ...
# 1     -1041.365553  426.576912  1839.560462 -1114.728824  420.294341  ...
# 2      -911.564144 -667.121729  2324.725209  -869.872486 -679.212750  ...
# 3      -604.500230   29.862294  2104.132052  -626.009722  -34.462104  ...
# 4     -1088.453476  -58.684024  1847.569718 -1023.241855  -61.497124  ...
# ...            ...         ...          ...          ...         ...  ...
# 19995 -1102.389582 -246.416439  1988.358415 -1074.967757 -216.729745  ...
# 19996  -680.655015   82.462357  2063.831926  -644.870216   59.702969  ...
# 19997  -858.800092 -153.154561  2162.668021  -893.466827 -120.479468  ...
# 19998  -980.072500 -639.271459  2003.151700  -933.713354 -608.333504  ...
# 19999 -1064.310873 -131.402699  2270.814587 -1042.464032 -120.630600  ...
#
#                 y5           z5          x6           y6           z6  \
# 0      2192.832735  -610.025082 -587.429300  2115.968032  -631.703850
# 1      1691.632384  -992.852370  409.280776  1596.545148  -935.175059
# 2      2223.273673  -761.674184 -721.175856  2166.691157  -697.495612
# 3      2011.968598  -668.677533 -153.536198  1967.842413  -684.913644
# 4      1709.166481  -878.563664  -80.045143  1635.586960  -823.678659
# ...            ...          ...         ...          ...          ...
# 19995  1901.836661 -1017.057742 -196.259683  1858.407408  -992.117282
# 19996  1908.419279  -584.666805   20.216378  1827.709624  -560.864895
# 19997  2034.871878  -971.790244  -73.983844  1974.403448 -1026.834629
# 19998  1902.440897  -848.317758 -553.832936  1855.286193  -808.167977
# 19999  2125.127443  -982.755261 -163.819119  2046.895287  -960.013489
#
#            dt12      dt23      dt34      dt45      dt56
# 0      0.014168  0.014124  0.017910  0.018062  0.019645
# 1      0.012073  0.012569  0.017010  0.013985  0.022107
# 2      0.017306  0.014794  0.013946  0.019165  0.018244
# 3      0.018113  0.017941  0.015098  0.017422  0.015089
# 4      0.015244  0.013933  0.015720  0.015874  0.016113
# ...         ...       ...       ...       ...       ...
# 19995  0.019153  0.015651  0.018304  0.009905  0.014798
# 19996  0.016703  0.014263  0.018502  0.013255  0.019048
# 19997  0.015960  0.014168  0.012842  0.019511  0.018747
# 19998  0.021819  0.015539  0.015371  0.014130  0.016043
# 19999  0.016055  0.013317  0.018731  0.016838  0.017080
#
# [20000 rows x 23 columns]

# %%
# View the outputs
print(y)
# Out:
#              x_hit        y_hit       z_hit       vx_hit       vy_hit  \
# 0       181.143112    58.771577 -575.800214  1376.436575 -3673.476952
# 1       310.529769     9.197282 -329.571217  -308.572302 -4935.690435
# 2     -1479.910550   344.429971 -572.956072 -1327.755836 -3169.739257
# 3     -1014.192835  1343.972303 -949.602869 -3862.697165 -2799.125066
# 4      -313.759981   364.624656  -22.440909  -821.904332 -4723.926473
# ...            ...          ...         ...          ...          ...
# 19995   224.623472    53.286435 -869.704026   708.162784 -3039.154323
# 19996  -459.729702   -50.324652 -802.537698 -1179.685122 -4617.235644
# 19997   608.632842   -17.107670 -805.956907  1318.115807 -3809.503151
# 19998   489.740459   -24.414074 -807.140563  1917.462465 -3437.013324
# 19999  -419.321843    45.799597 -934.964048  -574.418761 -4305.756995
#
#             vz_hit     t_hit
# 0       -81.077668  0.560320
# 1       288.623782  0.319429
# 2     -2599.911467  0.573112
# 3      2783.374619  0.222248
# 4      1645.831136  0.267055
# ...            ...       ...
# 19995    68.637303  0.595845
# 19996 -2574.072688  0.405588
# 19997 -1804.251709  0.520318
# 19998 -2680.750450  0.544212
# 19999  1234.716958  0.465401
#
# [20000 rows x 7 columns]

# %%
x = x.values
y = y.values

# %% [markdown]
# ### Splitting the Dataset into the Training set and Test set

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error

# 1) Build reachability vector from your full dataset
# (change column name if needed)
r = dataset["is_reachable"].to_numpy().astype(int)

# 2) Split x, y, and r together (important)
x_train, x_test, y_train, y_test, r_train, r_test = train_test_split(
    x, y, r,
    test_size=0.05,
    random_state=1,
    stratify=r   # recommended
)

# 3) Keep full test copy
x_test_all = x_test.copy()
y_test_all = y_test.copy()

# 4) Reachable-only adjusted test set
mask_reach = (r_test == 1)
x_test_reach = x_test_all[mask_reach].copy()
y_test_reach = y_test_all[mask_reach].copy()

# %%
print(x_train.shape)
print(x_test_all.shape)
print(x_test_reach.shape)
print(y_train.shape)
print(y_test_all.shape)
print(y_test_reach.shape)
# Out:
# (19000, 23)
# (1000, 23)
# (700, 23)
# (19000, 7)
# (1000, 7)
# (700, 7)

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

scx = StandardScaler()
scy = StandardScaler()

x_train = scx.fit_transform(x_train)
x_test_all = scx.transform(x_test_all)
x_test_reach = scx.transform(x_test_reach)

y_train = scy.fit_transform((y_train))
y_test_all = scy.transform((y_test_all))
y_test_reach = scy.transform((y_test_reach))

# %%
# --- weighted loss + sample weighting helpers (xyz emphasis + center/reach emphasis) ---
import tensorflow as tf
import numpy as np

@tf.keras.utils.register_keras_serializable(package="Custom")
def weighted_mse(y_true, y_pred):
    raw_w = tf.constant([1,1,1,0,0,0,0], tf.float32)
    w = raw_w / tf.reduce_mean(raw_w)
    err2 = tf.square(y_true - y_pred)
    return tf.reduce_mean(err2 * w, axis=-1)  # per-sample loss



WORKSPACE_CENTER_MM = np.array([0.0, 0.0, -900.0], dtype=np.float32)
CENTER_SIGMA_MM = 250.0
REACH_BOOST = 1.0
CENTER_BOOST = 2.0

def build_sample_weights(y_train_scaled, y_scaler, reachable_vec=None,
                         center=WORKSPACE_CENTER_MM,
                         sigma_mm=CENTER_SIGMA_MM,
                         reach_boost=REACH_BOOST,
                         center_boost=CENTER_BOOST):
    y_u = y_scaler.inverse_transform(y_train_scaled)
    d_mm = np.linalg.norm(y_u[:, :3] - center[None, :], axis=1)

    w_center = 1.0 + center_boost * np.exp(-(d_mm ** 2) / (2.0 * sigma_mm ** 2))
    if reachable_vec is None:
        w_reach = np.ones_like(w_center)
    else:
        w_reach = 1.0 + reach_boost * np.asarray(reachable_vec, dtype=float)

    w = w_center * w_reach
    w = w / np.mean(w)
    return np.clip(w, 0.5, 5.0)

# Broad-stage sample weights (r_train comes from the broad train/test split cell)
sample_w_broad = build_sample_weights(y_train, scy, reachable_vec=r_train)
print("sample_w_broad stats:", sample_w_broad.min(), sample_w_broad.mean(), sample_w_broad.max())
# Out:
# sample_w_broad stats: 0.5 1.0389965744310063 2.143109249345195

# %% [markdown]
# ## The ANN Model Initialization

# %%
ball_predictor = tf.keras.models.Sequential()

# %% [markdown]
# ### Constructing the Model

# %%
ball_predictor.add(tf.keras.layers.Dense(units=23, activation='relu')) # 23 input features (6 points + 5 dt)
ball_predictor.add(tf.keras.layers.Dense(units=32, activation='relu')) # hiddel layer 1
ball_predictor.add(tf.keras.layers.Dense(units=64, activation='relu')) # hidden layer 2
ball_predictor.add(tf.keras.layers.Dense(units=64, activation='relu')) # hiddel layer 3
ball_predictor.add(tf.keras.layers.Dense(units=32, activation='relu')) # hiddel layer 3
ball_predictor.add(tf.keras.layers.Dense(units=7, activation='linear')) # 7

# %%
ball_predictor.compile(
    loss=weighted_mse,
    optimizer='adam',
    metrics=['mean_squared_error']
)

# %% [markdown]
# ### Training

# %%
p1 = ball_predictor.fit(
    x_train,
    y_train,
    sample_weight=sample_w_broad,
    validation_split=0.2,
    batch_size=32,
    epochs=60,
    verbose=1,
)
# Out:
# Epoch 1/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.5153 - mean_squared_error: 0.7632 - val_loss: 0.3208 - val_mean_squared_error: 0.5039
# Epoch 2/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2365 - mean_squared_error: 0.3980 - val_loss: 0.1949 - val_mean_squared_error: 0.3450
# Epoch 3/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1572 - mean_squared_error: 0.2880 - val_loss: 0.1300 - val_mean_squared_error: 0.2557
# Epoch 4/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1145 - mean_squared_error: 0.2223 - val_loss: 0.1082 - val_mean_squared_error: 0.2089
# Epoch 5/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0962 - mean_squared_error: 0.1872 - val_loss: 0.0885 - val_mean_squared_error: 0.1767
# Epoch 6/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0847 - mean_squared_error: 0.1640 - val_loss: 0.0805 - val_mean_squared_error: 0.1563
# Epoch 7/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0770 - mean_squared_error: 0.1487 - val_loss: 0.0752 - val_mean_squared_error: 0.1471
# Epoch 8/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0727 - mean_squared_error: 0.1404 - val_loss: 0.0747 - val_mean_squared_error: 0.1416
# Epoch 9/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0686 - mean_squared_error: 0.1325 - val_loss: 0.0722 - val_mean_squared_error: 0.1357
# Epoch 10/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0663 - mean_squared_error: 0.1271 - val_loss: 0.0663 - val_mean_squared_error: 0.1315
# Epoch 11/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0634 - mean_squared_error: 0.1220 - val_loss: 0.0604 - val_mean_squared_error: 0.1195
# Epoch 12/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0608 - mean_squared_error: 0.1174 - val_loss: 0.0601 - val_mean_squared_error: 0.1183
# Epoch 13/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0589 - mean_squared_error: 0.1143 - val_loss: 0.0578 - val_mean_squared_error: 0.1133
# Epoch 14/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0575 - mean_squared_error: 0.1113 - val_loss: 0.0604 - val_mean_squared_error: 0.1153
# Epoch 15/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0554 - mean_squared_error: 0.1074 - val_loss: 0.0600 - val_mean_squared_error: 0.1136
# Epoch 16/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0545 - mean_squared_error: 0.1051 - val_loss: 0.0520 - val_mean_squared_error: 0.1021
# Epoch 17/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0530 - mean_squared_error: 0.1023 - val_loss: 0.0532 - val_mean_squared_error: 0.1066
# Epoch 18/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0511 - mean_squared_error: 0.0989 - val_loss: 0.0538 - val_mean_squared_error: 0.1045
# Epoch 19/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0517 - mean_squared_error: 0.0986 - val_loss: 0.0567 - val_mean_squared_error: 0.1088
# Epoch 20/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0501 - mean_squared_error: 0.0953 - val_loss: 0.0500 - val_mean_squared_error: 0.0991
# Epoch 21/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0496 - mean_squared_error: 0.0941 - val_loss: 0.0508 - val_mean_squared_error: 0.0949
# Epoch 22/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0490 - mean_squared_error: 0.0932 - val_loss: 0.0504 - val_mean_squared_error: 0.0961
# Epoch 23/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0485 - mean_squared_error: 0.0919 - val_loss: 0.0492 - val_mean_squared_error: 0.0931
# Epoch 24/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0472 - mean_squared_error: 0.0895 - val_loss: 0.0477 - val_mean_squared_error: 0.0922
# Epoch 25/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0462 - mean_squared_error: 0.0881 - val_loss: 0.0481 - val_mean_squared_error: 0.0883
# Epoch 26/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0458 - mean_squared_error: 0.0870 - val_loss: 0.0509 - val_mean_squared_error: 0.0960
# Epoch 27/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0456 - mean_squared_error: 0.0859 - val_loss: 0.0500 - val_mean_squared_error: 0.0916
# Epoch 28/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0447 - mean_squared_error: 0.0838 - val_loss: 0.0489 - val_mean_squared_error: 0.0923
# Epoch 29/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0446 - mean_squared_error: 0.0832 - val_loss: 0.0490 - val_mean_squared_error: 0.0915
# Epoch 30/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0440 - mean_squared_error: 0.0815 - val_loss: 0.0456 - val_mean_squared_error: 0.0872
# Epoch 31/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0436 - mean_squared_error: 0.0810 - val_loss: 0.0470 - val_mean_squared_error: 0.0851
# Epoch 32/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0434 - mean_squared_error: 0.0807 - val_loss: 0.0446 - val_mean_squared_error: 0.0851
# Epoch 33/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0424 - mean_squared_error: 0.0786 - val_loss: 0.0464 - val_mean_squared_error: 0.0857
# Epoch 34/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0423 - mean_squared_error: 0.0777 - val_loss: 0.0437 - val_mean_squared_error: 0.0826
# Epoch 35/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0424 - mean_squared_error: 0.0780 - val_loss: 0.0450 - val_mean_squared_error: 0.0844
# Epoch 36/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0416 - mean_squared_error: 0.0760 - val_loss: 0.0420 - val_mean_squared_error: 0.0788
# Epoch 37/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0410 - mean_squared_error: 0.0758 - val_loss: 0.0436 - val_mean_squared_error: 0.0808
# Epoch 38/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0401 - mean_squared_error: 0.0736 - val_loss: 0.0482 - val_mean_squared_error: 0.0842
# Epoch 39/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0407 - mean_squared_error: 0.0741 - val_loss: 0.0445 - val_mean_squared_error: 0.0778
# Epoch 40/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0396 - mean_squared_error: 0.0724 - val_loss: 0.0503 - val_mean_squared_error: 0.0821
# Epoch 41/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0404 - mean_squared_error: 0.0728 - val_loss: 0.0431 - val_mean_squared_error: 0.0797
# Epoch 42/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0395 - mean_squared_error: 0.0708 - val_loss: 0.0412 - val_mean_squared_error: 0.0737
# Epoch 43/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0395 - mean_squared_error: 0.0707 - val_loss: 0.0486 - val_mean_squared_error: 0.0826
# Epoch 44/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0390 - mean_squared_error: 0.0696 - val_loss: 0.0430 - val_mean_squared_error: 0.0787
# Epoch 45/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0403 - mean_squared_error: 0.0715 - val_loss: 0.0398 - val_mean_squared_error: 0.0720
# Epoch 46/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0385 - mean_squared_error: 0.0684 - val_loss: 0.0393 - val_mean_squared_error: 0.0719
# Epoch 47/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0379 - mean_squared_error: 0.0689 - val_loss: 0.0413 - val_mean_squared_error: 0.0710
# Epoch 48/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0382 - mean_squared_error: 0.0685 - val_loss: 0.0410 - val_mean_squared_error: 0.0718
# Epoch 49/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0375 - mean_squared_error: 0.0682 - val_loss: 0.0415 - val_mean_squared_error: 0.0722
# Epoch 50/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0377 - mean_squared_error: 0.0676 - val_loss: 0.0407 - val_mean_squared_error: 0.0720
# Epoch 51/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0367 - mean_squared_error: 0.0659 - val_loss: 0.0416 - val_mean_squared_error: 0.0721
# Epoch 52/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0370 - mean_squared_error: 0.0667 - val_loss: 0.0411 - val_mean_squared_error: 0.0707
# Epoch 53/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0373 - mean_squared_error: 0.0672 - val_loss: 0.0411 - val_mean_squared_error: 0.0749
# Epoch 54/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0374 - mean_squared_error: 0.0669 - val_loss: 0.0421 - val_mean_squared_error: 0.0715
# Epoch 55/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0367 - mean_squared_error: 0.0655 - val_loss: 0.0391 - val_mean_squared_error: 0.0725
# Epoch 56/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0361 - mean_squared_error: 0.0652 - val_loss: 0.0384 - val_mean_squared_error: 0.0690
# Epoch 57/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0361 - mean_squared_error: 0.0645 - val_loss: 0.0403 - val_mean_squared_error: 0.0698
# Epoch 58/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0361 - mean_squared_error: 0.0652 - val_loss: 0.0424 - val_mean_squared_error: 0.0751
# Epoch 59/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0375 - mean_squared_error: 0.0667 - val_loss: 0.0410 - val_mean_squared_error: 0.0738
# Epoch 60/60
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0359 - mean_squared_error: 0.0642 - val_loss: 0.0380 - val_mean_squared_error: 0.0670

# %% [markdown]
# ### Learning Curves

# %%
fig, axs = plt.subplots(figsize=(16,5))
fig.suptitle('Loss Function')

axs.plot(p1.history['loss'])
axs.plot(p1.history['val_loss'])
axs.set_title("Ball Prediction Learning Curves")
axs.set(xlabel='Epoch', ylabel='Loss')

fig.legend(labels=['Train', 'Validation'], loc="upper left")
plt.show()

# %%
# def eval_regression(name, y_true, y_pred):
#     mae = mean_absolute_error(y_true, y_pred, multioutput='raw_values')
#     rmse = np.sqrt(mean_squared_error(y_true, y_pred, multioutput='raw_values'))
#     print(f"\n{name}")
#     print("MAE per output:", mae)
#     print("RMSE per output:", rmse)

# # If y is scaled, inverse-transform both y_true and y_pred before metrics.
# y_pred_all = ball_predictor.predict(x_test_all)
# y_pred_reach = ball_predictor.predict(x_test_reach)

# # Example for scaled targets:
# # y_pred_all = scy.inverse_transform(y_pred_all); y_test_all_eval = scy.inverse_transform(y_test_all)
# # y_pred_reach = scy.inverse_transform(y_pred_reach); y_test_reach_eval = scy.inverse_transform(y_test_reach)

# eval_regression("All test shots", y_test_all, y_pred_all)
# eval_regression("Reachable-only test shots", y_test_reach, y_pred_reach)

import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error

target_names = ["x_hit", "y_hit", "z_hit", "vx_hit", "vy_hit", "vz_hit", "t_hit"]
target_units = ["mm", "mm", "mm", "mm/s", "mm/s", "mm/s", "ms"]

def eval_with_units(name, model, x_eval, y_eval, y_scaler, y_is_scaled=True, t_hit_in_seconds=True):
    y_pred = model.predict(x_eval, verbose=0)

    # Convert to physical units exactly once
    if y_is_scaled:
        assert y_eval.shape[1] == y_scaler.n_features_in_ == len(target_names)
        y_true_u = y_scaler.inverse_transform(y_eval)
        y_pred_u = y_scaler.inverse_transform(y_pred)
    else:
        y_true_u = y_eval
        y_pred_u = y_pred

    err = y_pred_u - y_true_u
    abs_err = np.abs(err)

    mae = mean_absolute_error(y_true_u, y_pred_u, multioutput="raw_values")
    rmse = np.sqrt(mean_squared_error(y_true_u, y_pred_u, multioutput="raw_values"))
    std_abs = abs_err.std(axis=0)

    # Convert t_hit to ms for reporting (only if stored in seconds)
    if t_hit_in_seconds:
        i = target_names.index("t_hit")
        mae[i] *= 1000.0
        rmse[i] *= 1000.0
        std_abs[i] *= 1000.0

    report = pd.DataFrame({
        "target": target_names,
        "unit": target_units,
        "MAE": mae,
        "RMSE": rmse,
        "STD_abs_error": std_abs,
    })

    print(f"\n{name}")
    print(report.to_string(index=False, float_format=lambda v: f"{v:,.3f}"))

# Run both:
eval_with_units("All test shots", ball_predictor, x_test_all, y_test_all, scy, y_is_scaled=True, t_hit_in_seconds=True)
eval_with_units("Reachable-only test shots", ball_predictor, x_test_reach, y_test_reach, scy, y_is_scaled=True, t_hit_in_seconds=True)
# Out:
# All test shots
# target unit     MAE      RMSE  STD_abs_error
#  x_hit   mm  58.831    76.467         48.847
#  y_hit   mm  63.560   101.337         78.927
#  z_hit   mm  35.405    54.272         41.132
# vx_hit mm/s 188.026   250.181        165.035
# vy_hit mm/s 151.221   202.428        134.572
# vz_hit mm/s 672.342 1,034.173        785.793
#  t_hit   ms  22.436    33.306         24.615
#
# Reachable-only test shots
# target unit     MAE      RMSE  STD_abs_error
#  x_hit   mm  59.424    76.224         47.737
#  y_hit   mm  56.727    84.711         62.912
#  z_hit   mm  24.273    33.844         23.585
# vx_hit mm/s 158.603   208.784        135.779
# vy_hit mm/s 127.295   169.352        111.696
# vz_hit mm/s 676.719 1,060.049        815.938
#  t_hit   ms  19.491    26.788         18.377

# %%
# Verification 
train_std = scy.scale_ 
rmse_sigma = np.sqrt(0.1084)   # val_mse from curve, e.g. 0.1151
rmse_units = rmse_sigma * train_std

print(rmse_units)
# Out:
# [1.77979691e+02 1.11748760e+02 9.59219570e+01 5.37080050e+02
#  3.70565393e+02 6.86117988e+02 6.09266036e-02]

# %% [markdown]
# ## Loading the Matched Synthetic Dataset (Transfer Learning)

# %%
# matched_dataset = pd.read_csv('../learning_data/synthetic_matched_data/synthetic_intercept_dataset.csv')
# matched_dataset.info()

# %%
# input_cols_6 = [
#     "x1", "y1", "z1",
#     "x2", "y2", "z2",
#     "x3", "y3", "z3",
#     "x4", "y4", "z4",
#     "x5", "y5", "z5",
#     "x6", "y6", "z6",
#     "dt12", "dt23", "dt34", "dt45", "dt56",
# ]
# target_cols = ["x_hit", "y_hit", "z_hit", "vx_hit", "vy_hit", "vz_hit", "t_hit"]

# x_matched = matched_dataset[input_cols_6]
# y_matched = matched_dataset[target_cols]
# r_matched = matched_dataset["is_reachable"].to_numpy().astype(int)

# # View the inputs
# print(x_matched)
# print(y_matched)

# x_matched = x_matched.values
# y_matched = y_matched.values

# %%
# #Split input and output x, y
# x_matched_train, x_matched_test, y_matched_train, y_matched_test, r_matched_train, r_matched_test = train_test_split(
#     x_matched, y_matched, r_matched,
#     test_size=0.1,
#     random_state=6,
#     stratify=r_matched
# )

# %%
# print(x_matched_train.shape)
# print(x_matched_test.shape)
# print(y_matched_train.shape)
# print(y_matched_test.shape)

# x_matched_train_s = scx.transform(x_matched_train)
# x_matched_test_s = scx.transform(x_matched_test)
# y_matched_train_s = scy.transform(y_matched_train)
# y_matched_test_s = scy.transform(y_matched_test)

# sample_w_matched = build_sample_weights(y_matched_train_s, scy, reachable_vec=r_matched_train)
# print("sample_w_matched stats:", sample_w_matched.min(), sample_w_matched.mean(), sample_w_matched.max())

# %%
import tensorflow as tf
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam

# # Try 1e-5 first; then tune [1e-6, 1e-5, 5e-5]
# L2_LAMBDA = 5e-5

# dense_total = sum(isinstance(l, tf.keras.layers.Dense) for l in ball_predictor.layers)
# dense_seen = {"n": 0}

# def clone_with_l2(layer):
#     cfg = layer.get_config()
#     if isinstance(layer, tf.keras.layers.Dense):
#         dense_seen["n"] += 1
#         is_output_layer = (dense_seen["n"] == dense_total)
#         if not is_output_layer:  # regularize hidden layers only
#             cfg["kernel_regularizer"] = regularizers.serialize(regularizers.l2(L2_LAMBDA))
#     return layer.__class__.from_config(cfg)

# # Start from broad pretrained model, but with L2 regularization added
# transfer_model_matched = tf.keras.models.clone_model(
#     ball_predictor,
#     clone_function=clone_with_l2
# )
# transfer_model_matched.set_weights(ball_predictor.get_weights())

# # Matched stage: unfreeze all layers, train with low LR
# for layer in transfer_model_matched.layers:
#     layer.trainable = True

# transfer_model_matched.compile(
#     loss=weighted_mse,
#     optimizer=Adam(learning_rate=1e-4),
#     metrics=["mean_squared_error"]
# )

# history_matched = transfer_model_matched.fit(
#     x_matched_train_s, y_matched_train_s,
#     sample_weight=sample_w_matched,
#     validation_split=0.2,
#     epochs=40,
#     verbose=1
# )

# %%
# import matplotlib.pyplot as plt

# fig, ax = plt.subplots(figsize=(12,4))
# ax.plot(history_matched.history["loss"], label="Train")
# ax.plot(history_matched.history["val_loss"], label="Validation")
# ax.set_title("Matched Synthetic Data Learning Curves")
# ax.set_xlabel("Epoch")
# ax.set_ylabel("Loss")
# ax.legend()
# plt.show()

# %%
# eval_with_units(
#     "Matched Data Transfer Model",
#     transfer_model_matched,
#     x_matched_test_s,
#     y_matched_test_s,
#     scy,
#     y_is_scaled=True,
#     t_hit_in_seconds=True
# )

# %% [markdown]
# ## Loading the Real Dataset (Transfer Learning)

# %%
real_dataset_path = '../learning_data/real_data/samples_good_ok_verified.csv'
real_dataset = pd.read_csv(real_dataset_path)
print('Using real dataset:', real_dataset_path)
real_dataset.info()
# Out:
# Using real dataset: ../learning_data/real_data/samples_good_ok_verified.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Data columns (total 40 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   sample_id                             174 non-null    int64
#  1   captured_at                           174 non-null    object
#  2   x1                                    174 non-null    float64
#  3   y1                                    174 non-null    float64
#  4   z1                                    174 non-null    float64
#  5   x2                                    174 non-null    float64
#  6   y2                                    174 non-null    float64
#  7   z2                                    174 non-null    float64
#  8   x3                                    174 non-null    float64
#  9   y3                                    174 non-null    float64
#  10  z3                                    174 non-null    float64
#  11  x4                                    174 non-null    float64
#  12  y4                                    174 non-null    float64
#  13  z4                                    174 non-null    float64
#  14  x5                                    174 non-null    float64
#  15  y5                                    174 non-null    float64
#  16  z5                                    174 non-null    float64
#  17  x6                                    174 non-null    float64
#  18  y6                                    174 non-null    float64
#  19  z6                                    174 non-null    float64
#  20  dt12                                  174 non-null    float64
#  21  dt23                                  174 non-null    float64
#  22  dt34                                  174 non-null    float64
#  23  dt45                                  174 non-null    float64
#  24  dt56                                  174 non-null    float64
#  25  x_hit                                 174 non-null    float64
#  26  y_hit                                 174 non-null    float64
#  27  z_hit                                 174 non-null    float64
#  28  vx_hit                                174 non-null    float64
#  29  vy_hit                                174 non-null    float64
#  30  vz_hit                                174 non-null    float64
#  31  t_hit                                 174 non-null    float64
#  32  is_reachable                          174 non-null    float64
#  33  intercept_valid                       174 non-null    float64
#  34  bounces_before_hit                    174 non-null    float64
#  35  has_bounce_before_hit                 174 non-null    float64
#  36  hit_obs_index                         174 non-null    float64
#  37  hit_obs_in_workspace                  174 non-null    float64
#  38  hit_obs_selected_from_workspace_pool  174 non-null    float64
#  39  hit_center_dist_mm                    174 non-null    float64
# dtypes: float64(38), int64(1), object(1)
# memory usage: 54.5+ KB

# %%
real_dataset.describe()
# Out:
#         sample_id          x1           y1           z1          x2  \
# count  174.000000  174.000000   174.000000   174.000000  174.000000
# mean   153.856322   66.592807  2232.798598  -742.904734   71.154397
# std     85.683428  283.309191   174.537416   186.838364  277.789582
# min      1.000000 -454.052783   985.465776 -1114.825121 -464.803516
# 25%     89.250000 -165.590174  2168.281847  -927.819397 -155.005118
# 50%    147.500000   28.971763  2263.577166  -692.857553   31.679909
# 75%    216.750000  319.375781  2337.175583  -607.342482  312.516796
# max    323.000000  714.302094  2451.031897  -385.130656  702.653598
#
#                 y2           z2          x3           y3           z3  ...  \
# count   174.000000   174.000000  174.000000   174.000000   174.000000  ...
# mean   2148.402927  -752.279343   69.312730  2067.458516  -761.964521  ...
# std     170.532921   192.942027  270.731422   167.792598   195.404045  ...
# min     938.710082 -1122.289696 -459.775344   893.141550 -1109.584089  ...
# 25%    2091.627131  -954.881442 -149.507726  2015.885242  -974.263823  ...
# 50%    2169.783810  -692.860180   37.884928  2093.284704  -701.034000  ...
# 75%    2253.525944  -612.629264  298.260244  2167.073590  -616.710640  ...
# max    2388.775703  -412.511512  690.347274  2316.139011  -437.799473  ...
#
#             vz_hit       t_hit  is_reachable  intercept_valid  \
# count   174.000000  174.000000    174.000000            174.0
# mean     45.031480    0.524528      0.948276              1.0
# std    1252.180918    0.159421      0.222109              0.0
# min   -4931.714676    0.234429      0.000000              1.0
# 25%   -1050.492792    0.424839      1.000000              1.0
# 50%     160.124019    0.495571      1.000000              1.0
# 75%    1157.107472    0.603926      1.000000              1.0
# max    2361.219206    1.331574      1.000000              1.0
#
#        bounces_before_hit  has_bounce_before_hit  hit_obs_index  \
# count          174.000000             174.000000     174.000000
# mean             0.074713               0.074713      38.545977
# std              0.263686               0.263686      10.276279
# min              0.000000               0.000000      19.000000
# 25%              0.000000               0.000000      32.000000
# 50%              0.000000               0.000000      37.000000
# 75%              0.000000               0.000000      44.000000
# max              1.000000               1.000000      92.000000
#
#        hit_obs_in_workspace  hit_obs_selected_from_workspace_pool  \
# count            174.000000                            174.000000
# mean               0.948276                              0.948276
# std                0.222109                              0.222109
# min                0.000000                              0.000000
# 25%                1.000000                              1.000000
# 50%                1.000000                              1.000000
# 75%                1.000000                              1.000000
# max                1.000000                              1.000000
#
#        hit_center_dist_mm
# count          174.000000
# mean           296.546066
# std            169.518199
# min              6.334217
# 25%            157.686820
# 50%            281.718723
# 75%            417.037480
# max            903.843327
#
# [8 rows x 39 columns]

# %% [markdown]
# ### Pre-Processing the Real Dataset

# %%
input_cols_6 = [
    'x1', 'y1', 'z1',
    'x2', 'y2', 'z2',
    'x3', 'y3', 'z3',
    'x4', 'y4', 'z4',
    'x5', 'y5', 'z5',
    'x6', 'y6', 'z6',
    'dt12', 'dt23', 'dt34', 'dt45', 'dt56',
]
target_cols = ['x_hit', 'y_hit', 'z_hit', 'vx_hit', 'vy_hit', 'vz_hit', 't_hit']

x_real = real_dataset[input_cols_6]
y_real = real_dataset[target_cols]

if 'is_reachable' in real_dataset.columns:
    r_real = real_dataset['is_reachable'].to_numpy().astype(int)
else:
    r_real = np.ones(len(real_dataset), dtype=int)

# %%
# View the inputs
print(x_real)
# Out:
#              x1           y1           z1          x2           y2  \
# 0    -90.491715  2367.800266  -916.990844  -55.894581  2273.066741
# 1    461.634882  2140.277963 -1073.795995  454.063902  2086.468000
# 2    245.848472  2210.606525  -646.797924  290.588653  2131.705282
# 3    292.877939  2168.064692  -576.692225  278.100545  2104.666495
# 4   -244.876224  2410.505180  -973.930709 -225.726794  2316.393528
# ..          ...          ...          ...         ...          ...
# 169   27.738880  2288.469453  -813.359775    8.967819  2216.756177
# 170  296.144938  2190.383546  -725.844437  300.457362  2111.160692
# 171 -349.850499  2396.882926  -451.058926 -346.594126  2309.381256
# 172  134.268440  2214.744820  -745.822122  138.167993  2090.633710
# 173  -46.359877  2316.732766  -644.515080    7.563078  2186.901628
#
#               z2          x3           y3           z3          x4  ...  \
# 0    -948.543017  -62.987701  2188.507166  -994.981357  -60.350077  ...
# 1   -1071.620664  449.725030  2040.002438 -1028.579191  456.277085  ...
# 2    -639.252635  288.547755  2059.209689  -641.671771  284.707917  ...
# 3    -580.785871  268.664400  2042.700009  -587.652513  254.637416  ...
# 4   -1009.919206 -222.619424  2228.886444 -1055.786385 -217.460942  ...
# ..           ...         ...          ...          ...         ...  ...
# 169  -812.450184    9.490540  2141.458634  -815.969983   -7.232544  ...
# 170  -723.631360  312.090338  2026.632278  -722.308556  285.730223  ...
# 171  -460.810169 -312.015187  2216.991608  -473.009715 -317.543486  ...
# 172  -751.922053  155.947883  1960.108427  -763.491681  195.374704  ...
# 173  -639.918495    3.925922  2073.002782  -647.176693  -15.327114  ...
#
#               y5           z5          x6           y6           z6      dt12  \
# 0    2019.049647 -1078.225317  -39.574118  1940.239407 -1095.573730  0.015990
# 1    1947.416272  -944.892586  449.060143  1902.719622  -908.198048  0.018970
# 2    1916.498459  -652.391242  283.148866  1848.875799  -663.266168  0.013870
# 3    1919.223452  -607.556244  243.915010  1857.053453  -622.867104  0.014602
# 4    2068.444746 -1086.714301 -216.028185  2003.293158 -1050.747286  0.016248
# ..           ...          ...         ...          ...          ...       ...
# 169  1994.155582  -824.026438   -3.106156  1921.575984  -831.025998  0.017031
# 170  1869.467266  -734.240996  315.592701  1794.913611  -745.201837  0.016195
# 171  2049.195353  -499.994165 -269.184671  1960.473606  -514.069410  0.014879
# 172  1705.800500  -782.718900  209.217627  1578.180315  -805.043850  0.020840
# 173  1848.145018  -667.845255    4.276656  1737.200351  -682.773193  0.015524
#
#          dt23      dt34      dt45      dt56
# 0    0.014135  0.013817  0.015170  0.016195
# 1    0.012854  0.015424  0.015978  0.015356
# 2    0.015055  0.016145  0.016737  0.015873
# 3    0.014228  0.014433  0.014906  0.014231
# 4    0.018445  0.015869  0.015259  0.014829
# ..        ...       ...       ...       ...
# 169  0.015380  0.019013  0.015015  0.014874
# 170  0.016095  0.016151  0.014567  0.016605
# 171  0.014785  0.017642  0.014556  0.013738
# 172  0.018006  0.016954  0.016826  0.013607
# 173  0.015512  0.015079  0.014223  0.013373
#
# [174 rows x 23 columns]

# %%
# View the inputs
print(y_real)
# Out:
#           x_hit       y_hit        z_hit      vx_hit       vy_hit  \
# 0      0.424086  -44.678074  -919.778583   77.757196 -2023.382444
# 1    343.190522    5.096790  -908.526012  -38.598108 -1365.390515
# 2    221.752370  -30.009061  -860.058778  -11.873004 -2160.765072
# 3      3.658612   87.490100  -984.491569 -155.797919 -1586.262774
# 4    -94.434291  -40.519740  -858.932457  295.249851 -1989.955558
# ..          ...         ...          ...         ...          ...
# 169 -139.410843  159.428019 -1002.149791 -228.028217 -2323.420077
# 170  473.934800   67.922302  -838.145283  326.794971 -2294.509533
# 171   14.342893  298.007752  -809.475895  324.918755 -2542.244286
# 172  431.978764  -30.748503  -926.509678  738.888217 -4744.416039
# 173 -122.836449   55.266051  -944.426956 -640.771022 -4392.190529
#
#           vz_hit     t_hit
# 0    1366.177086  0.594794
# 1   -1373.832949  0.893915
# 2   -1119.426904  0.604989
# 3   -2119.605352  0.721950
# 4     633.676458  0.632190
# ..           ...       ...
# 169 -1288.402363  0.525291
# 170  -234.963546  0.456784
# 171  1460.591096  0.394166
# 172  1565.191380  0.241532
# 173  1748.407300  0.298054
#
# [174 rows x 7 columns]

# %%
x_real = x_real.values
y_real = y_real.values

# %% [markdown]
# ### Splitting the Dataset into the Training set and Test set

# %%
# Split input/output and reachability together
stratify_real = r_real if np.unique(r_real).size > 1 else None
x_real_train, x_real_test, y_real_train, y_real_test, r_real_train, r_real_test = train_test_split(
    x_real,
    y_real,
    r_real,
    test_size=0.2,
    random_state=1,
    stratify=stratify_real,
)

# %%
print(x_real_train.shape)
print(x_real_test.shape)
print(y_real_train.shape)
print(y_real_test.shape)
print('Real train reachable %:', 100.0 * np.mean(r_real_train))
print('Real test reachable %:', 100.0 * np.mean(r_real_test))
# Out:
# (139, 23)
# (35, 23)
# (139, 7)
# (35, 7)
# Real train reachable %: 94.96402877697841
# Real test reachable %: 94.28571428571428

# %% [markdown]
# ### Scaling the real dataset

# %%
x_real_train_s = scx.transform(x_real_train)
x_real_test_s = scx.transform(x_real_test)
y_real_train_s = scy.transform(y_real_train)
y_real_test_s = scy.transform(y_real_test)

# Use actual reachability flags when available for consistency with weighted loss.
sample_w_real = build_sample_weights(
    y_real_train_s,
    scy,
    reachable_vec=r_real_train,
)
print('sample_w_real stats:', sample_w_real.min(), sample_w_real.mean(), sample_w_real.max())
# Out:
# sample_w_real stats: 0.5 1.007918524873721 1.4850158761576489

# %%
# ### WEighting the xyz more than velocities

# # Output order must match your y columns:
# # [x_hit, y_hit, z_hit, vx_hit, vy_hit, vz_hit, t_hit]
# raw_w = tf.constant([10.0, 10.0, 10.0, 1.0, 1.0, 1.0, 5.0], dtype=tf.float32)

# # normalize so average weight is ~1 (keeps loss scale stable)
# output_weights = raw_w / tf.reduce_mean(raw_w)

# def weighted_mse(y_true, y_pred):
#     err2 = tf.square(y_true - y_pred)              # (batch, 7)
#     weighted_err2 = err2 * output_weights          # broadcast on 7 outputs
#     return tf.reduce_mean(weighted_err2)

# %% [markdown]
# ## Training the New Layers (Classification Layers)

# %%
# Start from synthetic-pretrained weights
transfer_model = tf.keras.models.clone_model(ball_predictor)
transfer_model.set_weights(ball_predictor.get_weights())

# Stage 1: freeze first 2 layers (tuned baseline)
for layer in transfer_model.layers[:2]:
    layer.trainable = False

transfer_model.compile(
    loss=weighted_mse,
    optimizer=Adam(learning_rate=1e-4),
    metrics=['mean_squared_error']
)

history_stage1 = transfer_model.fit(
    x_real_train_s, y_real_train_s,
    sample_weight=sample_w_real,
    validation_split=0.2,
    epochs=120,
    batch_size=16,
    verbose=1
)


# # Matched-synthetic stage (optional, currently disabled in this broad-only workflow)
# # transfer_model_matched = tf.keras.models.clone_model(
# #     ball_predictor,
# #     clone_function=clone_with_l2
# # )
# # transfer_model_matched.set_weights(ball_predictor.get_weights())
# #
# # for layer in transfer_model_matched.layers:
# #     layer.trainable = True
# #
# # transfer_model_matched.compile(
# #     loss=weighted_mse,
# #     optimizer=Adam(learning_rate=1e-4),
# #     metrics=['mean_squared_error']
# # )
# #
# # history_matched = transfer_model_matched.fit(
# #     x_matched_train_s, y_matched_train_s,
# #     sample_weight=sample_w_matched,
# #     validation_split=0.2,
# #     epochs=40,
# #     verbose=1
# # )
# Out:
# Epoch 1/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2614 - mean_squared_error: 1.2065 - val_loss: 0.2689 - val_mean_squared_error: 1.1329
# Epoch 2/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2440 - mean_squared_error: 1.1326 - val_loss: 0.2511 - val_mean_squared_error: 1.0539
# Epoch 3/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2283 - mean_squared_error: 1.0596 - val_loss: 0.2352 - val_mean_squared_error: 0.9772
# Epoch 4/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2157 - mean_squared_error: 0.9939 - val_loss: 0.2203 - val_mean_squared_error: 0.9060
# Epoch 5/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2033 - mean_squared_error: 0.9300 - val_loss: 0.2072 - val_mean_squared_error: 0.8385
# Epoch 6/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1926 - mean_squared_error: 0.8718 - val_loss: 0.1952 - val_mean_squared_error: 0.7766
# Epoch 7/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1831 - mean_squared_error: 0.8174 - val_loss: 0.1841 - val_mean_squared_error: 0.7193
# Epoch 8/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1736 - mean_squared_error: 0.7673 - val_loss: 0.1743 - val_mean_squared_error: 0.6674
# Epoch 9/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1652 - mean_squared_error: 0.7215 - val_loss: 0.1657 - val_mean_squared_error: 0.6193
# Epoch 10/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1576 - mean_squared_error: 0.6801 - val_loss: 0.1578 - val_mean_squared_error: 0.5761
# Epoch 11/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1508 - mean_squared_error: 0.6415 - val_loss: 0.1505 - val_mean_squared_error: 0.5366
# Epoch 12/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1444 - mean_squared_error: 0.6069 - val_loss: 0.1443 - val_mean_squared_error: 0.5013
# Epoch 13/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1387 - mean_squared_error: 0.5746 - val_loss: 0.1385 - val_mean_squared_error: 0.4689
# Epoch 14/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1333 - mean_squared_error: 0.5457 - val_loss: 0.1333 - val_mean_squared_error: 0.4390
# Epoch 15/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1283 - mean_squared_error: 0.5190 - val_loss: 0.1287 - val_mean_squared_error: 0.4123
# Epoch 16/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1240 - mean_squared_error: 0.4943 - val_loss: 0.1244 - val_mean_squared_error: 0.3880
# Epoch 17/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1195 - mean_squared_error: 0.4730 - val_loss: 0.1204 - val_mean_squared_error: 0.3660
# Epoch 18/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1157 - mean_squared_error: 0.4530 - val_loss: 0.1167 - val_mean_squared_error: 0.3452
# Epoch 19/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1122 - mean_squared_error: 0.4347 - val_loss: 0.1135 - val_mean_squared_error: 0.3276
# Epoch 20/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1091 - mean_squared_error: 0.4192 - val_loss: 0.1108 - val_mean_squared_error: 0.3118
# Epoch 21/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1061 - mean_squared_error: 0.4047 - val_loss: 0.1079 - val_mean_squared_error: 0.2966
# Epoch 22/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1035 - mean_squared_error: 0.3913 - val_loss: 0.1059 - val_mean_squared_error: 0.2831
# Epoch 23/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1010 - mean_squared_error: 0.3791 - val_loss: 0.1041 - val_mean_squared_error: 0.2708
# Epoch 24/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0986 - mean_squared_error: 0.3673 - val_loss: 0.1025 - val_mean_squared_error: 0.2593
# Epoch 25/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0965 - mean_squared_error: 0.3571 - val_loss: 0.1007 - val_mean_squared_error: 0.2487
# Epoch 26/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0943 - mean_squared_error: 0.3472 - val_loss: 0.0995 - val_mean_squared_error: 0.2397
# Epoch 27/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0925 - mean_squared_error: 0.3390 - val_loss: 0.0981 - val_mean_squared_error: 0.2309
# Epoch 28/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0907 - mean_squared_error: 0.3309 - val_loss: 0.0967 - val_mean_squared_error: 0.2231
# Epoch 29/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0889 - mean_squared_error: 0.3236 - val_loss: 0.0950 - val_mean_squared_error: 0.2150
# Epoch 30/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0873 - mean_squared_error: 0.3162 - val_loss: 0.0935 - val_mean_squared_error: 0.2073
# Epoch 31/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0857 - mean_squared_error: 0.3094 - val_loss: 0.0926 - val_mean_squared_error: 0.2011
# Epoch 32/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0843 - mean_squared_error: 0.3031 - val_loss: 0.0917 - val_mean_squared_error: 0.1953
# Epoch 33/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0830 - mean_squared_error: 0.2972 - val_loss: 0.0904 - val_mean_squared_error: 0.1898
# Epoch 34/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0817 - mean_squared_error: 0.2921 - val_loss: 0.0891 - val_mean_squared_error: 0.1846
# Epoch 35/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0805 - mean_squared_error: 0.2873 - val_loss: 0.0881 - val_mean_squared_error: 0.1798
# Epoch 36/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0793 - mean_squared_error: 0.2824 - val_loss: 0.0869 - val_mean_squared_error: 0.1752
# Epoch 37/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0782 - mean_squared_error: 0.2780 - val_loss: 0.0859 - val_mean_squared_error: 0.1709
# Epoch 38/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0772 - mean_squared_error: 0.2737 - val_loss: 0.0850 - val_mean_squared_error: 0.1673
# Epoch 39/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0761 - mean_squared_error: 0.2698 - val_loss: 0.0843 - val_mean_squared_error: 0.1638
# Epoch 40/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0752 - mean_squared_error: 0.2662 - val_loss: 0.0835 - val_mean_squared_error: 0.1608
# Epoch 41/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0743 - mean_squared_error: 0.2625 - val_loss: 0.0827 - val_mean_squared_error: 0.1578
# Epoch 42/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0734 - mean_squared_error: 0.2593 - val_loss: 0.0820 - val_mean_squared_error: 0.1546
# Epoch 43/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0725 - mean_squared_error: 0.2557 - val_loss: 0.0816 - val_mean_squared_error: 0.1521
# Epoch 44/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0716 - mean_squared_error: 0.2526 - val_loss: 0.0810 - val_mean_squared_error: 0.1495
# Epoch 45/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0708 - mean_squared_error: 0.2497 - val_loss: 0.0806 - val_mean_squared_error: 0.1475
# Epoch 46/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0700 - mean_squared_error: 0.2467 - val_loss: 0.0803 - val_mean_squared_error: 0.1456
# Epoch 47/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0694 - mean_squared_error: 0.2445 - val_loss: 0.0795 - val_mean_squared_error: 0.1433
# Epoch 48/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0686 - mean_squared_error: 0.2418 - val_loss: 0.0791 - val_mean_squared_error: 0.1416
# Epoch 49/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0679 - mean_squared_error: 0.2395 - val_loss: 0.0788 - val_mean_squared_error: 0.1401
# Epoch 50/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0672 - mean_squared_error: 0.2373 - val_loss: 0.0784 - val_mean_squared_error: 0.1387
# Epoch 51/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0666 - mean_squared_error: 0.2353 - val_loss: 0.0780 - val_mean_squared_error: 0.1373
# Epoch 52/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0660 - mean_squared_error: 0.2333 - val_loss: 0.0777 - val_mean_squared_error: 0.1360
# Epoch 53/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0654 - mean_squared_error: 0.2315 - val_loss: 0.0774 - val_mean_squared_error: 0.1346
# Epoch 54/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0648 - mean_squared_error: 0.2298 - val_loss: 0.0772 - val_mean_squared_error: 0.1338
# Epoch 55/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0643 - mean_squared_error: 0.2281 - val_loss: 0.0770 - val_mean_squared_error: 0.1328
# Epoch 56/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0637 - mean_squared_error: 0.2263 - val_loss: 0.0768 - val_mean_squared_error: 0.1321
# Epoch 57/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0632 - mean_squared_error: 0.2248 - val_loss: 0.0767 - val_mean_squared_error: 0.1312
# Epoch 58/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0628 - mean_squared_error: 0.2233 - val_loss: 0.0764 - val_mean_squared_error: 0.1302
# Epoch 59/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0623 - mean_squared_error: 0.2219 - val_loss: 0.0764 - val_mean_squared_error: 0.1297
# Epoch 60/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0619 - mean_squared_error: 0.2208 - val_loss: 0.0766 - val_mean_squared_error: 0.1295
# Epoch 61/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0614 - mean_squared_error: 0.2195 - val_loss: 0.0761 - val_mean_squared_error: 0.1286
# Epoch 62/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0610 - mean_squared_error: 0.2182 - val_loss: 0.0759 - val_mean_squared_error: 0.1278
# Epoch 63/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0606 - mean_squared_error: 0.2174 - val_loss: 0.0758 - val_mean_squared_error: 0.1273
# Epoch 64/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0602 - mean_squared_error: 0.2161 - val_loss: 0.0756 - val_mean_squared_error: 0.1266
# Epoch 65/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0599 - mean_squared_error: 0.2151 - val_loss: 0.0753 - val_mean_squared_error: 0.1259
# Epoch 66/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0595 - mean_squared_error: 0.2142 - val_loss: 0.0752 - val_mean_squared_error: 0.1254
# Epoch 67/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0592 - mean_squared_error: 0.2135 - val_loss: 0.0749 - val_mean_squared_error: 0.1247
# Epoch 68/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0588 - mean_squared_error: 0.2125 - val_loss: 0.0746 - val_mean_squared_error: 0.1243
# Epoch 69/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0585 - mean_squared_error: 0.2118 - val_loss: 0.0745 - val_mean_squared_error: 0.1239
# Epoch 70/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0582 - mean_squared_error: 0.2110 - val_loss: 0.0744 - val_mean_squared_error: 0.1237
# Epoch 71/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0578 - mean_squared_error: 0.2103 - val_loss: 0.0745 - val_mean_squared_error: 0.1234
# Epoch 72/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0576 - mean_squared_error: 0.2097 - val_loss: 0.0744 - val_mean_squared_error: 0.1230
# Epoch 73/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0573 - mean_squared_error: 0.2091 - val_loss: 0.0742 - val_mean_squared_error: 0.1228
# Epoch 74/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0570 - mean_squared_error: 0.2085 - val_loss: 0.0742 - val_mean_squared_error: 0.1226
# Epoch 75/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0567 - mean_squared_error: 0.2078 - val_loss: 0.0741 - val_mean_squared_error: 0.1222
# Epoch 76/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0565 - mean_squared_error: 0.2071 - val_loss: 0.0740 - val_mean_squared_error: 0.1217
# Epoch 77/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0562 - mean_squared_error: 0.2065 - val_loss: 0.0739 - val_mean_squared_error: 0.1216
# Epoch 78/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0560 - mean_squared_error: 0.2061 - val_loss: 0.0738 - val_mean_squared_error: 0.1212
# Epoch 79/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0557 - mean_squared_error: 0.2055 - val_loss: 0.0733 - val_mean_squared_error: 0.1208
# Epoch 80/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0555 - mean_squared_error: 0.2050 - val_loss: 0.0734 - val_mean_squared_error: 0.1208
# Epoch 81/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0552 - mean_squared_error: 0.2046 - val_loss: 0.0732 - val_mean_squared_error: 0.1205
# Epoch 82/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0550 - mean_squared_error: 0.2040 - val_loss: 0.0731 - val_mean_squared_error: 0.1203
# Epoch 83/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0548 - mean_squared_error: 0.2035 - val_loss: 0.0734 - val_mean_squared_error: 0.1204
# Epoch 84/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0545 - mean_squared_error: 0.2031 - val_loss: 0.0732 - val_mean_squared_error: 0.1200
# Epoch 85/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0543 - mean_squared_error: 0.2025 - val_loss: 0.0729 - val_mean_squared_error: 0.1194
# Epoch 86/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0541 - mean_squared_error: 0.2020 - val_loss: 0.0726 - val_mean_squared_error: 0.1192
# Epoch 87/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0539 - mean_squared_error: 0.2015 - val_loss: 0.0725 - val_mean_squared_error: 0.1190
# Epoch 88/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0537 - mean_squared_error: 0.2011 - val_loss: 0.0723 - val_mean_squared_error: 0.1186
# Epoch 89/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0534 - mean_squared_error: 0.2006 - val_loss: 0.0725 - val_mean_squared_error: 0.1188
# Epoch 90/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0533 - mean_squared_error: 0.2001 - val_loss: 0.0723 - val_mean_squared_error: 0.1185
# Epoch 91/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0530 - mean_squared_error: 0.1997 - val_loss: 0.0723 - val_mean_squared_error: 0.1184
# Epoch 92/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0529 - mean_squared_error: 0.1994 - val_loss: 0.0723 - val_mean_squared_error: 0.1184
# Epoch 93/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0526 - mean_squared_error: 0.1989 - val_loss: 0.0722 - val_mean_squared_error: 0.1180
# Epoch 94/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0524 - mean_squared_error: 0.1984 - val_loss: 0.0721 - val_mean_squared_error: 0.1179
# Epoch 95/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0522 - mean_squared_error: 0.1981 - val_loss: 0.0720 - val_mean_squared_error: 0.1178
# Epoch 96/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0520 - mean_squared_error: 0.1977 - val_loss: 0.0721 - val_mean_squared_error: 0.1176
# Epoch 97/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0518 - mean_squared_error: 0.1973 - val_loss: 0.0718 - val_mean_squared_error: 0.1172
# Epoch 98/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0516 - mean_squared_error: 0.1969 - val_loss: 0.0717 - val_mean_squared_error: 0.1172
# Epoch 99/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0514 - mean_squared_error: 0.1965 - val_loss: 0.0718 - val_mean_squared_error: 0.1173
# Epoch 100/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0513 - mean_squared_error: 0.1961 - val_loss: 0.0716 - val_mean_squared_error: 0.1171
# Epoch 101/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0511 - mean_squared_error: 0.1957 - val_loss: 0.0715 - val_mean_squared_error: 0.1167
# Epoch 102/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0509 - mean_squared_error: 0.1954 - val_loss: 0.0713 - val_mean_squared_error: 0.1167
# Epoch 103/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0507 - mean_squared_error: 0.1950 - val_loss: 0.0711 - val_mean_squared_error: 0.1166
# Epoch 104/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0505 - mean_squared_error: 0.1946 - val_loss: 0.0710 - val_mean_squared_error: 0.1165
# Epoch 105/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0503 - mean_squared_error: 0.1939 - val_loss: 0.0709 - val_mean_squared_error: 0.1162
# Epoch 106/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0501 - mean_squared_error: 0.1934 - val_loss: 0.0711 - val_mean_squared_error: 0.1162
# Epoch 107/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0499 - mean_squared_error: 0.1930 - val_loss: 0.0713 - val_mean_squared_error: 0.1163
# Epoch 108/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0498 - mean_squared_error: 0.1926 - val_loss: 0.0711 - val_mean_squared_error: 0.1160
# Epoch 109/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0496 - mean_squared_error: 0.1921 - val_loss: 0.0710 - val_mean_squared_error: 0.1159
# Epoch 110/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0494 - mean_squared_error: 0.1918 - val_loss: 0.0710 - val_mean_squared_error: 0.1158
# Epoch 111/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0492 - mean_squared_error: 0.1914 - val_loss: 0.0711 - val_mean_squared_error: 0.1158
# Epoch 112/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0491 - mean_squared_error: 0.1909 - val_loss: 0.0709 - val_mean_squared_error: 0.1157
# Epoch 113/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0489 - mean_squared_error: 0.1904 - val_loss: 0.0708 - val_mean_squared_error: 0.1155
# Epoch 114/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0487 - mean_squared_error: 0.1899 - val_loss: 0.0707 - val_mean_squared_error: 0.1153
# Epoch 115/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0486 - mean_squared_error: 0.1895 - val_loss: 0.0705 - val_mean_squared_error: 0.1152
# Epoch 116/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0484 - mean_squared_error: 0.1892 - val_loss: 0.0705 - val_mean_squared_error: 0.1151
# Epoch 117/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0482 - mean_squared_error: 0.1888 - val_loss: 0.0704 - val_mean_squared_error: 0.1151
# Epoch 118/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0481 - mean_squared_error: 0.1884 - val_loss: 0.0702 - val_mean_squared_error: 0.1146
# Epoch 119/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0479 - mean_squared_error: 0.1880 - val_loss: 0.0705 - val_mean_squared_error: 0.1151
# Epoch 120/120
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0478 - mean_squared_error: 0.1875 - val_loss: 0.0701 - val_mean_squared_error: 0.1148

# %% [markdown]
# ## Stage 1 Validation Curve

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12,4))
ax.plot(history_stage1.history["loss"], label="Train")
ax.plot(history_stage1.history["val_loss"], label="Validation")
ax.set_title("Stage 1 Learning Curves")
ax.set_xlabel("Epoch")
ax.set_ylabel("Loss")
ax.legend()
plt.show()

# %%
eval_with_units(
    "Stage 1 Transfer Model - Real Test",
    transfer_model,
    x_real_test_s,
    y_real_test_s,
    scy,
    y_is_scaled=True,
    t_hit_in_seconds=True
)
# Out:
# Stage 1 Transfer Model - Real Test
# target unit     MAE      RMSE  STD_abs_error
#  x_hit   mm  75.326    97.191         61.418
#  y_hit   mm  89.520   109.179         62.500
#  z_hit   mm  42.253    54.415         34.289
# vx_hit mm/s 372.541   581.875        446.981
# vy_hit mm/s 336.721   453.677        304.043
# vz_hit mm/s 861.561 1,042.926        587.714
#  t_hit   ms  64.179    81.822         50.754

# %%
def snapshot_model(model):
    with tf.keras.utils.custom_object_scope({'weighted_mse': weighted_mse}):
        m = tf.keras.models.clone_model(model)
    m.set_weights(model.get_weights())
    return m

# --- run this RIGHT AFTER stage 1 training/eval ---
stage1_model = snapshot_model(transfer_model)
print("Saved stage1_model snapshot.")
# Out:
# Saved stage1_model snapshot.

# %%
# Stage 2: unfreeze all layers (tuned baseline)
for layer in transfer_model.layers:
    layer.trainable = True

transfer_model.compile(
    loss=weighted_mse,
    optimizer=Adam(learning_rate=5e-5),
    metrics=['mean_squared_error']
)

history_stage2 = transfer_model.fit(
    x_real_train_s, y_real_train_s,
    sample_weight=sample_w_real,
    validation_split=0.2,
    epochs=80,
    batch_size=16,
    verbose=1
)
# Out:
# Epoch 1/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0479 - mean_squared_error: 0.1876 - val_loss: 0.0696 - val_mean_squared_error: 0.1143
# Epoch 2/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0473 - mean_squared_error: 0.1869 - val_loss: 0.0700 - val_mean_squared_error: 0.1143
# Epoch 3/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0470 - mean_squared_error: 0.1862 - val_loss: 0.0702 - val_mean_squared_error: 0.1143
# Epoch 4/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0467 - mean_squared_error: 0.1857 - val_loss: 0.0703 - val_mean_squared_error: 0.1142
# Epoch 5/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0464 - mean_squared_error: 0.1849 - val_loss: 0.0704 - val_mean_squared_error: 0.1140
# Epoch 6/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0462 - mean_squared_error: 0.1844 - val_loss: 0.0704 - val_mean_squared_error: 0.1138
# Epoch 7/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0459 - mean_squared_error: 0.1838 - val_loss: 0.0704 - val_mean_squared_error: 0.1137
# Epoch 8/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0457 - mean_squared_error: 0.1834 - val_loss: 0.0706 - val_mean_squared_error: 0.1140
# Epoch 9/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0455 - mean_squared_error: 0.1829 - val_loss: 0.0706 - val_mean_squared_error: 0.1141
# Epoch 10/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0452 - mean_squared_error: 0.1822 - val_loss: 0.0704 - val_mean_squared_error: 0.1138
# Epoch 11/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0450 - mean_squared_error: 0.1818 - val_loss: 0.0702 - val_mean_squared_error: 0.1134
# Epoch 12/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0448 - mean_squared_error: 0.1814 - val_loss: 0.0702 - val_mean_squared_error: 0.1134
# Epoch 13/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0447 - mean_squared_error: 0.1809 - val_loss: 0.0702 - val_mean_squared_error: 0.1136
# Epoch 14/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0444 - mean_squared_error: 0.1804 - val_loss: 0.0701 - val_mean_squared_error: 0.1133
# Epoch 15/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0442 - mean_squared_error: 0.1798 - val_loss: 0.0700 - val_mean_squared_error: 0.1132
# Epoch 16/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0440 - mean_squared_error: 0.1792 - val_loss: 0.0699 - val_mean_squared_error: 0.1132
# Epoch 17/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0438 - mean_squared_error: 0.1787 - val_loss: 0.0698 - val_mean_squared_error: 0.1130
# Epoch 18/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0437 - mean_squared_error: 0.1783 - val_loss: 0.0696 - val_mean_squared_error: 0.1128
# Epoch 19/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0435 - mean_squared_error: 0.1778 - val_loss: 0.0696 - val_mean_squared_error: 0.1128
# Epoch 20/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0433 - mean_squared_error: 0.1773 - val_loss: 0.0696 - val_mean_squared_error: 0.1128
# Epoch 21/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0431 - mean_squared_error: 0.1769 - val_loss: 0.0695 - val_mean_squared_error: 0.1125
# Epoch 22/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0430 - mean_squared_error: 0.1766 - val_loss: 0.0694 - val_mean_squared_error: 0.1123
# Epoch 23/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0428 - mean_squared_error: 0.1761 - val_loss: 0.0696 - val_mean_squared_error: 0.1124
# Epoch 24/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0426 - mean_squared_error: 0.1755 - val_loss: 0.0693 - val_mean_squared_error: 0.1123
# Epoch 25/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0425 - mean_squared_error: 0.1752 - val_loss: 0.0691 - val_mean_squared_error: 0.1122
# Epoch 26/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0423 - mean_squared_error: 0.1745 - val_loss: 0.0688 - val_mean_squared_error: 0.1119
# Epoch 27/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0422 - mean_squared_error: 0.1742 - val_loss: 0.0690 - val_mean_squared_error: 0.1120
# Epoch 28/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0420 - mean_squared_error: 0.1739 - val_loss: 0.0688 - val_mean_squared_error: 0.1118
# Epoch 29/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0418 - mean_squared_error: 0.1735 - val_loss: 0.0688 - val_mean_squared_error: 0.1117
# Epoch 30/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0417 - mean_squared_error: 0.1731 - val_loss: 0.0688 - val_mean_squared_error: 0.1117
# Epoch 31/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0415 - mean_squared_error: 0.1726 - val_loss: 0.0687 - val_mean_squared_error: 0.1115
# Epoch 32/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0414 - mean_squared_error: 0.1722 - val_loss: 0.0686 - val_mean_squared_error: 0.1114
# Epoch 33/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0412 - mean_squared_error: 0.1718 - val_loss: 0.0686 - val_mean_squared_error: 0.1113
# Epoch 34/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0411 - mean_squared_error: 0.1715 - val_loss: 0.0684 - val_mean_squared_error: 0.1111
# Epoch 35/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0409 - mean_squared_error: 0.1710 - val_loss: 0.0684 - val_mean_squared_error: 0.1109
# Epoch 36/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0407 - mean_squared_error: 0.1706 - val_loss: 0.0684 - val_mean_squared_error: 0.1108
# Epoch 37/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0406 - mean_squared_error: 0.1702 - val_loss: 0.0683 - val_mean_squared_error: 0.1106
# Epoch 38/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0404 - mean_squared_error: 0.1699 - val_loss: 0.0680 - val_mean_squared_error: 0.1106
# Epoch 39/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0403 - mean_squared_error: 0.1695 - val_loss: 0.0680 - val_mean_squared_error: 0.1104
# Epoch 40/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0402 - mean_squared_error: 0.1692 - val_loss: 0.0677 - val_mean_squared_error: 0.1102
# Epoch 41/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0400 - mean_squared_error: 0.1687 - val_loss: 0.0677 - val_mean_squared_error: 0.1100
# Epoch 42/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0398 - mean_squared_error: 0.1683 - val_loss: 0.0676 - val_mean_squared_error: 0.1099
# Epoch 43/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0397 - mean_squared_error: 0.1679 - val_loss: 0.0676 - val_mean_squared_error: 0.1099
# Epoch 44/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0396 - mean_squared_error: 0.1676 - val_loss: 0.0677 - val_mean_squared_error: 0.1099
# Epoch 45/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0394 - mean_squared_error: 0.1670 - val_loss: 0.0675 - val_mean_squared_error: 0.1097
# Epoch 46/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0393 - mean_squared_error: 0.1666 - val_loss: 0.0676 - val_mean_squared_error: 0.1097
# Epoch 47/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0392 - mean_squared_error: 0.1662 - val_loss: 0.0675 - val_mean_squared_error: 0.1097
# Epoch 48/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0390 - mean_squared_error: 0.1659 - val_loss: 0.0676 - val_mean_squared_error: 0.1097
# Epoch 49/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0389 - mean_squared_error: 0.1653 - val_loss: 0.0674 - val_mean_squared_error: 0.1094
# Epoch 50/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0387 - mean_squared_error: 0.1649 - val_loss: 0.0672 - val_mean_squared_error: 0.1091
# Epoch 51/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0386 - mean_squared_error: 0.1645 - val_loss: 0.0672 - val_mean_squared_error: 0.1091
# Epoch 52/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0384 - mean_squared_error: 0.1639 - val_loss: 0.0670 - val_mean_squared_error: 0.1090
# Epoch 53/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0383 - mean_squared_error: 0.1634 - val_loss: 0.0670 - val_mean_squared_error: 0.1090
# Epoch 54/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0382 - mean_squared_error: 0.1631 - val_loss: 0.0669 - val_mean_squared_error: 0.1088
# Epoch 55/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0380 - mean_squared_error: 0.1627 - val_loss: 0.0668 - val_mean_squared_error: 0.1086
# Epoch 56/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0379 - mean_squared_error: 0.1621 - val_loss: 0.0668 - val_mean_squared_error: 0.1086
# Epoch 57/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0378 - mean_squared_error: 0.1616 - val_loss: 0.0667 - val_mean_squared_error: 0.1086
# Epoch 58/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0376 - mean_squared_error: 0.1612 - val_loss: 0.0667 - val_mean_squared_error: 0.1086
# Epoch 59/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0375 - mean_squared_error: 0.1609 - val_loss: 0.0666 - val_mean_squared_error: 0.1086
# Epoch 60/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0374 - mean_squared_error: 0.1603 - val_loss: 0.0665 - val_mean_squared_error: 0.1084
# Epoch 61/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0372 - mean_squared_error: 0.1599 - val_loss: 0.0663 - val_mean_squared_error: 0.1081
# Epoch 62/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0371 - mean_squared_error: 0.1595 - val_loss: 0.0662 - val_mean_squared_error: 0.1080
# Epoch 63/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0370 - mean_squared_error: 0.1590 - val_loss: 0.0660 - val_mean_squared_error: 0.1078
# Epoch 64/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0368 - mean_squared_error: 0.1584 - val_loss: 0.0659 - val_mean_squared_error: 0.1076
# Epoch 65/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0367 - mean_squared_error: 0.1582 - val_loss: 0.0659 - val_mean_squared_error: 0.1077
# Epoch 66/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0365 - mean_squared_error: 0.1578 - val_loss: 0.0658 - val_mean_squared_error: 0.1076
# Epoch 67/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0364 - mean_squared_error: 0.1574 - val_loss: 0.0657 - val_mean_squared_error: 0.1075
# Epoch 68/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0363 - mean_squared_error: 0.1570 - val_loss: 0.0656 - val_mean_squared_error: 0.1073
# Epoch 69/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0361 - mean_squared_error: 0.1566 - val_loss: 0.0655 - val_mean_squared_error: 0.1071
# Epoch 70/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0360 - mean_squared_error: 0.1561 - val_loss: 0.0653 - val_mean_squared_error: 0.1070
# Epoch 71/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0359 - mean_squared_error: 0.1557 - val_loss: 0.0653 - val_mean_squared_error: 0.1070
# Epoch 72/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0357 - mean_squared_error: 0.1552 - val_loss: 0.0651 - val_mean_squared_error: 0.1068
# Epoch 73/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0356 - mean_squared_error: 0.1548 - val_loss: 0.0651 - val_mean_squared_error: 0.1069
# Epoch 74/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0355 - mean_squared_error: 0.1544 - val_loss: 0.0646 - val_mean_squared_error: 0.1065
# Epoch 75/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0353 - mean_squared_error: 0.1541 - val_loss: 0.0647 - val_mean_squared_error: 0.1063
# Epoch 76/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0352 - mean_squared_error: 0.1540 - val_loss: 0.0648 - val_mean_squared_error: 0.1064
# Epoch 77/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0350 - mean_squared_error: 0.1535 - val_loss: 0.0646 - val_mean_squared_error: 0.1062
# Epoch 78/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0349 - mean_squared_error: 0.1531 - val_loss: 0.0644 - val_mean_squared_error: 0.1060
# Epoch 79/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0348 - mean_squared_error: 0.1528 - val_loss: 0.0645 - val_mean_squared_error: 0.1061
# Epoch 80/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0347 - mean_squared_error: 0.1524 - val_loss: 0.0643 - val_mean_squared_error: 0.1059

# %%
fig, ax = plt.subplots(figsize=(12,4))
ax.plot(history_stage2.history["loss"], label="Train")
ax.plot(history_stage2.history["val_loss"], label="Validation")
ax.set_title("Stage 2 Learning Curves")
ax.set_xlabel("Epoch")
ax.set_ylabel("Loss")
ax.legend()
plt.show()

# %%
eval_with_units(
    "Stage 2 Final Transfer Model - Real Test",
    transfer_model,
    x_real_test_s,
    y_real_test_s,
    scy,
    y_is_scaled=True,
    t_hit_in_seconds=True
)
# Out:
# WARNING:tensorflow:5 out of the last 27 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000170B9D36B60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
# Stage 2 Final Transfer Model - Real Test
# target unit     MAE    RMSE  STD_abs_error
#  x_hit   mm  73.591  97.063         63.289
#  y_hit   mm  89.855 110.615         64.512
#  z_hit   mm  36.762  48.778         32.061
# vx_hit mm/s 355.861 553.160        423.495
# vy_hit mm/s 305.926 421.958        290.616
# vz_hit mm/s 765.818 951.503        564.695
#  t_hit   ms  57.041  71.658         43.373

# %%
stage2_model = snapshot_model(transfer_model)
print('Saved stage2_model snapshot.')

# Broad synthetic pretrained model snapshot
broad_model = snapshot_model(ball_predictor)
print('Saved broad_model snapshot.')

# Matched snapshot is optional (only if matched-training cells were run)
if 'transfer_model_matched' in globals():
    matched_model = snapshot_model(transfer_model_matched)
    print('Saved matched_model snapshot.')
else:
    matched_model = None
    print('No transfer_model_matched found in this run (broad-only flow).')
# Out:
# Saved stage2_model snapshot.
# Saved broad_model snapshot.
# No transfer_model_matched found in this run (broad-only flow).

# %%
# --- final comparison on real test set ---
eval_with_units('Broad model - Real Test', broad_model, x_real_test_s, y_real_test_s, scy, y_is_scaled=True, t_hit_in_seconds=True)

if matched_model is not None:
    eval_with_units('Matched model - Real Test', matched_model, x_real_test_s, y_real_test_s, scy, y_is_scaled=True, t_hit_in_seconds=True)
else:
    print('Matched model evaluation skipped (not trained in this notebook run).')

eval_with_units('Stage 1 model - Real Test', stage1_model, x_real_test_s, y_real_test_s, scy, y_is_scaled=True, t_hit_in_seconds=True)
eval_with_units('Stage 2 model - Real Test', stage2_model, x_real_test_s, y_real_test_s, scy, y_is_scaled=True, t_hit_in_seconds=True)
# Out:
# WARNING:tensorflow:6 out of the last 28 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000170B9B8CAE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
# Broad model - Real Test
# target unit       MAE      RMSE  STD_abs_error
#  x_hit   mm   108.182   139.841         88.613
#  y_hit   mm   100.509   130.873         83.819
#  z_hit   mm    82.292   111.038         74.548
# vx_hit mm/s   679.931   824.554        466.458
# vy_hit mm/s 2,486.349 2,556.782        595.989
# vz_hit mm/s 1,833.197 2,035.570        884.835
#  t_hit   ms   167.846   197.336        103.774
# Matched model evaluation skipped (not trained in this notebook run).
#
# Stage 1 model - Real Test
# target unit     MAE      RMSE  STD_abs_error
#  x_hit   mm  75.326    97.191         61.418
#  y_hit   mm  89.520   109.179         62.500
#  z_hit   mm  42.253    54.415         34.289
# vx_hit mm/s 372.541   581.875        446.981
# vy_hit mm/s 336.721   453.677        304.043
# vz_hit mm/s 861.561 1,042.926        587.714
#  t_hit   ms  64.179    81.822         50.754
#
# Stage 2 model - Real Test
# target unit     MAE    RMSE  STD_abs_error
#  x_hit   mm  73.591  97.063         63.289
#  y_hit   mm  89.855 110.615         64.512
#  z_hit   mm  36.762  48.778         32.061
# vx_hit mm/s 355.861 553.160        423.495
# vy_hit mm/s 305.926 421.958        290.616
# vz_hit mm/s 765.818 951.503        564.695
#  t_hit   ms  57.041  71.658         43.373

# %% [markdown]
# ## K-Fold Hyperparameter Tuning (Real Data)
#
# Run this section after `transfer_model_matched`, `x_real`, `y_real`, `scx`, `scy`, `weighted_mse`, and `build_sample_weights` are defined.

# %%
from sklearn.model_selection import KFold, ParameterGrid
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
import numpy as np
import pandas as pd


def clone_with_weights(model):
    with tf.keras.utils.custom_object_scope({'weighted_mse': weighted_mse}):
        m = tf.keras.models.clone_model(model)
    m.set_weights(model.get_weights())
    return m


# XYZ-only validation metric in scaled space (used for early stopping monitor)
def xyz_mse(y_true, y_pred):
    err2_xyz = tf.square(y_true[:, :3] - y_pred[:, :3])
    return tf.reduce_mean(err2_xyz, axis=-1)

# Make metric name deterministic in Keras history keys
xyz_mse.__name__ = 'xyz_mse'


def evaluate_physical_mae(model, x_val_s, y_val_s, y_scaler):
    y_pred_s = model.predict(x_val_s, verbose=0)
    y_true_u = y_scaler.inverse_transform(y_val_s)
    y_pred_u = y_scaler.inverse_transform(y_pred_s)
    mae = np.mean(np.abs(y_pred_u - y_true_u), axis=0)
    mae_ms = mae.copy()
    mae_ms[6] = mae_ms[6] * 1000.0
    return mae_ms


def run_transfer_kfold_once(x_real_raw, y_real_raw, base_model, hp, n_splits=5, seed=6):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=seed)
    fold_rows = []

    for fold_id, (tr_idx, va_idx) in enumerate(kf.split(x_real_raw), start=1):
        x_tr, x_va = x_real_raw[tr_idx], x_real_raw[va_idx]
        y_tr, y_va = y_real_raw[tr_idx], y_real_raw[va_idx]

        x_tr_s = scx.transform(x_tr)
        x_va_s = scx.transform(x_va)
        y_tr_s = scy.transform(y_tr)
        y_va_s = scy.transform(y_va)

        sample_w = build_sample_weights(
            y_tr_s, scy, reachable_vec=np.ones(y_tr_s.shape[0], dtype=int)
        )

        model = clone_with_weights(base_model)

        freeze_first_n = int(hp.get('freeze_first_n', 2))
        for layer in model.layers[:freeze_first_n]:
            layer.trainable = False

        callbacks = [
            EarlyStopping(
                monitor='val_xyz_mse',
                patience=int(hp.get('patience', 12)),
                restore_best_weights=True,
                verbose=0,
                mode='min',
            )
        ]

        model.compile(
            loss=weighted_mse,
            optimizer=Adam(learning_rate=float(hp['stage1_lr'])),
            metrics=['mean_squared_error', xyz_mse],
        )
        hist1 = model.fit(
            x_tr_s,
            y_tr_s,
            sample_weight=sample_w,
            validation_data=(x_va_s, y_va_s),
            epochs=int(hp.get('stage1_epochs', 120)),
            batch_size=int(hp.get('batch_size', 16)),
            callbacks=callbacks,
            verbose=0,
        )
        best_stage1_xyz = float(np.min(hist1.history['val_xyz_mse']))

        stage2_epochs = int(hp.get('stage2_epochs', 80))
        if stage2_epochs > 0:
            for layer in model.layers:
                layer.trainable = True

            model.compile(
                loss=weighted_mse,
                optimizer=Adam(learning_rate=float(hp['stage2_lr'])),
                metrics=['mean_squared_error', xyz_mse],
            )
            hist2 = model.fit(
                x_tr_s,
                y_tr_s,
                sample_weight=sample_w,
                validation_data=(x_va_s, y_va_s),
                epochs=stage2_epochs,
                batch_size=int(hp.get('batch_size', 16)),
                callbacks=callbacks,
                verbose=0,
            )
            best_stage2_xyz = float(np.min(hist2.history['val_xyz_mse']))
            best_val_xyz_mse = min(best_stage1_xyz, best_stage2_xyz)
        else:
            best_val_xyz_mse = best_stage1_xyz

        mae = evaluate_physical_mae(model, x_va_s, y_va_s, scy)
        mae_xyz_mm = float(np.mean(mae[:3]))

        fold_rows.append(
            {
                'fold': fold_id,
                'best_val_xyz_mse': best_val_xyz_mse,
                'mae_x_mm': mae[0],
                'mae_y_mm': mae[1],
                'mae_z_mm': mae[2],
                'mae_xyz_mm': mae_xyz_mm,
                'mae_vx_mm_s': mae[3],
                'mae_vy_mm_s': mae[4],
                'mae_vz_mm_s': mae[5],
                'mae_t_ms': mae[6],
            }
        )

        tf.keras.backend.clear_session()

    return pd.DataFrame(fold_rows)


def run_grid_kfold(x_real_raw, y_real_raw, base_model, param_grid, n_splits=5, seed=6):
    all_runs = []

    for run_id, hp in enumerate(ParameterGrid(param_grid), start=1):
        fold_df = run_transfer_kfold_once(
            x_real_raw=x_real_raw,
            y_real_raw=y_real_raw,
            base_model=base_model,
            hp=hp,
            n_splits=n_splits,
            seed=seed,
        )

        summary = {
            'run_id': run_id,
            **hp,
            'mean_mae_xyz_mm': fold_df['mae_xyz_mm'].mean(),
            'std_mae_xyz_mm': fold_df['mae_xyz_mm'].std(ddof=0),
            'mean_best_val_xyz_mse': fold_df['best_val_xyz_mse'].mean(),
            'std_best_val_xyz_mse': fold_df['best_val_xyz_mse'].std(ddof=0),
            'mae_v_mm_s': fold_df[['mae_vx_mm_s', 'mae_vy_mm_s', 'mae_vz_mm_s']].mean().mean(),
            'mae_t_ms': fold_df['mae_t_ms'].mean(),
        }
        all_runs.append(summary)
        print(
            f"[run {run_id}] mean_mae_xyz_mm={summary['mean_mae_xyz_mm']:.2f} "
            f"mean_best_val_xyz_mse={summary['mean_best_val_xyz_mse']:.4f} hp={hp}"
        )

    out_df = pd.DataFrame(all_runs).sort_values(
        ['mean_mae_xyz_mm', 'mean_best_val_xyz_mse'],
        ascending=[True, True],
    ).reset_index(drop=True)
    return out_df

# %%
# XYZ-focused ranking: results are sorted by mean_mae_xyz_mm
# K-fold hyperparameter search around your current best setup
# Current best baseline (from your last run):
# batch_size=16, freeze_first_n=2, patience=12, stage1_epochs=120, stage1_lr=1e-4, stage2_epochs=80, stage2_lr=5e-5
param_grid = {
    'freeze_first_n': [1,2],
    'stage1_lr': [1e-4, 1e-5],
    'stage2_lr': [5e-5, 3e-5],
    'batch_size': [16,32],
    'stage1_epochs': [50, 100],
    'stage2_epochs': [100, 150],
    'patience': [10],
}

kfold_results = run_grid_kfold(
    x_real_raw=x_real,
    y_real_raw=y_real,
    base_model=ball_predictor,
    param_grid=param_grid,
    n_splits=5,
    seed=6,
)

kfold_results.head(10)

# %%
from pathlib import Path
import joblib

export_dir = Path("../models/ann_stage2_big_dataset")
export_dir.mkdir(parents=True, exist_ok=True)

deploy_model = stage2_model   # or transfer_model / matched_model / broad_model
deploy_model.save(export_dir / "ball_predictor.keras")
joblib.dump(scx, export_dir / "scx.joblib")
joblib.dump(scy, export_dir / "scy.joblib")

print("Saved model + scalers to:", export_dir.resolve())
# Out:
# Saved model + scalers to: C:\Users\rocky\Personal\UBC\Year 4\IGEN 430\TableTennis_Software_Firmware\transfer_learning\models\ann_stage2_big_dataset
